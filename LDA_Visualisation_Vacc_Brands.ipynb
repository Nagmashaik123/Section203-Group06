# %% [markdown]
# <a href="https://colab.research.google.com/github/Nagmashaik123/Section203-Group06/blob/main/LDA_Visualisation_Vacc_Brands.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import re
import os
import io
import spacy
import string
import numpy as np
import pandas as pd

# Gensim
import gensim
from gensim import models
import gensim.corpora as corpora
from gensim.models import Phrases
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read and Prepare Dataset

# %%
dataset = pd.read_csv("processedcovidvaccinereact.csv", index_col=0)
dataset.shape
# Out:
# (126250, 7)

# %%
dataset = dataset.dropna() # drop null values
dataset.shape
# Out:
# (125829, 7)

# %%
dataset.head(5)
# Out:
#              TweetDate                                          TweetText  \
# 0  2021-03-17 23:59:34  The only way #COVID19 can mutate with variants...
# 1  2021-03-17 23:59:20  I've now officially had my 1st dose of the #Co...
# 2  2021-03-17 23:58:31  @hendopolis Imagine if the #Brexit referendum ...
# 3  2021-03-17 23:58:03  @EICostheta @RicBarraArch1 @insiders Yep. The ...
# 4  2021-03-17 23:57:37  This sounds like an important topic for @NickS...
#
#                                         CleanedTweet      TweetAuthor  \
# 0  onli way mutat variant viru replic host peopl ...         kemsunde
# 1  ive offici dose covidvaccin definit worth driv...         ManeckiN
# 2  hendopoli imagin brexit referendum held secret...  raymasseytweets
# 3  eicostheta insid yep liarsnparasit veri narrow...       MikeFitzAU
# 4  thi sound like import topic nicksawyermd tnich...     stephjantzen
#
#              TweetLocation                                        AllHashtags  \
# 0                  Unknown  ['COVID19', 'CovidVaccine', 'GetTheFactsGetThe...
# 1  The Wild Western Wastes  ['CovidVaccine', 'COVID19', 'PfizerVaccine', '...
# 2                  England  ['Brexit', 'EU', 'TrueColours', 'Impfstoff', '...
# 3                 Mudjimba                ['LiarsNParasites', 'CovidVaccine']
# 4       Greater Sacramento                   ['FiresideChat', 'CovidVaccine']
#
#           Country
# 0         Unknown
# 1         Unknown
# 2  United Kingdom
# 3       Australia
# 4          Brazil

# %%
text_data = dataset["CleanedTweet"]  # select cleaned tweets column
#text_data = text_data[:100]

# %%
text__data =  [text.split() for text in text_data]  # tokenize dataset

# %%
text__data
# Out:
# [['onli',
#   'way',
#   'mutat',
#   'variant',
#   'viru',
#   'replic',
#   'host',
#   'peopl',
#   'get',
#   'covidvaccin',
#   'protect',
#   'ourselv',
#   'block',
#   'viru',
#   'spread',
#   'mutat',
#   'dr',
#   'max',
#   'madher',
#   'bcbsla',
#   'getthefactsgetthevax',
#   'covidsaf'],
#  ['ive',
#   'offici',
#   'dose',
#   'covidvaccin',
#   'definit',
#   'worth',
#   'drive',
#   'without',
#   'doubt',
#   'thu',
#   'far',
#   'least',
#   'onli',
#   'side',
#   'effect',
#   'slightli',
#   'sore',
#   'arm',
#   'hope',
#   'happen',
#   'pfizervaccin',
#   'doyourpart',
#   'pic',
#   'come',
#   'soon'],
#  ['hendopoli',
#   'imagin',
#   'brexit',
#   'referendum',
#   'held',
#   'secretli',
#   'work',
#   'nigel',
#   'farag',
#   'eu',
#   'truecolour',
#   'vonderleyen',
#   'impfstoff',
#   'covidvaccin'],
#  ['eicostheta',
#   'insid',
#   'yep',
#   'liarsnparasit',
#   'veri',
#   'narrow',
#   'world',
#   'view',
#   'nobodi',
#   'safe',
#   'safe',
#   'concept',
#   'theyll',
#   'never',
#   'understand',
#   'start',
#   'abbotthockey',
#   'budget',
#   'amp',
#   'decim',
#   'foreign',
#   'aid',
#   'budget',
#   'china',
#   'step',
#   'well',
#   'durr',
#   'covidvaccin'],
#  ['thi',
#   'sound',
#   'like',
#   'import',
#   'topic',
#   'nicksawyermd',
#   'tnicholsmd',
#   'cover',
#   'join',
#   'u',
#   'firesidechat',
#   'import',
#   'convers',
#   'would',
#   'love',
#   'covidvaccin'],
#  ['studi',
#   'show',
#   'fdaapprov',
#   'vaccin',
#   'protect',
#   'current',
#   'covid',
#   'variant',
#   'covidvaccin'],
#  ['updat',
#   'back',
#   'park',
#   'lot',
#   'peopl',
#   'line',
#   'vaccin',
#   'appoint',
#   'wait',
#   'till',
#   'last',
#   'vaccin',
#   'administ',
#   'see',
#   'ani',
#   'spare',
#   'bottl',
#   'brother',
#   'top',
#   'standbi',
#   'list',
#   'covidvaccin'],
#  ['german',
#   'headlin',
#   'angela',
#   'merkel',
#   'refus',
#   'astrazeneca',
#   'vaccin',
#   'becaus',
#   'recommend',
#   'anyon',
#   'covidvaccin',
#   'say',
#   'safe',
#   'urg',
#   'take',
#   'stand',
#   'strong',
#   'refus'],
#  ['mask',
#   'ha',
#   'slip',
#   'eu',
#   'savag',
#   'aw',
#   'vaccin',
#   'block',
#   'threat',
#   'brand',
#   'bitter',
#   'honestli',
#   'hope',
#   'vonderleyen',
#   'guyverhofstadt',
#   'amp',
#   'eu',
#   'keep',
#   'make',
#   'threat',
#   'everyon',
#   'see',
#   'vile',
#   'eu',
#   'glori',
#   'uk',
#   'covidvaccin'],
#  ['chicagoan',
#   'age',
#   'older',
#   'receiv',
#   'first',
#   'dose',
#   'want',
#   'number',
#   'improv',
#   'chipublichealth',
#   'dr',
#   'jennif',
#   'seo',
#   'tell',
#   'annadavlant',
#   'protectchicago'],
#  ['think',
#   'like',
#   'gqp',
#   'simultan',
#   'prais',
#   'trimp',
#   'vaccin',
#   'confirm',
#   'need',
#   'take',
#   'vaccin',
#   'becaus',
#   'trimp',
#   'isnt',
#   'tell',
#   'truth',
#   'say',
#   'take',
#   'vaccin'],
#  ['hell',
#   'industri',
#   'sourc',
#   'say',
#   'australia',
#   'govern',
#   'rush',
#   'launch',
#   'covid',
#   'vaccin',
#   'book',
#   'system',
#   'scottmorrisonmp',
#   'stick',
#   'photo',
#   'opportun',
#   'covidvaccin',
#   'rollout',
#   'beyond',
#   'hi',
#   'abil',
#   'lnpfail',
#   'auspol'],
#  ['let',
#   'take',
#   'look',
#   'astrazeneca',
#   'covidvaccin',
#   'concern',
#   'venou',
#   'thromboembol',
#   'aka',
#   'blood',
#   'clotsthi',
#   'whi',
#   'use',
#   'ha',
#   'suspend',
#   'countri',
#   'yet',
#   'approv',
#   'valid',
#   'concern',
#   'thi',
#   'data',
#   'suggest',
#   'probabl'],
#  ['break',
#   'pregnanc',
#   'increas',
#   'risk',
#   'complic',
#   'read',
#   'preganc',
#   'covidvaccin',
#   'woman',
#   'thi',
#   'articl',
#   'wa',
#   'factcheck',
#   'oigetit',
#   'httpstcoqjyidbwvck'],
#  ['covidvaccin', 'appoint', 'avail', 'elig', 'patient'],
#  ['yay',
#   'stage',
#   'im',
#   'final',
#   'elig',
#   'vaccin',
#   'cross',
#   'finger',
#   'get',
#   'find',
#   'open',
#   'appoint',
#   'provaxx',
#   'covidvaccin'],
#  ['seriou',
#   'note',
#   'someth',
#   'wish',
#   'know',
#   'long',
#   'ago',
#   'needlephob',
#   'barrier',
#   'seek',
#   'medic',
#   'care',
#   'get',
#   'covidvaccin',
#   'legit',
#   'reason',
#   'ask',
#   'doctor',
#   'valium',
#   'dont',
#   'afraid',
#   'ask',
#   'help',
#   'need',
#   'stay',
#   'healthi'],
#  ['addit',
#   'appoint',
#   'staterun',
#   'vaccin',
#   'site',
#   'open',
#   'friday',
#   'follow',
#   'week',
#   'covidvaccin'],
#  ['key',
#   'rememb',
#   'hospit',
#   'posit',
#   'test',
#   'two',
#   'week',
#   'behind',
#   'time',
#   'infect',
#   'best',
#   'cours',
#   'action',
#   'vaccin',
#   'mani',
#   'peopl',
#   'possibl',
#   'wearamask',
#   'open',
#   'friday',
#   'match',
#   'colorado',
#   'getvaccinatedco',
#   'covidvaccin'],
#  ['think', 'know', 'origin', 'covidvaccin'],
#  ['first',
#   'shot',
#   'hopeget',
#   'covid',
#   'vaccin',
#   'via',
#   'kathleenmrodg',
#   'covidvaccin',
#   'author',
#   'hope'],
#  ['covidvaccin',
#   'enter',
#   'vacuum',
#   'without',
#   'ani',
#   'breath',
#   'apparatu',
#   'would',
#   'shortli',
#   'die',
#   'even',
#   'worn',
#   'crap',
#   'mask',
#   'amp',
#   'air',
#   'tank',
#   'may',
#   'last',
#   'littl',
#   'longer',
#   'none'],
#  ['abcbrisban',
#   'omg',
#   'talk',
#   'sheepl',
#   'flock',
#   'lem',
#   'like',
#   'fals',
#   'horizon',
#   'hope',
#   'sad',
#   'illus',
#   'covidvaccin',
#   'auspol'],
#  ['mdteryn',
#   'tryin',
#   'fool',
#   'doctor',
#   'dont',
#   'give',
#   'damn',
#   'patient',
#   'ani',
#   'maskup',
#   'shutup',
#   'socialdist',
#   'covidvaccin'],
#  ['guinea',
#   'pig',
#   'know',
#   'evid',
#   'vaccin',
#   'caus',
#   'woman',
#   'ever',
#   'abl',
#   'carri',
#   'babi',
#   'fullterm',
#   'research',
#   'befor',
#   'blindli',
#   'trust',
#   'globalist',
#   'govern',
#   'commit',
#   'popul',
#   'reduct',
#   'covidvaccin'],
#  ['earlier',
#   'today',
#   'got',
#   'first',
#   'dose',
#   'pfizer',
#   'covidvaccin',
#   'far',
#   'good',
#   'littl',
#   'sore'],
#  ['never',
#   'thought',
#   'id',
#   'loiter',
#   'mall',
#   'thi',
#   'vaccin',
#   'four',
#   'season',
#   'town',
#   'centr'],
#  ['got',
#   'first',
#   'shot',
#   'covidvaccin',
#   'today',
#   'nurs',
#   'put',
#   'bandaid',
#   'said',
#   'veri',
#   'brave',
#   'didnt',
#   'know',
#   'much',
#   'need',
#   'happen'],
#  ['peopl',
#   'book',
#   'vaccin',
#   'appoint',
#   'friday',
#   'peopl',
#   'abl',
#   'book',
#   'shot',
#   'accord',
#   'provinc',
#   'httpstcowzckureogp',
#   'oceansidenew',
#   'pqbnew',
#   'covidvaccin'],
#  ['doctor',
#   'adapt',
#   'shot',
#   'hamilton',
#   'vaccin',
#   'anthem',
#   'click',
#   'link',
#   'watch',
#   'video',
#   'covidvaccin',
#   'thisisourshot'],
#  ['tri',
#   'get',
#   'vaccin',
#   'luck',
#   'everyth',
#   'ha',
#   'book',
#   'open',
#   'father',
#   'year',
#   'old',
#   'still',
#   'ha',
#   'receiv',
#   'hi',
#   'first',
#   'shot',
#   'covidvaccin',
#   'noappoint',
#   'stillwait',
#   'astrazenecavaccin',
#   'wednesday',
#   'cdc',
#   'wearamask'],
#  ['ireland',
#   'hear',
#   'cdnpoli',
#   'publichealth',
#   'doctor',
#   'state',
#   'onli',
#   'ethic',
#   'moral',
#   'politician',
#   'ive',
#   'found',
#   'far',
#   'catherinegalway',
#   'say',
#   'support',
#   'ani',
#   'covidvaccin',
#   'maskup',
#   'polici',
#   'mani',
#   'dead',
#   'need',
#   'pediatr'],
#  ['thi',
#   'break',
#   'heart',
#   'polio',
#   'thank',
#   'salk',
#   'vaccin',
#   'mild',
#   'case',
#   'sibl',
#   'get',
#   'vaccin',
#   'save',
#   'mani',
#   'life',
#   'vaccin',
#   'vaccin',
#   'httpstcodhgmkfoytp'],
#  ['normanswan',
#   'nearest',
#   'clinic',
#   'hotdoc',
#   'onlin',
#   'book',
#   'appoint',
#   'phone',
#   'call',
#   'said',
#   'info',
#   'vaccin',
#   'arriv',
#   'put',
#   'hotdoc',
#   'answer',
#   'clinic',
#   'onlin',
#   'covidvaccinerollout',
#   'lie',
#   'covidvaccin'],
#  ['samslamdunk',
#   'im',
#   'think',
#   'often',
#   'case',
#   'wee',
#   'bit',
#   'jealousi',
#   'enter',
#   'countri',
#   'ensur',
#   'wellb',
#   'citizen',
#   'outstand',
#   'wellexecut',
#   'covidvaccin',
#   'rollout',
#   'israel',
#   'vaccinen'],
#  ['got', 'vaccinatedcovidvaccin'],
#  ['ha',
#   'anyon',
#   'ask',
#   'life',
#   'insur',
#   'compani',
#   'still',
#   'payout',
#   'suffer',
#   'life',
#   'chang',
#   'injuri',
#   'even',
#   'death',
#   'covid',
#   'vaccin',
#   'covid',
#   'vaccin',
#   'still',
#   'triall',
#   'covidvaccin'],
#  ['view',
#   'irishdailymail',
#   'eu',
#   'astrazeneca',
#   'ireland',
#   'covidvaccin',
#   'vonderleyen'],
#  ['new', 'pfizer', 'king', 'vaccin'],
#  ['last', 'week', 'began', 'vaccin', 'atrisk', 'inmat', 'opso', 'covidvaccin'],
#  ['vaccin',
#   'still',
#   'get',
#   'covid',
#   'mean',
#   'get',
#   'chanc',
#   'wont',
#   'die',
#   'still',
#   'give',
#   'covid',
#   'someon',
#   'els',
#   'lot',
#   'peopl',
#   'vaccin',
#   'wearamask',
#   'keepyourdist'],
#  ['hand',
#   'reckon',
#   'could',
#   'manag',
#   'prioritis',
#   'covidvaccin',
#   'roll',
#   'australian',
#   'better',
#   'scottyfrommarket',
#   'amp',
#   'greghuntmp',
#   'lnpfail',
#   'auspol',
#   'catastroph'],
#  ['matthancock',
#   'astrazeneca',
#   'say',
#   'issu',
#   'vaccinesuppli',
#   'whi',
#   'delay',
#   'whi',
#   'say',
#   'suppli',
#   'lumpi',
#   'clearli',
#   'adult',
#   'treat',
#   'u',
#   'tell',
#   'u',
#   'truth',
#   'covidvaccin',
#   'coronaviru'],
#  ['got',
#   'first',
#   'shot',
#   'moderna',
#   'covidvaccin',
#   'today',
#   'im',
#   'still',
#   'wait',
#   'gain',
#   'power',
#   'thor',
#   'side',
#   'effect',
#   'vaccin'],
#  ['got',
#   'vaccin',
#   'yesterday',
#   'onli',
#   'side',
#   'effect',
#   'wa',
#   'sore',
#   'arm',
#   'im',
#   'grate',
#   'high',
#   'risk',
#   'self',
#   'soon',
#   'protect',
#   'scienc',
#   'covidvaccin',
#   'moderna'],
#  ['new',
#   'protocol',
#   'youv',
#   'ever',
#   'need',
#   'covid',
#   'test',
#   'onc',
#   'past',
#   'yearfront',
#   'line',
#   'need',
#   'test',
#   'becaus',
#   'legit',
#   'covid',
#   'exposur',
#   'asymptomat',
#   'neg',
#   'want',
#   'get',
#   'call',
#   'give',
#   'vaccin',
#   'within',
#   'hr',
#   'makeithappen',
#   'covidvaccin'],
#  ['get',
#   'vaccin',
#   'becaus',
#   'thing',
#   'protect',
#   'help',
#   'get',
#   'everyon',
#   'back',
#   'normal',
#   'life',
#   'talk',
#   'covidvaccin',
#   'healthcar',
#   'peopl',
#   'learningdis',
#   'new',
#   'ablemag',
#   'articl'],
#  ['receiv',
#   'dose',
#   'pfizer',
#   'ani',
#   'sick',
#   'later',
#   'daynext',
#   'day',
#   'ive',
#   'heard',
#   'notsogreat',
#   'stori',
#   'curiou',
#   'covidvaccin'],
#  ['notic',
#   'peopl',
#   'demagogu',
#   'covid',
#   'vaccin',
#   'rush',
#   'trump',
#   'vaccin',
#   'urg',
#   'peopl',
#   'get',
#   'shot',
#   'covidvaccin',
#   'vaccin'],
#  ['deadli',
#   'incompet',
#   'age',
#   'onlin',
#   'medic',
#   'record',
#   'wow',
#   'covidvaccin',
#   'onpoli'],
#  ['one',
#   'hesit',
#   'get',
#   'covidvaccin',
#   'becaus',
#   'cost',
#   'avail',
#   'peopl',
#   'privat',
#   'insur',
#   'medicaid',
#   'medicar',
#   'uninsur',
#   'care',
#   'act',
#   'bcbsla',
#   'paula',
#   'shepherd'],
#  ['longcovid',
#   'rare',
#   'health',
#   'crisi',
#   'covidvaccin',
#   'washingtonpost',
#   'nytim',
#   'financialtim',
#   'wsjhealth',
#   'reuter',
#   'busi',
#   'ap',
#   'bbc',
#   'cnbc',
#   'cnn',
#   'msn',
#   'msnbc',
#   'thehil',
#   'amermedicalassn',
#   'dupagecm',
#   'cdcgov',
#   'hhsgov',
#   'acog'],
#  ['peston',
#   'interestingno',
#   'suppli',
#   'problem',
#   'thenso',
#   'govern',
#   'paus',
#   'call',
#   'halt',
#   'due',
#   'variou',
#   'health',
#   'safeti',
#   'issu',
#   'rais',
#   'subsequ',
#   'ban',
#   'thi',
#   'vaccin',
#   'countri',
#   'covidvaccin'],
#  ['art',
#   'live',
#   'beauti',
#   'green',
#   'anim',
#   'lover',
#   'deer',
#   'dallasartist',
#   'flower',
#   'instapaint',
#   'instanatur',
#   'natur',
#   'interiordesign',
#   'artlov',
#   'artist',
#   'paint',
#   'anim',
#   'galleri',
#   'artistontwitt',
#   'artclass',
#   'class',
#   'covidvaccin'],
#  ['get',
#   'vaccin',
#   'becaus',
#   'thing',
#   'help',
#   'get',
#   'everyon',
#   'back',
#   'normal',
#   'life',
#   'talk',
#   'covidvaccin',
#   'peopl',
#   'learningdis',
#   'new',
#   'ablemag',
#   'articl',
#   'read'],
#  ['slow',
#   'start',
#   'canada',
#   'vaccin',
#   'rollout',
#   'race',
#   'time',
#   'cbc',
#   'news',
#   'covidcanada',
#   'covidvaccin',
#   'covidvaccin'],
#  ['mood', 'happystpatricksday', 'vaccin', 'vaccinessavel', 'vaccineswork'],
#  ['understand',
#   'peopl',
#   'hesit',
#   'covidvaccin',
#   'import',
#   'look',
#   'data',
#   'talk',
#   'healthcar',
#   'provid',
#   'dont',
#   'reli',
#   'rumor',
#   'thing',
#   'see',
#   'onlin',
#   'bcbsla',
#   'getthefactsgetthevax',
#   'covidsaf'],
#  ['vaccin',
#   'roll',
#   'slow',
#   'april',
#   'doe',
#   'thi',
#   'mean',
#   'lockdown',
#   'eas',
#   'also',
#   'delay',
#   'see',
#   'first',
#   'test',
#   'vaccin',
#   'deploy',
#   'programm',
#   'continu',
#   'success',
#   'covidvaccin'],
#  ['austin',
#   'leaf',
#   'traviscounti',
#   'popul',
#   'still',
#   'need',
#   'fulli',
#   'vaccin',
#   'texascovid',
#   'coronaviru',
#   'pandem',
#   'covidvaccin',
#   'atx',
#   'health',
#   'covid'],
#  ['covidvaccin',
#   'moderna',
#   'shot',
#   'updat',
#   'hr',
#   'sinc',
#   'moderna',
#   'dose',
#   'weve',
#   'fatigu',
#   'sore',
#   'arm',
#   'first',
#   'shot',
#   'wa',
#   'sore',
#   'im',
#   'littl',
#   'woozi',
#   'w',
#   'slight',
#   'headach',
#   'havent',
#   'taken',
#   'anyth',
#   'earli',
#   'bed',
#   'tonight',
#   'hope'],
#  ['biden',
#   'readi',
#   'campaign',
#   'combat',
#   'vaccin',
#   'skeptic',
#   'via',
#   'politico',
#   'covidvaccin',
#   'vaxnew',
#   'vaccin',
#   'vaccineswork',
#   'vaccin'],
#  ['beauti',
#   'memori',
#   'rome',
#   'sister',
#   'anoth',
#   'mister',
#   'brought',
#   'smile',
#   'face',
#   'yet',
#   'im',
#   'humbl',
#   'dispirit',
#   'lock',
#   'itali',
#   'due',
#   'anoth',
#   'wave',
#   'poor',
#   'vaccin',
#   'effort',
#   'europ',
#   'covidvaccin',
#   'rome',
#   'vatican',
#   'cathol',
#   'histori',
#   'travel',
#   'httpstcoqhodkdnyob'],
#  ['everyth',
#   'need',
#   'know',
#   'get',
#   'vaccin',
#   'rollout',
#   'extend',
#   'across',
#   'u',
#   'vaccin',
#   'covidvaccin'],
#  ['skynew',
#   'suppli',
#   'astrazenecavaccin',
#   'refus',
#   'use',
#   'thank',
#   'god',
#   'brexitr',
#   'vaccin',
#   'covidvaccin'],
#  ['spot',
#   'got',
#   'hi',
#   'shot',
#   'proud',
#   'dad',
#   'share',
#   'hi',
#   'reason',
#   'get',
#   'covidvaccin',
#   'ncdhh'],
#  ['ppaulcharl',
#   'news',
#   'put',
#   'hold',
#   'vaccinehow',
#   'thi',
#   'affect',
#   'chanc',
#   'peopl',
#   'go',
#   'cypru',
#   'whove',
#   'chanc',
#   'fulli',
#   'vaccin',
#   'peak',
#   'summer',
#   'im',
#   'worri',
#   'wont',
#   'jab',
#   'septemb',
#   'covidvaccin'],
#  ['onion',
#   'john',
#   'kerri',
#   'chines',
#   'viru',
#   'wuhan',
#   'unwit',
#   'thanktrumpfornoth',
#   'stopasianh',
#   'trump',
#   'gop',
#   'maga',
#   'bidenactnow',
#   'bidenbordercrisi',
#   'congress',
#   'cancelcultur',
#   'blacklivesmatt',
#   'covidvaccin',
#   'covideoparti',
#   'blm',
#   'asian',
#   'american',
#   'breakingnew',
#   'break',
#   'foxnew'],
#  ['yeah', 'strain', 'come', 'think', 'philippin', 'covidvaccin'],
#  ['vaccin',
#   'covidvaccin',
#   'got',
#   'first',
#   'covid',
#   'vaccin',
#   'shot',
#   'yesterday',
#   'moderna',
#   'ani',
#   'side',
#   'effect',
#   'clinic',
#   'wa',
#   'veri',
#   'well',
#   'organ',
#   'togeth',
#   'spent',
#   'le',
#   'minut',
#   'includ',
#   'minut',
#   'wait',
#   'time',
#   'shot',
#   'make',
#   'sure',
#   'wa',
#   'ok'],
#  ['thi',
#   'one',
#   'imposs',
#   'comprehend',
#   'uninspir',
#   'unrealist',
#   'dreamer',
#   'inspir',
#   'heart',
#   'make',
#   'life',
#   'say',
#   'wow',
#   'inspir',
#   'wisdom',
#   'philosophi',
#   'motiv',
#   'mentalhealth',
#   'quot',
#   'quot',
#   'dreambig',
#   'posit',
#   'possibl',
#   'optim',
#   'covidvaccin'],
#  ['wrap', 'covidvaccin', 'sleevesupla', 'httpstcothimscywmr'],
#  ['donald',
#   'trump',
#   'still',
#   'public',
#   'health',
#   'threat',
#   'via',
#   'motherjon',
#   'covidvaccin',
#   'getvaccin'],
#  ['would',
#   'like',
#   'thank',
#   'emot',
#   'eat',
#   'past',
#   'month',
#   'friday',
#   'qualifi',
#   'covid',
#   'shot',
#   'ohio',
#   'god',
#   'work',
#   'mysteri',
#   'way',
#   'covidvaccin'],
#  ['thi', 'happen', 'vaccin'],
#  ['gold',
#   'coin',
#   'found',
#   'stpatricksday',
#   'onli',
#   'dollar',
#   'send',
#   'jimmyfallon',
#   'style',
#   'thank',
#   'note',
#   'bidenadminstr',
#   'stimuluscheck',
#   'studentdebt',
#   'covidreliefbil',
#   'covidvaccin',
#   'etc',
#   'etc'],
#  ['thi', 'would', 'fun', 'tri', 'covidvaccin', 'httpstcofximiskjxa'],
#  ['heartotxheartmd', 'thank', 'voic', 'power', 'necessari', 'covidvaccin'],
#  ['dont',
#   'talk',
#   'histori',
#   'minor',
#   'fear',
#   'relat',
#   'research',
#   'im',
#   'activ',
#   'particip',
#   'move',
#   'histori',
#   'forward',
#   'encourag',
#   'minor',
#   'particip',
#   'life',
#   'save',
#   'research',
#   'vaccin',
#   'histori',
#   'dontbeleftbehind',
#   'cancersurvivor',
#   'httpstcoatsdvjniyw'],
#  ['plan',
#   'get',
#   'vaccin',
#   'far',
#   'answer',
#   'ye',
#   'survey',
#   'sponsor',
#   'teaminspir',
#   'let',
#   'voic',
#   'heard',
#   'take',
#   'survey',
#   'inspireambassador',
#   'httpstcoypfozsxhmm'],
#  ['thegreatreset', 'covidvaccin'],
#  ['kosovo',
#   'seek',
#   'help',
#   'israel',
#   'vaccin',
#   'failur',
#   'eu',
#   'deliv',
#   'far',
#   'covidvaccin'],
#  ['thi',
#   'kind',
#   'amaz',
#   'vacavil',
#   'doctor',
#   'remix',
#   'hamilton',
#   'celebr',
#   'covidvaccin',
#   'bravo',
#   'frontlin',
#   'healthcar',
#   'worker',
#   'still',
#   'work',
#   'save',
#   'life',
#   'dispel',
#   'misinform',
#   'dure',
#   'thi',
#   'pandem'],
#  ['covidvaccin',
#   'clinic',
#   'thur',
#   'sat',
#   'call',
#   'ahead',
#   'make',
#   'appoint',
#   'walkin',
#   'welcom',
#   'guarante'],
#  ['pfizer', 'let', 'thi', 'vaccin', 'pfizervaccin'],
#  ['pfulli',
#   'pfizerd',
#   'thank',
#   'maudsleynh',
#   'amp',
#   'kingscollegenh',
#   'covidvaccin',
#   'httpstcovpwbhfzvoj'],
#  ['got',
#   'first',
#   'dose',
#   'moderna',
#   'covidvaccin',
#   'today',
#   'feel',
#   'veri',
#   'hope',
#   'thi',
#   'summer',
#   'gon',
#   'na',
#   'veri',
#   'awkward',
#   'relearn',
#   'social',
#   'irl',
#   'human'],
#  ['karriehiggin',
#   'havent',
#   'abl',
#   'book',
#   'appoint',
#   'week',
#   'went',
#   'onto',
#   'govern',
#   'websit',
#   'today',
#   'vaccin',
#   'center',
#   'within',
#   'mile',
#   'radiu',
#   'appoint',
#   'got',
#   'ta',
#   'love',
#   'well',
#   'execut',
#   'plan',
#   'action',
#   'govern',
#   'peopl',
#   'covidvaccin'],
#  ['got', 'first', 'vaccin', 'dose', 'today', 'yay', 'covidvaccin'],
#  ['year',
#   'dont',
#   'wear',
#   'green',
#   'irish',
#   'wife',
#   'pinch',
#   'exact',
#   'spot',
#   'arm',
#   'everi',
#   'year',
#   'thi',
#   'year',
#   'forgot',
#   'green',
#   'gave',
#   'love',
#   'pinch',
#   'arm',
#   'yell',
#   'ouch',
#   'got',
#   'covidvaccin',
#   'whi',
#   'feel',
#   'like',
#   'charli',
#   'brown',
#   'right'],
#  ['kind',
#   'shot',
#   'normal',
#   'stpatricksday',
#   'shot',
#   'none',
#   'le',
#   'covidvaccin',
#   'shotsinarm',
#   'pfizervaccin',
#   'vaccinessavel'],
#  ['got',
#   'appoint',
#   'vaccin',
#   'sunday',
#   'im',
#   'get',
#   'children',
#   'hospit',
#   'yay',
#   'justbreath',
#   'spooni',
#   'covidvaccin'],
#  ['probabl', 'best', 'text', 'ever', 'got', 'mom', 'vaccin'],
#  ['chrischirp',
#   'independentsag',
#   'covid',
#   'vaccin',
#   'wa',
#   'alway',
#   'go',
#   'onc',
#   'second',
#   'start',
#   'sure',
#   'thi',
#   'wasnt',
#   'plan',
#   'along',
#   'letter',
#   'r',
#   'sent',
#   'also',
#   'whi',
#   'r',
#   'plan',
#   'fulli',
#   'open',
#   'june',
#   'plan',
#   'give',
#   'peopl',
#   'dose',
#   'isnt',
#   'till',
#   'juli',
#   'much',
#   'inconsist',
#   'covidvaccin'],
#  ['thi',
#   'morn',
#   'percent',
#   'new',
#   'yorker',
#   'complet',
#   'least',
#   'one',
#   'covidvaccin',
#   'dose'],
#  ['thank',
#   'walmart',
#   'thi',
#   'inform',
#   'vaccin',
#   'avail',
#   'teacher',
#   'caregiv',
#   'atlantachoosehealthylif',
#   'covidvaccin'],
#  ['shortcut',
#   'scientif',
#   'review',
#   'process',
#   'covidvaccin',
#   'wa',
#   'thoroughli',
#   'vet',
#   'test',
#   'speed',
#   'wa',
#   'result',
#   'world',
#   'scientist',
#   'come',
#   'togeth',
#   'global',
#   'fund',
#   'resourc',
#   'work',
#   'bcbsla',
#   'paula',
#   'shepherd'],
#  ['go',
#   'retweet',
#   'comment',
#   'mani',
#   'boston',
#   'polic',
#   'depart',
#   'refus',
#   'covidvaccin',
#   'bottom',
#   'line',
#   'someon',
#   'involv',
#   'hire',
#   'didnt',
#   'hire',
#   'conscienti',
#   'care',
#   'educ',
#   'choic',
#   'avail',
#   'hire',
#   'pool',
#   'bostonglob',
#   'check'],
#  ['proud',
#   'see',
#   'india',
#   'improv',
#   'day',
#   'day',
#   'india',
#   'made',
#   'vaccin',
#   'provid',
#   'countri',
#   'corona',
#   'gocoronago',
#   'covidvaccin',
#   'improud',
#   'india',
#   'jaimatadi',
#   'bharatmatakijai'],
#  ['drericd',
#   'thi',
#   'part',
#   'sound',
#   'deepli',
#   'concern',
#   'especi',
#   'peopl',
#   'seem',
#   'optimist',
#   'fatigu',
#   'run',
#   'wild',
#   'free',
#   'without',
#   'wear',
#   'mask',
#   'social',
#   'distanc',
#   'practic',
#   'hygien',
#   'variant',
#   'variantsofconcern',
#   'variant',
#   'covidfatigu',
#   'covidvaccin',
#   'wearamask'],
#  ['bbpublichealth',
#   'much',
#   'thank',
#   'guard',
#   'medic',
#   'personnel',
#   'staf',
#   'lane',
#   'today',
#   'civic',
#   'center',
#   'veri',
#   'profession',
#   'effici',
#   'inform',
#   'ndnationalguard',
#   'covidvaccin'],
#  ['today',
#   'wore',
#   'herd',
#   'immun',
#   'dress',
#   'amp',
#   'watch',
#   'man',
#   'leav',
#   'w',
#   'hi',
#   'cain',
#   'mask',
#   'becam',
#   'soggi',
#   'tear',
#   'incred',
#   'thank',
#   'overcom',
#   'thank',
#   'worker',
#   'amp',
#   'scientist',
#   'hero',
#   'mourn',
#   'lost',
#   'amp',
#   'allow',
#   'dream',
#   'amp',
#   'breath',
#   'vaccin'],
#  ['bopanc',
#   'bring',
#   'vonderleyen',
#   'eu',
#   'nut',
#   'go',
#   'thi',
#   'road',
#   'astrazeneca',
#   'covidvaccin'],
#  ['appoint',
#   'doctor',
#   'im',
#   'still',
#   'wait',
#   'hour',
#   'later',
#   'told',
#   'wait',
#   'still',
#   'doctor',
#   'overwhelm',
#   'callsvisit',
#   'covidvaccin',
#   'dont',
#   'mind',
#   'wait',
#   'interest',
#   'affect'],
#  ['drink', 'dasani', 'dont', 'worri', 'covidvaccin'],
#  ['mom',
#   'got',
#   'second',
#   'vaccin',
#   'today',
#   'im',
#   'look',
#   'forward',
#   'show',
#   'around',
#   'florida',
#   'next',
#   'month',
#   'covidvaccin'],
#  ['go',
#   'got',
#   'vaccin',
#   'could',
#   'safe',
#   'around',
#   'dad',
#   'love',
#   'one',
#   'thi',
#   'big',
#   'step',
#   'posit',
#   'direct',
#   'everyon',
#   'findyourspotnc',
#   'vaccinessavel'],
#  ['inde',
#   'need',
#   'eu',
#   'never',
#   'let',
#   'go',
#   'covidvaccin',
#   'euvaccineshambl'],
#  ['dr',
#   'max',
#   'madher',
#   'broke',
#   'ingredi',
#   'covidvaccin',
#   'explain',
#   'whi',
#   'safe',
#   'effect',
#   'base',
#   'decad',
#   'medic',
#   'research',
#   'technolog',
#   'brandnew',
#   'vaccin',
#   'type',
#   'getthefactsgetthevax',
#   'covidsaf',
#   'bcbsla'],
#  ['govrondesanti',
#   'rondesantisfl',
#   'theme',
#   'park',
#   'worker',
#   'thousand',
#   'u',
#   'ye',
#   'essenti',
#   'worker',
#   'vaccin',
#   'u',
#   'vaccin',
#   'florida',
#   'covidvaccin'],
#  ['march',
#   'inform',
#   'pandem',
#   'across',
#   'canada',
#   'around',
#   'world',
#   'click',
#   'link',
#   'lockdown',
#   'covidvaccin',
#   'coronaviru',
#   'covid',
#   'astrazeneca',
#   'onpoli',
#   'cdnpoli',
#   'toronto',
#   'ontario',
#   'canada'],
#  ['woman',
#   'hidalgo',
#   'mexico',
#   'die',
#   'minut',
#   'receiv',
#   'health',
#   'author',
#   'said',
#   'find',
#   'link',
#   'death',
#   'shot',
#   'administ',
#   'httpstcooamwawcljr'],
#  ['got',
#   'covidvaccin',
#   'yesterday',
#   'nasti',
#   'headach',
#   'nausea',
#   'today',
#   'wa',
#   'hope',
#   'first',
#   'shot',
#   'would',
#   'easi',
#   'lot',
#   'anxieti',
#   'dure',
#   'minut',
#   'wait',
#   'go'],
#  ['check',
#   'latest',
#   'infograph',
#   'reason',
#   'continu',
#   'wear',
#   'mask',
#   'vaccin',
#   'facemask',
#   'bettermask',
#   'covidvaccin',
#   'publichealth',
#   'cdc',
#   'staysaf'],
#  ['ye',
#   'oldest',
#   'child',
#   'got',
#   'hi',
#   'first',
#   'shot',
#   'today',
#   'vaccin',
#   'hi',
#   'wife',
#   'alreadi',
#   'doneon',
#   'one',
#   'famili',
#   'becom',
#   'safe',
#   'final',
#   'togeth',
#   'thi',
#   'veri',
#   'veri',
#   'long',
#   'separ'],
#  ['absolut',
#   'nazi',
#   'jjhorgan',
#   'say',
#   'ani',
#   'author',
#   'limit',
#   'restrict',
#   'fright',
#   'freedom',
#   'canadian',
#   'citizen',
#   'anticip',
#   'mani',
#   'lawsuit',
#   'thi',
#   'even',
#   'topic',
#   'discuss',
#   'fuckig',
#   'joke',
#   'bcpoli',
#   'cndpoli',
#   'covidvaccin',
#   'httpstcozzegrwnbtf'],
#  ['good',
#   'bless',
#   'young',
#   'adult',
#   'son',
#   'got',
#   'leftov',
#   'vaccin',
#   'today',
#   'husband',
#   'got',
#   'hi',
#   'monday',
#   'mean',
#   'im',
#   'last',
#   'adult',
#   'vaccin',
#   'famili',
#   'tomorrow',
#   'covidvaccin',
#   'gratefulheart',
#   'get',
#   'waitlist'],
#  ['thi',
#   'explain',
#   'whi',
#   'im',
#   'get',
#   'ani',
#   'damn',
#   'covid',
#   'vaccin',
#   'dont',
#   'make',
#   'immun',
#   'dont',
#   'stop',
#   'spread',
#   'henc',
#   'vaccin',
#   'thi',
#   'articl',
#   'worth',
#   'read',
#   'experiment',
#   'gene',
#   'therapi',
#   'bad',
#   'idea',
#   'covidvaccin'],
#  ['lot',
#   'site',
#   'say',
#   'vaccin',
#   'fl',
#   'younger',
#   'teacher',
#   'staff',
#   'cant',
#   'get',
#   'appoint',
#   'anywher',
#   'frustrat',
#   'covidvaccin',
#   'publix',
#   'cvspharmaci',
#   'winndixi',
#   'walmart'],
#  ['receiv',
#   'dose',
#   'moderna',
#   'vaccin',
#   'today',
#   'im',
#   'incred',
#   'grate',
#   'time',
#   'effort',
#   'ha',
#   'gone',
#   'make',
#   'thi',
#   'possibl',
#   'cant',
#   'wait',
#   'end',
#   'april',
#   'im',
#   'fulli',
#   'vaccin',
#   'vaccin'],
#  ['learn',
#   'safe',
#   'practic',
#   'implement',
#   'dure',
#   'thi',
#   'ongo',
#   'pandem',
#   'complet',
#   'thi',
#   'free',
#   'awar',
#   'train',
#   'program',
#   'onlin',
#   'today',
#   'find',
#   'httpstcolipyzanmek',
#   'find',
#   'scarborough',
#   'care',
#   'commun',
#   'network',
#   'covidvaccin'],
#  ['maddow',
#   'fl',
#   'corrupt',
#   'govrondesanti',
#   'wont',
#   'let',
#   'dentist',
#   'administ',
#   'covidvaccin',
#   'bc',
#   'dental',
#   'associ',
#   'hasnt',
#   'bribe',
#   'like',
#   'publix',
#   'potu',
#   'pleas',
#   'overrid',
#   'far',
#   'limit',
#   'elig',
#   'give',
#   'receiv',
#   'vaccin'],
#  ['minut',
#   'break',
#   'abstractart',
#   'asianlivesmatt',
#   'covidvaccin',
#   'hockney',
#   'artist',
#   'artsofash',
#   'artcur',
#   'artgalleri',
#   'exhibit',
#   'planb',
#   'brown',
#   'earth',
#   'earthton',
#   'yellow',
#   'app',
#   'pictur',
#   'design',
#   'photooftheday',
#   'photographyisart'],
#  ['receiv',
#   'first',
#   'covidvaccin',
#   'today',
#   'id',
#   'like',
#   'send',
#   'special',
#   'thank',
#   'u',
#   'health',
#   'care',
#   'worker',
#   'doctor',
#   'nurs',
#   'etc',
#   'yall',
#   'real',
#   'superhero',
#   'healthcarehero'],
#  ['slipper',
#   'insid',
#   'apart',
#   'need',
#   'help',
#   'rescu',
#   'vaccin',
#   'vaccin',
#   'vaccin',
#   'socialdistanc'],
#  ['today',
#   'gave',
#   'covidvaccin',
#   'good',
#   'sam',
#   'one',
#   'patient',
#   'share',
#   'kind',
#   'word',
#   'team',
#   'say',
#   'wa',
#   'impress',
#   'way',
#   'handl',
#   'covid',
#   'shot',
#   'organ',
#   'help',
#   'got',
#   'thank',
#   'veri',
#   'much',
#   'nurs',
#   'great',
#   'job'],
#  ['rabbijil',
#   'tell',
#   'doctor',
#   'would',
#   'refus',
#   'attend',
#   'unvaccin',
#   'staff',
#   'covidiot',
#   'covidvaccin',
#   'coronaviru'],
#  ['thing',
#   'somehow',
#   'feel',
#   'left',
#   'scroll',
#   'timelin',
#   'zachsnydersjusticeleagu',
#   'preview',
#   'access',
#   'covidvaccin'],
#  ['good',
#   'day',
#   'got',
#   'first',
#   'dose',
#   'vaccin',
#   'courtesi',
#   'democrat',
#   'parti',
#   'unit',
#   'state',
#   'america',
#   'covidvaccin',
#   'democrat'],
#  ['book', 'appoint', 'dang', 'thing', 'vaccin'],
#  ['dr',
#   'max',
#   'madher',
#   'bcbsla',
#   'paula',
#   'shepherd',
#   'give',
#   'fact',
#   'covidvaccin',
#   'help',
#   'everyon',
#   'feel',
#   'safe',
#   'comfort',
#   'prepar',
#   'rollupyoursleev',
#   'getthefactsgetthevax',
#   'covidsaf'],
#  ['shot', 'done', 'vaccin', 'woo', 'hoo', 'covidvaccin', 'getvaccin'],
#  ['greghuntmp',
#   'mani',
#   'otherwis',
#   'qualifi',
#   'covidvaccin',
#   'shot',
#   'miss',
#   'becaus',
#   'med',
#   'centr',
#   'far',
#   'away',
#   'gov',
#   'health',
#   'record'],
#  ['got',
#   'first',
#   'dose',
#   'two',
#   'dose',
#   'moderna',
#   'covidvaccin',
#   'im',
#   'happi'],
#  ['whether', 'believ', 'luck', 'pleas', 'research'],
#  ['covidvaccin',
#   'shot',
#   'number',
#   'tmw',
#   'first',
#   'time',
#   'life',
#   'paid',
#   'asthma'],
#  ['proud',
#   'grate',
#   'receiv',
#   'first',
#   'covidvaccin',
#   'today',
#   'thank',
#   'pfizer',
#   'walgreen',
#   'getvaccin'],
#  ['happi',
#   'announc',
#   'got',
#   'first',
#   'covid',
#   'vaccin',
#   'covidvaccin',
#   'vaccin'],
#  ['true', 'stori', 'vaccin'],
#  ['well',
#   'even',
#   'want',
#   'covidvaccin',
#   'closest',
#   'locat',
#   'slot',
#   'avail',
#   'hour',
#   'drive',
#   'guess',
#   'ill',
#   'wait',
#   'xrp'],
#  ['make',
#   'wait',
#   'inject',
#   'incas',
#   'reaction',
#   'complain',
#   'arm',
#   'sore',
#   'like',
#   'ani',
#   'vaccin',
#   'come',
#   'back',
#   'second',
#   'dosag',
#   'easi',
#   'peasi',
#   'yall',
#   'covidvaccin'],
#  ['covidvaccin',
#   'realli',
#   'curiousso',
#   'let',
#   'social',
#   'experi',
#   'vaccin',
#   'either',
#   'pfizer',
#   'astrazeneca',
#   'pleas',
#   'answer',
#   'honestli',
#   'retweet',
#   'possibl'],
#  ['mebottazzi',
#   'peterhotez',
#   'sciencematt',
#   'covidvaccin',
#   'genet',
#   'modif',
#   'abl',
#   'design',
#   'bettercontrol',
#   'stabl',
#   'vaccin',
#   'candid',
#   'essenti',
#   'import',
#   'criterion',
#   'ani',
#   'process',
#   'manufactur',
#   'biolog',
#   'drug',
#   'human',
#   'use'],
#  ['albomp',
#   'dont',
#   'promis',
#   'cant',
#   'deliv',
#   'dont',
#   'put',
#   'roll',
#   'hand',
#   'privat',
#   'liber',
#   'donor',
#   'use',
#   'state',
#   'public',
#   'health',
#   'council',
#   'mass',
#   'immunis',
#   'suppli',
#   'gp',
#   'covidvaccin',
#   'per',
#   'fortnight',
#   'pay',
#   'appropri',
#   'racgppresid',
#   'amapresid'],
#  ['im', 'schedul', 'vaccin', 'covidvaccin'],
#  ['get',
#   'shit',
#   'togeth',
#   'prioriti',
#   'list',
#   'fuckin',
#   'bullshit',
#   'know',
#   'itcovidvaccin'],
#  ['month',
#   'left',
#   'signup',
#   'excit',
#   'live',
#   'webinar',
#   'featur',
#   'among',
#   'expert',
#   'vaccin',
#   'immunologist',
#   'dr',
#   'ali',
#   'ellebedi',
#   'thebcellartist',
#   'discuss',
#   'covaripad',
#   'initi',
#   'data',
#   'soon',
#   'effectivenesssafeti',
#   'ibd',
#   'amp',
#   'autoimmun',
#   'dz'],
#  ['wednesday',
#   'covidvaccin',
#   'number',
#   'new',
#   'sinc',
#   'monday',
#   'tue',
#   'number',
#   'never',
#   'post',
#   'georgian',
#   'two',
#   'adult',
#   'still',
#   'freezer',
#   'gov',
#   'kemp',
#   'urg',
#   'provid',
#   'hoard',
#   'futur',
#   'second',
#   'shot'],
#  ['go', 'wrong', 'covidvaccin'],
#  ['mrna',
#   'two',
#   'covidvaccin',
#   'like',
#   'snapchat',
#   'immun',
#   'system',
#   'deliv',
#   'messag',
#   'fight',
#   'doe',
#   'interact',
#   'dna',
#   'cell',
#   'materi',
#   'ani',
#   'way',
#   'dr',
#   'max',
#   'madher',
#   'bcbsla',
#   'getthefactsgetthevax',
#   'covidsaf'],
#  ['remind',
#   'ema',
#   'approv',
#   'first',
#   'vaccin',
#   'decemb',
#   'becaus',
#   'eu',
#   'ireland',
#   'vaccin',
#   'onli',
#   'peopl',
#   'uk',
#   'done',
#   'million',
#   'fuck',
#   'eu',
#   'fuck',
#   'brussel',
#   'covidvaccin'],
#  ['bbcnew',
#   'assum',
#   'wa',
#   'plan',
#   'increas',
#   'infrastructur',
#   'number',
#   'daili',
#   'first',
#   'would',
#   'drop',
#   'substanti',
#   'anyway',
#   'mani',
#   'peopl',
#   'start',
#   'becom',
#   'due',
#   'second',
#   'jab'],
#  ['senjohnbarrasso',
#   'newsweek',
#   'potu',
#   'truth',
#   'democrat',
#   'offer',
#   'better',
#   'tax',
#   'relief',
#   'nation',
#   'secur',
#   'covidvaccin',
#   'polici',
#   'law',
#   'order',
#   'support',
#   'militari',
#   'opposit',
#   'tyrant',
#   'like',
#   'putin',
#   'gop',
#   'gopcorruptionovercountri',
#   'maga',
#   'joebiden',
#   'wyom'],
#  ['itvnew',
#   'eu',
#   'ha',
#   'almost',
#   'entireti',
#   'ban',
#   'use',
#   'astrazeneca',
#   'vaccin',
#   'dont',
#   'want',
#   'uk',
#   'use',
#   'suppli',
#   'theyr',
#   'bin',
#   'nonsens',
#   'covidvaccin',
#   'niceneighbour'],
#  ['dearborn', 'dearbornheight', 'inkster', 'resid', 'fyi', 'covidvaccin'],
#  ['last',
#   'time',
#   'wa',
#   'thi',
#   'room',
#   'wa',
#   'watch',
#   'talksmachina',
#   'never',
#   'thought',
#   'id',
#   'happier',
#   'thi',
#   'thi',
#   'even',
#   'better',
#   'vaccin'],
#  ['summon',
#   'astrazeneca',
#   'covidvaccin',
#   'inject',
#   'get',
#   'zero',
#   'inform',
#   'go',
#   'inject',
#   'potenti',
#   'side',
#   'effect',
#   'option',
#   'discuss',
#   'noon',
#   'mention',
#   'ivermectin',
#   'covidtreat',
#   'right'],
#  ['vaccin', 'scienc', 'vaccin', 'vaccin', 'vaccin'],
#  ['surpris', 'matt', 'hancock', 'cant', 'count', 'covidvaccin'],
#  ['guardiannew',
#   'wtf',
#   'disgust',
#   'eurocrat',
#   'quot',
#   'go',
#   'finish',
#   'job',
#   'germani',
#   'start',
#   'go',
#   'send',
#   'british',
#   'graf',
#   'stop',
#   'covidvaccin',
#   'export',
#   'britain'],
#  ['stpatricksday',
#   'luck',
#   'would',
#   'use',
#   'mychart',
#   'get',
#   'covidvaccin',
#   'appoint',
#   'next',
#   'week',
#   'togetheroh',
#   'faltuseugen',
#   'keepcancrclassi',
#   'drandrewalbert',
#   'dmgraymd',
#   'gyrig',
#   'johnwmccarthi'],
#  ['day',
#   'second',
#   'pfizer',
#   'shot',
#   'arm',
#   'sore',
#   'littl',
#   'headach',
#   'im',
#   'also',
#   'tire',
#   'becaus',
#   'didnt',
#   'sleep',
#   'great',
#   'last',
#   'night',
#   'arm',
#   'sleeper',
#   'ive',
#   'wors',
#   'wa',
#   'total',
#   'worth',
#   'vaccin'],
#  ['rebeccapalsha', 'total', 'know', 'mean', 'vaccin'],
#  ['couldnt',
#   'happi',
#   'announc',
#   'receiv',
#   'first',
#   'dose',
#   'pfizer',
#   'vaccin',
#   'today',
#   'painless',
#   'easi',
#   'relief',
#   'vaccin',
#   'inthistogeth',
#   'thisisourshot'],
#  ['spot',
#   'statement',
#   'bbcnewsnight',
#   'good',
#   'hear',
#   'calm',
#   'consid',
#   'defens',
#   'uk',
#   'govern',
#   'support',
#   'vaccin',
#   'rollout',
#   'countri',
#   'highlight',
#   'challeng',
#   'pose',
#   'careless',
#   'statement',
#   'vaccin',
#   'safeti',
#   'eu',
#   'covidvaccin'],
#  ['grate',
#   'swiss',
#   'aunt',
#   'amp',
#   'uncl',
#   'see',
#   'child',
#   'amp',
#   'grandchild',
#   'long',
#   'month',
#   'vaccin',
#   'vaccineforal'],
#  ['know',
#   'know',
#   'hate',
#   'needl',
#   'alway',
#   'dread',
#   'get',
#   'shot',
#   'never',
#   'happier',
#   'one',
#   'tonight',
#   'within',
#   'hour',
#   'im',
#   'get',
#   'covidvaccin',
#   'actual',
#   'look',
#   'forward',
#   'thi',
#   'week',
#   'elig',
#   'get',
#   'vaccin'],
#  ['covidvaccin',
#   'pleas',
#   'check',
#   'friend',
#   'arent',
#   'comfort',
#   'internet',
#   'see',
#   'need',
#   'help',
#   'take',
#   'home',
#   'messag',
#   'gp',
#   'get',
#   'vaccin',
#   'small',
#   'batch',
#   'take',
#   'vaccin',
#   'everyon',
#   'elig'],
#  ['retweet',
#   'agre',
#   'moderna',
#   'modernavaccin',
#   'pfizer',
#   'pfizervaccin',
#   'pfizercovidvaccin',
#   'vaccin',
#   'covidvaccin',
#   'covidvaccinesideeffect',
#   'mandatoryvaccin',
#   'vaccinedeath',
#   'vaccineinjuri',
#   'genocid',
#   'depopul',
#   'mandatoryvaccin',
#   'vaccinepassport',
#   'transhuman',
#   'vaccin'],
#  ['got', 'vaccin', 'astrazenecavaccin', 'vaccin'],
#  ['thing',
#   'today',
#   'didnt',
#   'feel',
#   'thing',
#   'tho',
#   'despit',
#   'look',
#   'manskin',
#   'vaccin',
#   'vaccin',
#   'vaccinationdon'],
#  ['thing',
#   'today',
#   'didnt',
#   'feel',
#   'thing',
#   'tho',
#   'despit',
#   'look',
#   'manskin',
#   'vaccin',
#   'vaccin',
#   'vaccinationdon'],
#  ['got',
#   'sign',
#   'second',
#   'dose',
#   'motherfuck',
#   'hell',
#   'yeah',
#   'covidvaccin'],
#  ['let',
#   'forget',
#   'dollyparton',
#   'gave',
#   'money',
#   'covidvaccin',
#   'research',
#   'feder',
#   'govern',
#   'trump',
#   'bless',
#   'u',
#   'vaccin',
#   'theme',
#   'jolen',
#   'remix',
#   'thanktrumpfornoth',
#   'httpstcobulrnmulix'],
#  ['bluecheck',
#   'lib',
#   'rethuglican',
#   'vote',
#   'violenc',
#   'woman',
#   'act',
#   'also',
#   'bluecheck',
#   'lib',
#   'let',
#   'pa',
#   'equal',
#   'act',
#   'destroy',
#   'woman',
#   'sport',
#   'allow',
#   'grown',
#   'men',
#   'potti',
#   'alongsid',
#   'littl',
#   'girl',
#   'biden',
#   'covidvaccin',
#   'violenceagainstwomen'],
#  ['atsrazenica',
#   'uk',
#   'domest',
#   'suppli',
#   'chain',
#   'experienc',
#   'ani',
#   'disrupt',
#   'impact',
#   'deliveri',
#   'schedul',
#   'suppli',
#   'problem',
#   'thenso',
#   'govern',
#   'call',
#   'halt',
#   'due',
#   'issu',
#   'highlight',
#   'countri',
#   'covidvaccin'],
#  ['china',
#   'brazil',
#   'covidvaccin',
#   'diplomaci',
#   'trevorsutton',
#   'tell',
#   'voanew',
#   'ha',
#   'concert',
#   'campaign',
#   'le',
#   'develop',
#   'countri',
#   'obtain',
#   'waiver',
#   'world',
#   'trade',
#   'organ',
#   'around',
#   'intellectu',
#   'properti',
#   'begin',
#   'produc',
#   'vaccin',
#   'themselv'],
#  ['skynew',
#   'ive',
#   'vaccin',
#   'week',
#   'right',
#   'rain',
#   'thi',
#   'bullshit',
#   'amp',
#   'bollock',
#   'take',
#   'vaccin',
#   'stop',
#   'fcking',
#   'moan',
#   'whine',
#   'ppl',
#   'make',
#   'sick',
#   'fuck',
#   'sad',
#   'fantasist',
#   'covidvaccin'],
#  ['clinic',
#   'secur',
#   'guard',
#   'werent',
#   'paid',
#   'compani',
#   'week',
#   'arm',
#   'guard',
#   'covid',
#   'site',
#   'havent',
#   'paid',
#   'week'],
#  ['elig',
#   'ny',
#   'resid',
#   'age',
#   'older',
#   'publicfac',
#   'govern',
#   'amp',
#   'public',
#   'employe',
#   'notforprofit',
#   'worker',
#   'provid',
#   'publicfac',
#   'servic',
#   'neediest',
#   'essenti',
#   'inperson',
#   'publicfac',
#   'build',
#   'servic',
#   'worker',
#   'worker',
#   'construct',
#   'site'],
#  ['dont',
#   'test',
#   'luck',
#   'turn',
#   'get',
#   'sign',
#   'san',
#   'mateo',
#   'counti',
#   'vaccin',
#   'updat',
#   'httpstcojderjmxffb',
#   'notifi',
#   'elig',
#   'vaccin',
#   'state',
#   'myturn',
#   'system',
#   'httpstcoasgyosggej'],
#  ['okay',
#   'hour',
#   'later',
#   'im',
#   'feel',
#   'wreck',
#   'chill',
#   'dure',
#   'sleep',
#   'last',
#   'night',
#   'feel',
#   'pretti',
#   'achi',
#   'tire',
#   'cours',
#   'call',
#   'sick',
#   'think',
#   'stay',
#   'bed',
#   'johnsonandjohnsonvaccin',
#   'covidvaccin'],
#  ['rowanramseymp',
#   'thi',
#   'live',
#   'mid',
#   'north',
#   'town',
#   'high',
#   'popul',
#   'elderli',
#   'folk',
#   'mani',
#   'drive',
#   'htf',
#   'suppos',
#   'deal',
#   'thi',
#   'shame',
#   'covidvaccin',
#   'p',
#   'want',
#   'write',
#   'rowan',
#   'get',
#   'angri'],
#  ['doe',
#   'thi',
#   'vindic',
#   'decis',
#   'get',
#   'covidvaccin',
#   'mani',
#   'peopl',
#   'possibl',
#   'quickli',
#   'possibl',
#   'least',
#   'protect',
#   'risk',
#   'group',
#   'alreadi',
#   'remark',
#   'rollout',
#   'thu',
#   'far',
#   'sandrakanth'],
#  ['cross',
#   'border',
#   'illeg',
#   'worri',
#   'covidvaccin',
#   'test',
#   'need',
#   'liberalismistherealpandem'],
#  ['first',
#   'covid',
#   'vaccin',
#   'today',
#   'minut',
#   'omlif',
#   'standard',
#   'needl',
#   'normal',
#   'tini',
#   'pinch',
#   'unnecessari',
#   'bandaid',
#   'side',
#   'effect',
#   'yet',
#   'ill',
#   'keep',
#   'bird',
#   'app',
#   'appris',
#   'chang',
#   'go',
#   'back',
#   'week',
#   'dose',
#   'moderna',
#   'covidvaccin',
#   'vaccin'],
#  ['pleas',
#   'got',
#   'covid',
#   'jab',
#   'appt',
#   'next',
#   'tuesday',
#   'covidvaccin',
#   'wecanbeatthi'],
#  ['got',
#   'fauciouchi',
#   'today',
#   'vaccin',
#   'getvaccin',
#   'covidvaccin',
#   'pfizercovidvaccin',
#   'cvspharmacyvaccin'],
#  ['let', 'break', 'record', 'hour', 'getvaccin', 'hope'],
#  ['join',
#   'u',
#   'great',
#   'covidvaccin',
#   'talk',
#   'bcbsla',
#   'getthefactsgetthevax'],
#  ['huzzah', 'first', 'jab', 'done', 'vaccin'],
#  ['neurologist',
#   'approv',
#   'pfizer',
#   'covid',
#   'vaccin',
#   'amp',
#   'wrote',
#   'doctor',
#   'note',
#   'need',
#   'amp',
#   'state',
#   'ct',
#   'take',
#   'underli',
#   'medic',
#   'condit',
#   'vaccin',
#   'group',
#   'ct',
#   'method',
#   'solv',
#   'vaccin',
#   'shortag',
#   'cut',
#   'group',
#   'need',
#   'covidvaccin'],
#  ['yr',
#   'ago',
#   'disney',
#   'spring',
#   'befor',
#   'surpris',
#   'intro',
#   'joshgad',
#   'see',
#   'beauti',
#   'beast',
#   'v',
#   'today',
#   'ak',
#   'celebr',
#   'lincoln',
#   'birthday',
#   'littl',
#   'earli',
#   'st',
#   'patrick',
#   'day',
#   'precovid',
#   'rainbowbabi',
#   'vaccin',
#   'happystpatricksday'],
#  ['thought',
#   'death',
#   'matter',
#   'caus',
#   'occur',
#   'someon',
#   'ha',
#   'vaccin',
#   'record',
#   'due',
#   'towith',
#   'covid',
#   'covidvaccin',
#   'logic',
#   'covid',
#   'death',
#   'record'],
#  ['normanswan',
#   'dont',
#   'promis',
#   'cant',
#   'deliv',
#   'dont',
#   'put',
#   'roll',
#   'hand',
#   'privat',
#   'liber',
#   'donor',
#   'use',
#   'state',
#   'public',
#   'health',
#   'council',
#   'mass',
#   'immunis',
#   'suppli',
#   'gp',
#   'covidvaccin',
#   'per',
#   'fortnight',
#   'pay',
#   'appropri',
#   'racgppresid',
#   'amapresid'],
#  ['f',
#   'n',
#   'l',
#   'l',
#   'actual',
#   'go',
#   'ive',
#   'vaccin',
#   'disneyland',
#   'im',
#   'come',
#   'httpstcodudyschcqd'],
#  ['food',
#   'groceri',
#   'worker',
#   'resid',
#   'older',
#   'elig',
#   'vaccin',
#   'next',
#   'week',
#   'httpstcomxbjrhejeq',
#   'massgov',
#   'massdph',
#   'covidvaccin',
#   'stopthespread',
#   'maskupma'],
#  ['give',
#   'thi',
#   'unequit',
#   'system',
#   'vaccin',
#   'florida',
#   'respons',
#   'time',
#   'frame',
#   'end',
#   'time',
#   'accept',
#   'messag',
#   'respons',
#   'ha',
#   'end',
#   'thi',
#   'notif',
#   'thank',
#   'respond',
#   'everbridg',
#   'covidvaccin',
#   'vaccineequ',
#   'manateegov'],
#  ['natur',
#   'nervou',
#   'covidvaccin',
#   'make',
#   'sure',
#   'know',
#   'fact',
#   'dont',
#   'listen',
#   'conspiraci',
#   'theori',
#   'thi',
#   'vaccin',
#   'safe',
#   'best',
#   'chanc',
#   'cancelcovid',
#   'learn',
#   'healingstartsher',
#   'httpstcoxonmqnofnm'],
#  ['kerncounti',
#   'find',
#   'elig',
#   'vaccin',
#   'schedul',
#   'appoint',
#   'today',
#   'covidvaccin',
#   'vaccin',
#   'wearamask'],
#  ['unpopular',
#   'opinion',
#   'nobodi',
#   'want',
#   'see',
#   'vaccin',
#   'card',
#   'covidvaccin'],
#  ['fab', 'comment', 'facebook', 'covidvaccin'],
#  ['rnao',
#   'dorisgrinspun',
#   'pamelafellbaum',
#   'gmbutt',
#   'covidzerocanada',
#   'ctvottawa',
#   'cbcalert',
#   'salthorn',
#   'picardonhealth',
#   'sunnurs',
#   'cfnu',
#   'cbcthenat',
#   'justintrudeau',
#   'fordnat',
#   'celliott',
#   'ctvnew',
#   'colindmello',
#   'julieireton',
#   'cbccanada',
#   'cbcwhitecoat',
#   'thecurrentcbc',
#   'vassykapelo',
#   'would',
#   'requir',
#   'leadership',
#   'lhinsohsadli',
#   'obsess',
#   'chang',
#   'thier',
#   'name',
#   'againoh',
#   'name',
#   'chang',
#   'doe',
#   'equal',
#   'transform',
#   'covidvaccin',
#   'homecar',
#   'whoareyounow'],
#  ['massachusett',
#   'aim',
#   'fulli',
#   'open',
#   'vaccin',
#   'elig',
#   'april',
#   'massgov',
#   'massdph',
#   'massgovernor',
#   'covidvaccin'],
#  ['gt',
#   'design',
#   'avail',
#   'tshirt',
#   'shirt',
#   'gift',
#   'idea',
#   'fashion',
#   'tshirtdesign',
#   'vaccin',
#   'coronavirusvaccin',
#   'coronaviru',
#   'corona',
#   'giftidea',
#   'viru',
#   'vaccinoanticovid',
#   'vaccin',
#   'design',
#   'giftidea',
#   'health',
#   'prevent',
#   'vaccin'],
#  ['want',
#   'know',
#   'youll',
#   'elig',
#   'get',
#   'covidvaccin',
#   'call',
#   'hospitalth',
#   'go',
#   'would',
#   'go',
#   'log',
#   'user',
#   'account',
#   'inform',
#   'happen',
#   'base',
#   'short',
#   'questionnair'],
#  ['need',
#   'best',
#   'promot',
#   'market',
#   'ebook',
#   'amazon',
#   'kindl',
#   'book',
#   'promot',
#   'activ',
#   'reader',
#   'contact',
#   'thi',
#   'vendor',
#   'chelseaatleti',
#   'mendi',
#   'cash',
#   'tommyrobinson',
#   'uel',
#   'ucl',
#   'guin',
#   'aafialifeisindang',
#   'covidvaccin',
#   'stopasianh'],
#  ['go',
#   'lie',
#   'feel',
#   'like',
#   'pin',
#   'needl',
#   'constantli',
#   'arm',
#   'vaccin',
#   'feel',
#   'like',
#   'ive',
#   'shit',
#   'kick',
#   'astrazeneca',
#   'covidvaccin'],
#  ['ha',
#   'ever',
#   'polit',
#   'vindic',
#   'swift',
#   'true',
#   'predict',
#   'brexit',
#   'wake',
#   'murder',
#   'warmong',
#   'shenanigan',
#   'eu',
#   'ever',
#   'disgust',
#   'vaccin',
#   'polici',
#   'covidvaccin',
#   'vonderleyen'],
#  ['economi',
#   'recov',
#   'canada',
#   'alberta',
#   'covidvaccin',
#   'endthelockdown',
#   'greatreset',
#   'econom',
#   'bitcoin',
#   'jkenney',
#   'rachelnotley',
#   'ezralev',
#   'maximeberni',
#   'paulhinmanwipa',
#   'erinotool',
#   'randyhilli'],
#  ['ive',
#   'talk',
#   'veteran',
#   'friend',
#   'covid',
#   'vaccin',
#   'coupl',
#   'thing',
#   'emerg',
#   'vet',
#   'ive',
#   'talk',
#   'want',
#   'get',
#   'vaccin',
#   'asap',
#   'one',
#   'get',
#   'vaccin',
#   'deptvetaffair',
#   'weve',
#   'come',
#   'expect',
#   'spectacularli',
#   'screw'],
#  ['lot',
#   'money',
#   'develop',
#   'vaccin',
#   'wa',
#   'actual',
#   'public',
#   'money',
#   'wasnt',
#   'privat',
#   'money',
#   'increas',
#   'moral',
#   'case',
#   'ip',
#   'waiv',
#   'public',
#   'good',
#   'said',
#   'baum',
#   'auspol',
#   'png',
#   'covidvaccin'],
#  ['dear',
#   'gavinnewsom',
#   'want',
#   'birthday',
#   'chanc',
#   'doe',
#   'meet',
#   'ani',
#   'current',
#   'qualif',
#   'get',
#   'befor',
#   'april'],
#  ['wonder',
#   'see',
#   'babbington',
#   'hospit',
#   'belper',
#   'get',
#   'recognit',
#   'deserv',
#   'simonharebbc',
#   'packag',
#   'bbcemt',
#   'covidvaccin',
#   'see',
#   'certain',
#   'belpertownfc',
#   'chairman',
#   'tele',
#   'box'],
#  ['thi',
#   'vaccin',
#   'passport',
#   'go',
#   'work',
#   'u',
#   'old',
#   'biddi',
#   'go',
#   'holiday',
#   'beach',
#   'majorca',
#   'young',
#   'peopl',
#   'stuck',
#   'blackpool',
#   'covidvaccin',
#   'covidpassport'],
#  ['ha',
#   'covidvaccin',
#   'caus',
#   'zombieapocalyps',
#   'yet',
#   'stop',
#   'buy',
#   'glove',
#   'mask',
#   'amp',
#   'alcohol',
#   'spray',
#   'start',
#   'buy',
#   'crossbow',
#   'katana',
#   'amp',
#   'ammonia'],
#  ['final', 'figur', 'damn', 'card', 'freak', 'covidvaccin', 'bigbroth'],
#  ['thi',
#   'afternoon',
#   'got',
#   'covidvaccin',
#   'shot',
#   'thank',
#   'ucsdhealth',
#   'get',
#   'shot',
#   'arm',
#   'vaccin'],
#  ['china', 'allow', 'foreign', 'theyv', 'chines', 'vaccinepassport'],
#  ['updat', 'throw', 'go', 'wrong', 'kroger', 'got', 'vaccin', 'covidvaccin'],
#  ['seem',
#   'head',
#   'anoth',
#   'wave',
#   'lockdown',
#   'mayb',
#   'thi',
#   'time',
#   'fordnat',
#   'announc',
#   'wont',
#   'lift',
#   'case',
#   'drop',
#   'zero',
#   'way',
#   'mayb',
#   'save',
#   'summer',
#   'ontpoli',
#   'onpoli',
#   'covidvaccin'],
#  ['one',
#   'shot',
#   'one',
#   'go',
#   'let',
#   'get',
#   'thi',
#   'sacrif',
#   'dure',
#   'thi',
#   'pandem',
#   'least',
#   'could',
#   'honor',
#   'sacrific',
#   'covid',
#   'vaccin',
#   'vaccin',
#   'vaccinessavel',
#   'vaccineswork'],
#  ['kyri',
#   'eleison',
#   'lord',
#   'merci',
#   'christ',
#   'eleison',
#   'christ',
#   'merci',
#   'kyri',
#   'eleison',
#   'lord',
#   'merci',
#   'kyri',
#   'eleison',
#   'centuri',
#   'pray',
#   'tansania',
#   'brasil',
#   'atlanta',
#   'iceland',
#   'earthquak',
#   'itali',
#   'franc',
#   'covidvaccin',
#   'usa',
#   'homeless',
#   'woman',
#   'asianlivesmatt',
#   'jesu',
#   'love',
#   'peac'],
#  ['watch',
#   'thi',
#   'video',
#   'post',
#   'comment',
#   'within',
#   'sec',
#   'got',
#   'notif',
#   'comment',
#   'remov',
#   'hate',
#   'speech',
#   'symbol',
#   'none',
#   'wa',
#   'seem',
#   'even',
#   'gener',
#   'statement',
#   'post',
#   'covid',
#   'allow',
#   'covidvaccin'],
#  ['day', 'life', 'drama', 'queen', 'fulli', 'vaccin'],
#  ['covid',
#   'real',
#   'vaccin',
#   'safe',
#   'say',
#   'honor',
#   'wirba',
#   'cameroon',
#   'former',
#   'vib',
#   'rant',
#   'member',
#   'parliament',
#   'ha',
#   'advic',
#   'southerncameroonian',
#   'keep',
#   'themselv',
#   'safe',
#   'take',
#   'vaccin',
#   'covidvaccin'],
#  ['first',
#   'shot',
#   'thi',
#   'morn',
#   'second',
#   'one',
#   'thi',
#   'afternoon',
#   'covidvaccin',
#   'wednesdaywisdom'],
#  ['onli',
#   'rare',
#   'opportun',
#   'particip',
#   'molecular',
#   'happen',
#   'thank',
#   'scienc',
#   'current',
#   'danc',
#   'parti',
#   'go',
#   'insid',
#   'cell',
#   'vaccin'],
#  ['guess',
#   'wear',
#   'gold',
#   'sequin',
#   'onesi',
#   'kermi',
#   'pin',
#   'amp',
#   'one',
#   'helluva',
#   'pziday',
#   'shot',
#   'one',
#   'vaccin'],
#  ['diaperdon',
#   'call',
#   'hoax',
#   'mock',
#   'drfauci',
#   'threw',
#   'hi',
#   'follow',
#   'bu',
#   'got',
#   'covidvaccin',
#   'thi',
#   'republicansnowflak',
#   'need',
#   'wake',
#   'chicago',
#   'trumpfamilycrim',
#   'covid',
#   'payattent'],
#  ['european',
#   'union',
#   'go',
#   'stop',
#   'export',
#   'vaccin',
#   'unless',
#   'receiv',
#   'countri',
#   'outsid',
#   'eu',
#   'suppli',
#   'astrazenecavaccin',
#   'refus',
#   'use',
#   'thank',
#   'god',
#   'brexitr',
#   'vaccin',
#   'covidvaccin'],
#  ['sign',
#   'get',
#   'covid',
#   'vaccin',
#   'thi',
#   'week',
#   'glad',
#   'thi',
#   'wa',
#   'googl',
#   'effect',
#   'newhousemvj',
#   'covidvaccin'],
#  ['anti',
#   'vaxxer',
#   'reel',
#   'anticovidvaccin',
#   'b',
#   'use',
#   'random',
#   'websit',
#   'amp',
#   'youtub',
#   'video',
#   'mate',
#   'difficult',
#   'seek',
#   'peerreview',
#   'scientif',
#   'sourcesdata',
#   'ration',
#   'mind',
#   'weigh',
#   'pro',
#   'con',
#   'respons',
#   'adult'],
#  ['merck', 'scrap', 'covidvaccin', 'say', 'effect', 'catch', 'recov'],
#  ['reveal',
#   'plan',
#   'digit',
#   'green',
#   'pa',
#   'allow',
#   'vaccin',
#   'peopl',
#   'travel',
#   'freeli',
#   'across',
#   'bloc',
#   'meanwhil',
#   'china',
#   'foreign',
#   'citizen',
#   'allow',
#   'enter',
#   'countri',
#   'theyv',
#   'receiv',
#   'vaccin',
#   'ha',
#   'vaccin'],
#  ['anoth',
#   'total',
#   'eff',
#   'brought',
#   'greghuntmp',
#   'scottmorrisonmp',
#   'covidvaccin',
#   'auspol'],
#  ['pleas',
#   'stop',
#   'go',
#   'covidvaccin',
#   'ye',
#   'pandem',
#   'wa',
#   'terribl',
#   'world',
#   'far',
#   'wors',
#   'sick',
#   'death',
#   'constant',
#   'doom',
#   'gloom',
#   'surround',
#   'time',
#   'move',
#   'moveon',
#   'vaccin',
#   'least',
#   'one'],
#  ['thenamedicin',
#   'publichealth',
#   'got',
#   'first',
#   'dose',
#   'moderna',
#   'today',
#   'amp',
#   'moon',
#   'covidvaccin'],
#  ['mean',
#   'im',
#   'gon',
#   'na',
#   'moan',
#   'complain',
#   'amaz',
#   'nh',
#   'aint',
#   'near',
#   'ill',
#   'wait',
#   'ta',
#   'covidvaccin'],
#  ['partner',
#   'medium',
#   'outlet',
#   'trust',
#   'refuge',
#   'immigr',
#   'migrant',
#   'commun',
#   'dissemin',
#   'culturallytailor',
#   'vaccin',
#   'messag',
#   'address',
#   'uniqu',
#   'concern',
#   'learn',
#   'covidvaccin'],
#  ['covidvaccin',
#   'covidvaccinefirstdos',
#   'lasvega',
#   'govsisolak',
#   'got',
#   'mine',
#   'done',
#   'bo'],
#  ['thank',
#   'newpghcouri',
#   'host',
#   'great',
#   'convers',
#   'thi',
#   'even',
#   'covidvaccin',
#   'dispel',
#   'myth',
#   'address',
#   'anxietyconcern',
#   'dispar',
#   'impact',
#   'black',
#   'brown',
#   'commun',
#   'pa',
#   'michelewpxi',
#   'abettergateway',
#   'ahntoday',
#   'upmc',
#   'aarppa',
#   'ekanewilliam'],
#  ['like', 'covidvaccin'],
#  ['motherdaught',
#   'got',
#   'pfizer',
#   'covidvaccin',
#   'today',
#   'getvaccin',
#   'wearamask',
#   'coveryournos'],
#  ['ashland',
#   'tweep',
#   'kdmh',
#   'ha',
#   'surplu',
#   'vaccin',
#   'pretti',
#   'much',
#   'give',
#   'anyon',
#   'walk',
#   'door',
#   'anyon',
#   'know',
#   'want',
#   'vaccin',
#   'thi',
#   'shot',
#   'pun',
#   'intend',
#   'also',
#   'check',
#   'elder',
#   'peopl',
#   'may',
#   'need',
#   'help',
#   'get',
#   'kdmh',
#   'covidvaccin'],
#  ['philippin',
#   'presid',
#   'rodrigo',
#   'dutert',
#   'ha',
#   'order',
#   'border',
#   'close',
#   'foreign',
# ...
#  ['first',
#   'covidvaccin',
#   'today',
#   'im',
#   'observ',
#   'ehlersdanlossyndrom',
#   'mca',
#   'mean',
#   'minut',
#   'allergi',
#   'med',
#   'hand',
#   'case',
#   'thank',
#   'abl',
#   'get',
#   'readi',
#   'day',
#   'come'],
#  ['check',
#   'dad',
#   'happili',
#   'wait',
#   'hi',
#   'vaccin',
#   'thank',
#   'setorontofht',
#   'scienc',
#   'covidvaccin'],
#  ['got',
#   'vaccin',
#   'thank',
#   'presid',
#   'trump',
#   'thank',
#   'good',
#   'politician',
#   'wasnt',
#   'charg',
#   'last',
#   'year',
#   'vaccin',
#   'vaccin',
#   'operationwarpspe'],
#  ['wa',
#   'dure',
#   'spanish',
#   'flu',
#   'oldest',
#   'person',
#   'vaccin',
#   'meet',
#   'kewal',
#   'krishan',
#   'went',
#   'first',
#   'time',
#   'sinc',
#   'coronavirusinduc',
#   'lockdown',
#   'get',
#   'hi',
#   'covidvaccin',
#   'jab',
#   'indiafightscorona'],
#  ['thi',
#   'ha',
#   'onli',
#   'time',
#   'ive',
#   'left',
#   'harlequin',
#   'stoop',
#   'sober',
#   'plu',
#   'side',
#   'left',
#   'vaccin',
#   'covidvaccin',
#   'httpstcoaiplmhoqdi'],
#  ['senschum',
#   'nydiavelazquez',
#   'well',
#   'sinc',
#   'u',
#   'brought',
#   'puerto',
#   'rico',
#   'im',
#   'concern',
#   'get',
#   'enough',
#   'covidvaccin',
#   'could',
#   'u',
#   'speak',
#   'potu',
#   'whco',
#   'whcovidrespons',
#   'increas',
#   'get',
#   'weekli'],
#  ['ive',
#   'astra',
#   'zeneca',
#   'vaccin',
#   'im',
#   'proud',
#   'fk',
#   'covid',
#   'covidvaccin',
#   'astrazeneca',
#   'covidiot'],
#  ['mom',
#   'get',
#   'covidvaccin',
#   'tuesday',
#   'think',
#   'cri',
#   'like',
#   'charlenebsid'],
#  ['partner',
#   'vaccin',
#   'right',
#   'might',
#   'sexiest',
#   'thing',
#   'ha',
#   'happen',
#   'year',
#   'truestori',
#   'vaccin'],
#  ['got',
#   'second',
#   'covid',
#   'shot',
#   'today',
#   'hope',
#   'side',
#   'effect',
#   'arent',
#   'bad',
#   'like',
#   'last',
#   'time',
#   'covidvaccin'],
#  ['mani',
#   'state',
#   'use',
#   'disadvantag',
#   'index',
#   'promot',
#   'covidvaccin',
#   'healthequ',
#   'new',
#   'studi',
#   'w',
#   'amaz',
#   'lawrencegostin',
#   'harvardchandean',
#   'abuttenheim',
#   'angelakshen',
#   'state',
#   'data',
#   'guru',
#   'kate',
#   'miller',
#   'viz'],
#  ['covidvaccin',
#   'domin',
#   'cum',
#   'went',
#   'barnard',
#   'castl',
#   'wa',
#   'hoo',
#   'haa',
#   'news',
#   'glaxosmithklin',
#   'announc',
#   'look',
#   'produc',
#   'next',
#   'gener',
#   'covidvaccin',
#   'good',
#   'job',
#   'theyr',
#   'offic',
#   'barnard',
#   'castl',
#   'httpstcovvcubdgjlc'],
#  ['got',
#   'new',
#   'monitor',
#   'chip',
#   'ask',
#   'shove',
#   'covid',
#   'vaccin',
#   'needl',
#   'wa',
#   'anyway',
#   'vaccin'],
#  ['get',
#   'covid',
#   'vaccin',
#   'wan',
#   'na',
#   'go',
#   'around',
#   'hug',
#   'random',
#   'stranger',
#   'coronaviru',
#   'coronavirusupd',
#   'covidvaccin',
#   'hugm',
#   'letshug'],
#  ['yall',
#   'im',
#   'line',
#   'get',
#   'covidvaccin',
#   'right',
#   'serious',
#   'alreadi',
#   'cri',
#   'happi',
#   'tear',
#   'sleevesupla'],
#  ['woohoo',
#   'seashantysong',
#   'thisisourshot',
#   'vaccineswork',
#   'vaccinessavel',
#   'thisisourshot',
#   'gretchenlasal',
#   'davidepsteinmd',
#   'httpstcopopzdmkloa'],
#  ['wa',
#   'dure',
#   'spanish',
#   'flu',
#   'oldest',
#   'person',
#   'vaccin',
#   'meet',
#   'kewal',
#   'krishan',
#   'went',
#   'first',
#   'time',
#   'sinc',
#   'coronavirusinduc',
#   'lockdown',
#   'get',
#   'hi',
#   'covidvaccin',
#   'jab'],
#  ['benefit',
#   'coronaviru',
#   'vaccin',
#   'risk',
#   'nafdac',
#   'reveal',
#   'corona',
#   'covidvaccin'],
#  ['ani',
#   'question',
#   'vaccin',
#   'gener',
#   'concern',
#   'allergi',
#   'underli',
#   'medic',
#   'condit',
#   'pleas',
#   'reach',
#   'local',
#   'healthcar',
#   'provid',
#   'covidvaccin',
#   'stayinformedstaysaf'],
#  ['pleas',
#   'note',
#   'vaccin',
#   'approv',
#   'canada',
#   'gone',
#   'rigor',
#   'test',
#   'amp',
#   'applic',
#   'process',
#   'also',
#   'import',
#   'know',
#   'compar',
#   'data',
#   'vaccin',
#   'complic',
#   'sinc',
#   'underw',
#   'differ',
#   'research',
#   'methodolog',
#   'dure',
#   'clinic',
#   'trial',
#   'covidvaccin'],
#  ['healthequitynu',
#   'chipublib',
#   'look',
#   'particip',
#   'interest',
#   'learn',
#   'clinicaltri',
#   'sign',
#   'live',
#   'virtual',
#   'session',
#   'learn',
#   'whi',
#   'divers',
#   'clinicaltri',
#   'import',
#   'thing',
#   'like',
#   'covidvaccin'],
#  ['new',
#   'product',
#   'alert',
#   'recombin',
#   'llama',
#   'vhh',
#   'nanobodi',
#   'studi',
#   'neutral',
#   'detect',
#   'spike',
#   'protein',
#   'visit',
#   'inform',
#   'biotechnolog'],
#  ['frustrat',
#   'tri',
#   'book',
#   'vaccin',
#   'amp',
#   'find',
#   'date',
#   'avail',
#   'calendar',
#   'till',
#   'jan',
#   'endscovidvaccin'],
#  ['bbcbreakfast',
#   'hell',
#   'doe',
#   'anyon',
#   'without',
#   'vaccin',
#   'affect',
#   'vaccin',
#   'protect',
#   'problem'],
#  ['stranger', 'doe', 'right', 'dad', 'pay', 'forward', 'covidvaccin'],
#  ['dad', 'got', 'hi', 'covidvaccin', 'thi', 'afternoon'],
#  ['ha', 'anyon', 'els', 'lost', 'sens', 'smell', 'get', 'covidvaccin'],
#  ['vaccin',
#   'administ',
#   'american',
#   'popul',
#   'fulli',
#   'vaccin',
#   'part',
#   'vaccin'],
#  ['yippe',
#   'got',
#   'vaccin',
#   'today',
#   'feel',
#   'great',
#   'happi',
#   'husband',
#   'hope',
#   'son',
#   'soon',
#   'feel',
#   'like',
#   'relief',
#   'grate',
#   'covidvaccin'],
#  ['doe',
#   'anyon',
#   'ani',
#   'reliabl',
#   'sourc',
#   'astrazeneca',
#   'ukbas',
#   'plant',
#   'product',
#   'level',
#   'covid',
#   'uk'],
#  ['talkradio',
#   'much',
#   'money',
#   'made',
#   'thi',
#   'pretenti',
#   'viru',
#   'covidvaccin'],
#  ['round', 'vaccin', 'done', 'covidvaccin'],
#  ['plan', 'disast', 'covidvaccinesideeffect', 'death', 'covidvaccin'],
#  ['onli',
#   'one',
#   'think',
#   'republican',
#   'antivaccin',
#   'moron',
#   'shouldnt',
#   'get',
#   'medic',
#   'treatment',
#   'get',
#   'covid',
#   'covidvaccin',
#   'httpstcoqhymqixmhd'],
#  ['julianhillmp',
#   'yeah',
#   'gave',
#   'manag',
#   'state',
#   'ha',
#   'gone',
#   'well',
#   'save',
#   'covidvaccin',
#   'distribut',
#   'like',
#   'trump',
#   'distribut',
#   'plan',
#   'find',
#   'scottyfrommarket',
#   'plan',
#   'doesnt',
#   'realli',
#   'exist',
#   'theyr',
#   'shoot',
#   'u',
#   'small',
#   'thing'],
#  ['watch',
#   'medium',
#   'report',
#   'satellit',
#   'tv',
#   'channel',
#   'httpstcodizmzvajrp',
#   'cover',
#   'commun',
#   'pop',
#   'vaccin',
#   'clinic',
#   'held',
#   'moss',
#   'st',
#   'youth',
#   'centr',
#   'kingsway',
#   'rochdal',
#   'total',
#   'resid',
#   'dose',
#   'covidvaccin',
#   'great',
#   'work',
#   'involv',
#   'togetherrochdal',
#   'httpstcobtaienttsb'],
#  ['covidvaccin',
#   'india',
#   'becaus',
#   'strong',
#   'experi',
#   'drug',
#   'vaccin',
#   'product',
#   'slate',
#   'becom',
#   'key',
#   'global',
#   'centr',
#   'fgodement',
#   'write',
#   'httpstcolzaeoofprn'],
#  ['mosconecent',
#   'impress',
#   'vaccin',
#   'oper',
#   'thank',
#   'matthaneysf',
#   'run',
#   'thi',
#   'site',
#   'min',
#   'londonbre',
#   'gavinnewsom',
#   'bayareaappt',
#   'covidvaccin'],
#  ['retweet',
#   'thi',
#   'messag',
#   'nurs',
#   'vaccin',
#   'covidvaccin',
#   'need',
#   'nurs',
#   'vaccin',
#   'champion',
#   'let',
#   'amplifi',
#   'voic'],
#  ['scottmorrisonmp',
#   'hi',
#   'bunch',
#   'clown',
#   'couldnt',
#   'organis',
#   'root',
#   'brothel',
#   'peopl',
#   'surpris',
#   'vaccin',
#   'roll',
#   'im',
#   'fail',
#   'auspol',
#   'scottmorrison',
#   'sloppyscotti',
#   'vaccin'],
#  ['pregnant',
#   'breastfeed',
#   'confus',
#   'inform',
#   'check',
#   'vaccin',
#   'fact',
#   'sheet'],
#  ['final',
#   'got',
#   'appoint',
#   'covidvaccin',
#   'one',
#   'toward',
#   'end',
#   'thi',
#   'month',
#   'earli',
#   'june'],
#  ['hello',
#   'friend',
#   'mom',
#   'still',
#   'bit',
#   'congest',
#   'wa',
#   'abl',
#   'get',
#   'first',
#   'covidvaccin',
#   'yesterday',
#   'daughter',
#   'better',
#   'well',
#   'take',
#   'time',
#   'im',
#   'reliev'],
#  ['japan',
#   'million',
#   'japanes',
#   'citizen',
#   'complet',
#   'vaccin',
#   'vaccin',
#   'rate',
#   'olymp',
#   'tokyoolymp',
#   'japanvari',
#   'vaccineswork'],
#  ['think',
#   'futur',
#   'peopl',
#   'regret',
#   'say',
#   'jab',
#   'wa',
#   'well',
#   'organis',
#   'didnt',
#   'feel',
#   'thing',
#   'perhap',
#   'autumnwint',
#   'thi',
#   'year',
#   'perhap',
#   'immun',
#   'system',
#   'attack',
#   'within',
#   'covidvaccin',
#   'vaccin',
#   'vaccin'],
#  ['thi',
#   'real',
#   'happen',
#   'maharashtra',
#   'good',
#   'vaccin',
#   'go',
#   'thi',
#   'trend',
#   'continu',
#   'covidvaccin'],
#  ['done',
#   'thank',
#   'everyon',
#   'novotellonwest',
#   'brilliant',
#   'experi',
#   'vaccin'],
#  ['richardzussman',
#   'japnaamsingh',
#   'mean',
#   'look',
#   'number',
#   'administ',
#   'bc',
#   'number',
#   'certainli',
#   'exceed',
#   'everi',
#   'provinc',
#   'except',
#   'quebec',
#   'amp',
#   'ontario',
#   'obvious',
#   'popul',
#   'receiv',
#   'suppli',
#   'bc',
#   'ha',
#   'elderli',
#   'ab',
#   'also',
#   'obvious'],
#  ['problem',
#   'put',
#   'top',
#   'queue',
#   'lockdown',
#   'covidvaccin',
#   'dublinprotest',
#   'stpatricksday'],
#  ['got',
#   'vaccin',
#   'today',
#   'phew',
#   'hope',
#   'get',
#   'soon',
#   'covidvaccin',
#   'jabtobeatcorona'],
#  ['vaccin', 'psn', 'follow', 'goal'],
#  ['part', 'return', 'world', 'travel', 'vaccin'],
#  ['excel',
#   'stuff',
#   'medtwitt',
#   'like',
#   'notic',
#   'petechia',
#   'follow',
#   'covidvaccin',
#   'administr',
#   'understand',
#   'subtleti',
#   'save',
#   'life'],
#  ['dawai',
#   'bhi',
#   'kadhai',
#   'bhi',
#   'adopt',
#   'newnorm',
#   'amp',
#   'follow',
#   'appropri',
#   'behaviour',
#   'stay',
#   'safe',
#   'amp',
#   'protect',
#   'viru',
#   'even',
#   'get',
#   'covidvaccin',
#   'take',
#   'pledg',
#   'today',
#   'httpstcovkzfkdocjz',
#   'indiafightscorona'],
#  ['wa',
#   'last',
#   'figur',
#   'hell',
#   'get',
#   'mask',
#   'feel',
#   'like',
#   'ill',
#   'last',
#   'figur',
#   'get',
#   'covidvaccin'],
#  ['telepolit',
#   'best',
#   'certif',
#   'piec',
#   'paper',
#   'rather',
#   'get',
#   'vaccin',
#   'paper',
#   'shuffler',
#   'whi',
#   'dont',
#   'bother',
#   'get',
#   'popul',
#   'vaccin',
#   'msm',
#   'come',
#   'guy',
#   'hold',
#   'thi',
#   'supran',
#   'state',
#   'account',
#   'behaviour',
#   'better',
#   'eu'],
#  ['great',
#   'quot',
#   'professor',
#   'van',
#   'tam',
#   'today',
#   'vaccin',
#   'dont',
#   'save',
#   'life',
#   'fridg',
#   'save',
#   'life',
#   'arm',
#   'vaccin',
#   'vaccin'],
#  ['stuart',
#   'robert',
#   'say',
#   'chang',
#   'made',
#   'team',
#   'respons',
#   'covidvaccin',
#   'rollout',
#   'best'],
#  ['wife',
#   'get',
#   'first',
#   'shot',
#   'pfizer',
#   'thi',
#   'saturday',
#   'scienc',
#   'fuck',
#   'amaz',
#   'cours',
#   'littl',
#   'nervou',
#   'covidvaccin',
#   'httpstcoihtkwmhzxu'],
#  ['million', 'peopl', 'day', 'phenomen', 'covidvaccin'],
#  ['got',
#   'first',
#   'shot',
#   'best',
#   'saint',
#   'patrick',
#   'day',
#   'ever',
#   'thank',
#   'presid',
#   'biden',
#   'cdc',
#   'sfcitywid',
#   'sanfrancisco',
#   'covidvaccin',
#   'stpatricksday',
#   'httpstconcoevmzuip'],
#  ['pleas',
#   'share',
#   'unit',
#   'uac',
#   'coalit',
#   'partner',
#   'state',
#   'host',
#   'vaccin',
#   'clinic',
#   'specif',
#   'target',
#   'agricultur',
#   'worker',
#   'regist',
#   'call',
#   'publichealthinstitut',
#   'togethertowardhealth',
#   'vaccinatecalifornia',
#   'covidvaccin',
#   'httpstcouasamudypp'],
#  ['go', 'vaccin'],
#  ['thi',
#   'quit',
#   'disturb',
#   'waikato',
#   'newzealand',
#   'get',
#   'covidvaccin',
#   'becaus',
#   'vaccin',
#   'base',
#   'centuri',
#   'scienc',
#   'skeptic',
#   'base',
#   'conspiratori',
#   'reckon',
#   'larg',
#   'discredit',
#   'gobshit'],
#  ['watch',
#   'infecti',
#   'diseas',
#   'expert',
#   'bakerchb',
#   'fellow',
#   'peterhotez',
#   'join',
#   'thedailyshow',
#   'discu',
#   'import',
#   'get',
#   'vaccin',
#   'debunk',
#   'common',
#   'vaccin',
#   'myth'],
#  ['check',
#   'updat',
#   'rcd',
#   'rollout',
#   'glanc',
#   'infograph',
#   'view',
#   'thi',
#   'great',
#   'resourc',
#   'visit',
#   'rcdhu',
#   'main',
#   'webpag',
#   'weareinthistogeth',
#   'vaccineswork',
#   'httpstcoxyvrzwkbei'],
#  ['timelin',
#   'vaccin',
#   'ha',
#   'implement',
#   'go',
#   'inform',
#   'covidvaccin',
#   'woburn'],
#  ['third',
#   'vaccin',
#   'clinic',
#   'open',
#   'middlesex',
#   'london',
#   'region',
#   'covidvaccin'],
#  ['today', 'great', 'day', 'shot', 'vaccin'],
#  ['power', 'kick', 'covidvaccin'],
#  ['dont',
#   'count',
#   'leadermcconnel',
#   'senategop',
#   'someth',
#   'product',
#   'countri',
#   'covidvaccin'],
#  ['vaccin',
#   'open',
#   'adult',
#   'march',
#   'import',
#   'get',
#   'group',
#   'get',
#   'shot',
#   'luca',
#   'co',
#   'number',
#   'mirror',
#   'ohio',
#   'thi',
#   'group',
#   'often',
#   'infect',
#   'mean',
#   'greater',
#   'opportun',
#   'spread',
#   'viru',
#   'covidvaccin',
#   'httpstcoykdflwjsnx'],
#  ['got', 'appoint', 'covidvaccin', 'im', 'excit'],
#  ['got', 'stuck', 'dose', 'done', 'vaccin'],
#  ['shot',
#   'moderna',
#   'vax',
#   'done',
#   'thank',
#   'potu',
#   'vp',
#   'compet',
#   'get',
#   'sht',
#   'done',
#   'covidvaccin',
#   'moderna',
#   'itrustsci'],
#  ['wish', 'knew', 'thi', 'last', 'month', 'covidvaccin'],
#  ['happi',
#   'year',
#   'home',
#   'today',
#   'day',
#   'left',
#   'offic',
#   'took',
#   'train',
#   'last',
#   'time',
#   'workingfromhom',
#   'ever',
#   'sinc',
#   'dont',
#   'miss',
#   'commut',
#   'mark',
#   'occas',
#   'receiv',
#   'text',
#   'invit',
#   'covidvaccin',
#   'jab',
#   'today'],
#  ['realli',
#   'fan',
#   'fat',
#   'peopl',
#   'get',
#   'vaccin',
#   'shot',
#   'befor',
#   'tbh',
#   'covidvaccin'],
#  ['tonight',
#   'updat',
#   'covidvaccin',
#   'invit',
#   'tomorrow',
#   'march',
#   'beliz',
#   'time',
#   'join',
#   'u',
#   'beliz',
#   'cme',
#   'jhidalgomd',
#   'vcantosl',
#   'paulinarebolledo',
#   'emoryinfectdi'],
#  ['thechurm',
#   'well',
#   'jel',
#   'today',
#   'news',
#   'wonder',
#   'ill',
#   'ever',
#   'get',
#   'mine',
#   'hey',
#   'maggiemizzi',
#   'vaccin',
#   'vazeg'],
#  ['uk',
#   'foreign',
#   'secretari',
#   'domin',
#   'raab',
#   'compar',
#   'eu',
#   'dictatorship',
#   'row',
#   'access',
#   'vaccin',
#   'escal',
#   'httpstcoomhrjbsfem',
#   'covidvaccin'],
#  ['kenklippenstein',
#   'govern',
#   'draft',
#   'everi',
#   'abl',
#   'man',
#   'woman',
#   'fight',
#   'extend',
#   'war',
#   'kill',
#   'ten',
#   'million',
#   'oversea',
#   'wont',
#   'tell',
#   'crybabi',
#   'take',
#   'two',
#   'shot',
#   'protect',
#   'popul',
#   'sound',
#   'bit',
#   'extrem',
#   'potu',
#   'vp',
#   'covidvaccin',
#   'life'],
#  ['eu',
#   'uk',
#   'dont',
#   'know',
#   'anyon',
#   'els',
#   'im',
#   'take',
#   'ani',
#   'news',
#   'uk',
#   'msm',
#   'pinch',
#   'salt',
#   'better',
#   'search',
#   'foreign',
#   'news',
#   'even',
#   'vagu',
#   'accur',
#   'news'],
#  ['hey',
#   'milwauke',
#   'know',
#   'start',
#   'monday',
#   'live',
#   'one',
#   'zip',
#   'code',
#   'youll',
#   'elig',
#   'fave',
#   'coproduc',
#   'kevschwa',
#   'come',
#   'vital',
#   'vaccin',
#   'info',
#   'graphic'],
#  ['guess',
#   'got',
#   'vaccin',
#   'virginiabeach',
#   'hope',
#   'lightattheendofthetunnel',
#   'maskupva',
#   'ralphnortham',
#   'joebiden',
#   'protectingmysonstheonlywayican'],
#  ['botswana', 'platform', 'regist', 'vaccin', 'open', 'httpstcooicrlesjij'],
#  ['icymi',
#   'granicu',
#   'blog',
#   'granicu',
#   'see',
#   'recordbreak',
#   'citizen',
#   'engag',
#   'dure',
#   'vaccin',
#   'rollout',
#   'govern',
#   'meet',
#   'unpreced',
#   'demand',
#   'civictech',
#   'govtech',
#   'stateandlocalgov',
#   'vaccinedistribut'],
#  ['hand',
#   'case',
#   'report',
#   'patient',
#   'hearingloss',
#   'becom',
#   'avail',
#   'small',
#   'grow',
#   'number',
#   'report',
#   'vaccin',
#   'individu',
#   'report',
#   'sudden',
#   'hear',
#   'loss'],
#  ['first',
#   'covid',
#   'vaccin',
#   'dose',
#   'mani',
#   'pharmaci',
#   'start',
#   'open',
#   'appoint',
#   'everyon',
#   'make',
#   'sure',
#   'jump',
#   'open',
#   'especi',
#   'part',
#   'prioriti',
#   'group',
#   'covidvaccin',
#   'httpstcoxxlaagprr'],
#  ['hand',
#   'god',
#   'guy',
#   'said',
#   'let',
#   'give',
#   'big',
#   'needl',
#   'got',
#   'front',
#   'line',
#   'covidvaccin'],
#  ['great',
#   'see',
#   'hazelmccallion',
#   'live',
#   'promot',
#   'peopl',
#   'get',
#   'vaccin',
#   'covidvaccin',
#   'httpstcohxixbmciem'],
#  ['mom',
#   'got',
#   'first',
#   'covidvaccin',
#   'idea',
#   'worri',
#   'wa',
#   'right',
#   'pandem',
#   'stress',
#   'real',
#   'sometim',
#   'silent',
#   'thing',
#   'take',
#   'time',
#   'take',
#   'care',
#   'yourselv'],
#  ['got',
#   'vaccin',
#   'feel',
#   'thank',
#   'san',
#   'diego',
#   'open',
#   'vaccin',
#   'highrisk',
#   'individu',
#   'covidvaccin'],
#  ['vaccin', 'vaccin', 'covidvaccin'],
#  ['feel',
#   'veri',
#   'lucki',
#   'gotten',
#   'first',
#   'dose',
#   'covidvaccin',
#   'today',
#   'shout',
#   'asburi',
#   'park',
#   'senior',
#   'center',
#   'vnacj',
#   'veri',
#   'smooth',
#   'process'],
#  ['im',
#   'book',
#   'friday',
#   'covidvaccin',
#   'mean',
#   'everyon',
#   'immedi',
#   'famili',
#   'two',
#   'frontlin',
#   'worker',
#   'oldi',
#   'underli',
#   'condit',
#   'first',
#   'dose',
#   'thanksnh',
#   'epilepsi'],
#  ['someon', 'call', 'want', 'know', 'wa', 'potato', 'covidvaccin'],
#  ...]

# %%
brand_keywords =['Covax','Vax','behalf_covax','Covishield','borisjohnson','johnson','johnsonandjohnson',
           'johnsonandjohnsonvaccine','moderna','modernavaccine','modernapfizer','teammoderna','pfizercovidvaccine',
           'pfizervaccine','pfizer']
text_data = []
for tweetSentence in text__data:
  
  sent = []
  for tweetWord in tweetSentence:
    if tweetWord in brand_keywords:
        sent.append(tweetWord)
       
  if sent:
    text_data.append(sent)

# %%
text_data[:10]
# Out:
# [['pfizer'],
#  ['pfizer'],
#  ['moderna'],
#  ['moderna'],
#  ['pfizer'],
#  ['moderna', 'moderna'],
#  ['moderna'],
#  ['pfizer'],
#  ['moderna'],
#  ['moderna']]

# %% [markdown]
# ### Make Bigrams for LDA Model

# %%
# Build the bigram models
bigram = gensim.models.Phrases(text_data, min_count=1) # higher threshold fewer phrases.

# Faster way to get a sentence clubbed as a bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)

text_data = [bigram_mod[doc] for doc in text_data]

# %%
text_data[:10]
# Out:
# [['pfizer'],
#  ['pfizer'],
#  ['moderna'],
#  ['moderna'],
#  ['pfizer'],
#  ['moderna', 'moderna'],
#  ['moderna'],
#  ['pfizer'],
#  ['moderna'],
#  ['moderna']]

# %% [markdown]
# # Build Dictionary

# %%
# make dictionary of complete corpus
dictionary_LDA = corpora.Dictionary(text_data)
# filter tokens below frequency of 3 words
dictionary_LDA.filter_extremes(no_below=3)
# index to words 
corpus = [dictionary_LDA.doc2bow(tok) for tok in text_data]

# %% [markdown]
# # Build LDA Model
# # Compute Coherence and Preplexity
# # Choose optimal number of topics

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    
    topics_list = [2, 4, 6, 8, 10, 12]
    coherence_values = []
    perplexity_val = []
    model_list = []
    for num_topics in topics_list:
        model = models.LdaModel(corpus, num_topics=num_topics, id2word=dictionary_LDA, passes=4, alpha=0.05, eta=[0.01]*len(dictionary_LDA.keys()))
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=text_data, dictionary=dictionary_LDA, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        perplexity_val.append(model.log_perplexity(corpus))

    return model_list, coherence_values, perplexity_val

# %% [markdown]
# # Train LDA Model

# %%
# Can take a long time to run.
model_list, coherence_values, perplexity_val = compute_coherence_values(dictionary=dictionary_LDA, corpus=corpus, texts=text_data, start=2, limit=40, step=6)

# %% [markdown]
# # Plot Coherence Scores

# %%
# Show graph
import matplotlib.pyplot as plt

topics_list = [2, 4, 6, 8, 10, 12]
plt.plot(topics_list, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %% [markdown]
# # Plot Perplexity Scores

# %%
# Show graph
import matplotlib.pyplot as plt

topics_list = [2, 4, 6, 8, 10, 12]
plt.plot(topics_list, perplexity_val)
plt.xlabel("Num Topics")
plt.ylabel("Perplexity score")
plt.legend(("perplexity_values"), loc='best')
plt.show()

# %% [markdown]
# ### Display Results

# %%
# Print the coherence scores
topics_list = [2, 4, 6, 8, 10, 12]
for m, cv, pr in zip(topics_list, coherence_values, perplexity_val):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4), " has Perplexity of", round(pr, 4))
# Out:
# Num Topics = 2  has Coherence Value of 0.3418  has Perplexity of -1.1428
# Num Topics = 4  has Coherence Value of 0.3418  has Perplexity of -1.5796
# Num Topics = 6  has Coherence Value of 0.3418  has Perplexity of -1.6948
# Num Topics = 8  has Coherence Value of 0.3418  has Perplexity of -1.9526
# Num Topics = 10  has Coherence Value of 0.3418  has Perplexity of -2.1374
# Num Topics = 12  has Coherence Value of 0.3418  has Perplexity of -2.3156

# %% [markdown]
# ## Train Model with Best number of topics

# %%
best_topic_number = 10
best_model = models.LdaModel(corpus, num_topics=best_topic_number, id2word=dictionary_LDA, passes=4, alpha=0.05, eta=[0.01]*len(dictionary_LDA.keys()))

# %%
coherencemodel = CoherenceModel(model=best_model, texts=text_data, dictionary=dictionary_LDA, coherence='c_v')
coherence_score = coherencemodel.get_coherence()
perplexity_score = best_model.log_perplexity(corpus)
print("Num Topics =", best_topic_number, " has Coherence Value of", round(coherence_score, 4), " has Perplexity of", round(perplexity_score, 4))
# Out:
# Num Topics = 10  has Coherence Value of 0.3418  has Perplexity of -2.1337

# %%
# display all topics with weight of all keywords
for i,topic in best_model.show_topics(formatted=True, num_topics=best_topic_number, num_words=20):
    print(str(i)+": "+ topic)
    print()
# Out:
# 0: 0.500*"johnson" + 0.500*"borisjohnson" + 0.000*"moderna" + 0.000*"johnsonandjohnson" + 0.000*"teammoderna"
#
# 1: 1.000*"johnson" + 0.000*"moderna" + 0.000*"johnsonandjohnson" + 0.000*"borisjohnson" + 0.000*"teammoderna"
#
# 2: 1.000*"moderna" + 0.000*"johnson" + 0.000*"johnsonandjohnson" + 0.000*"teammoderna" + 0.000*"borisjohnson"
#
# 3: 1.000*"johnson" + 0.000*"moderna" + 0.000*"borisjohnson" + 0.000*"johnsonandjohnson" + 0.000*"teammoderna"
#
# 4: 1.000*"moderna" + 0.000*"johnsonandjohnson" + 0.000*"johnson" + 0.000*"teammoderna" + 0.000*"borisjohnson"
#
# 5: 0.664*"johnson" + 0.335*"moderna" + 0.000*"teammoderna" + 0.000*"borisjohnson" + 0.000*"johnsonandjohnson"
#
# 6: 0.998*"teammoderna" + 0.001*"moderna" + 0.001*"johnson" + 0.000*"borisjohnson" + 0.000*"johnsonandjohnson"
#
# 7: 1.000*"borisjohnson" + 0.000*"johnson" + 0.000*"johnsonandjohnson" + 0.000*"moderna" + 0.000*"teammoderna"
#
# 8: 1.000*"moderna" + 0.000*"teammoderna" + 0.000*"johnsonandjohnson" + 0.000*"johnson" + 0.000*"borisjohnson"
#
# 9: 1.000*"johnsonandjohnson" + 0.000*"johnson" + 0.000*"moderna" + 0.000*"borisjohnson" + 0.000*"teammoderna"

# %% [markdown]
# # Visulaize Topics

# %%
import pyLDAvis.gensim
warnings.filterwarnings('ignore')

pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(best_model, corpus, dictionary=dictionary_LDA, mds='mmds')
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 8      0.251199  0.270268       1        1  16.764142
# 4      0.251838  0.269279       2        1  15.550432
# 2      0.251373  0.269992       3        1  15.164677
# 7     -0.265238 -0.384213       4        1  13.297540
# 3     -0.328508  0.117337       5        1  10.237104
# 1     -0.328529  0.117220       6        1   9.603888
# 9      0.440394 -0.261186       7        1   8.178508
# 5     -0.109327  0.183438       8        1   4.593346
# 0     -0.307193 -0.103674       9        1   3.399050
# 6      0.143989 -0.478462      10        1   3.211312, topic_info=                Term         Freq        Total Category  logprob  loglift
# 0            moderna  2352.000000  2352.000000  Default   5.0000   5.0000
# 1            johnson  1180.000000  1180.000000  Default   4.0000   4.0000
# 2       borisjohnson   719.000000   719.000000  Default   3.0000   3.0000
# 3  johnsonandjohnson   392.000000   392.000000  Default   2.0000   2.0000
# 4        teammoderna   153.000000   153.000000  Default   1.0000   1.0000
# 0            moderna   804.473528  2352.618687   Topic1  -0.0000   0.7128
# 4        teammoderna     0.009950   153.872755   Topic1 -11.3004  -7.8604
# 3  johnsonandjohnson     0.009554   392.655159   Topic1 -11.3410  -8.8378
# 2       borisjohnson     0.009093   719.750318   Topic1 -11.3905  -9.4932
# 1            johnson     0.009093  1180.103217   Topic1 -11.3905  -9.9877
# 0            moderna   746.220749  2352.618687   Topic2  -0.0001   0.7128
# 4        teammoderna     0.008794   153.872755   Topic2 -11.3488  -7.9087
# 3  johnsonandjohnson     0.014134   392.655159   Topic2 -10.8743  -8.3711
# 2       borisjohnson     0.008399   719.750318   Topic2 -11.3948  -9.4975
# 1            johnson     0.013172  1180.103217   Topic2 -10.9448  -9.5419
# 0            moderna   727.715203  2352.618687   Topic3  -0.0001   0.7128
# 4        teammoderna     0.009066   153.872755   Topic3 -11.2932  -7.8532
# 3  johnsonandjohnson     0.009631   392.655159   Topic3 -11.2327  -8.7295
# 2       borisjohnson     0.008658   719.750318   Topic3 -11.3392  -9.4419
# 1            johnson     0.010308  1180.103217   Topic3 -11.1648  -9.7620
# 2       borisjohnson   638.108377   719.750318   Topic4  -0.0001   1.8972
# 4        teammoderna     0.008249   153.872755   Topic4 -11.2563  -7.8162
# 3  johnsonandjohnson     0.010578   392.655159   Topic4 -11.0075  -8.5043
# 1            johnson     0.013523  1180.103217   Topic4 -10.7619  -9.3591
# 0            moderna     0.008249  2352.618687   Topic4 -11.2563 -10.5434
# 1            johnson   491.215620  1180.103217   Topic5  -0.0001   1.4027
# 4        teammoderna     0.011053   153.872755   Topic5 -10.7021  -7.2620
# 3  johnsonandjohnson     0.011053   392.655159   Topic5 -10.7021  -8.1988
# 2       borisjohnson     0.011053   719.750318   Topic5 -10.7021  -8.8048
# 0            moderna     0.029858  2352.618687   Topic5  -9.7083  -8.9954
# 1            johnson   460.830934  1180.103217   Topic6  -0.0001   1.4027
# 4        teammoderna     0.010152   153.872755   Topic6 -10.7233  -7.2833
# 3  johnsonandjohnson     0.017533   392.655159   Topic6 -10.1769  -7.6736
# 2       borisjohnson     0.012683   719.750318   Topic6 -10.5006  -8.6034
# 0            moderna     0.019307  2352.618687   Topic6 -10.0805  -9.3676
# 3  johnsonandjohnson   392.438113   392.655159   Topic7  -0.0001   2.5031
# 4        teammoderna     0.010747   153.872755   Topic7 -10.5056  -7.0656
# 2       borisjohnson     0.010747   719.750318   Topic7 -10.5056  -8.6084
# 1            johnson     0.014989  1180.103217   Topic7 -10.1729  -8.7701
# 0            moderna     0.012014  2352.618687   Topic7 -10.3941  -9.6813
# 1            johnson   146.409098  1180.103217   Topic8  -0.4092   0.9936
# 0            moderna    73.952778  2352.618687   Topic8  -1.0922  -0.3793
# 4        teammoderna     0.025747   153.872755   Topic8  -9.0550  -5.6150
# 3  johnsonandjohnson     0.023532   392.655159   Topic8  -9.1450  -6.6418
# 2       borisjohnson     0.023532   719.750318   Topic8  -9.1450  -7.2477
# 2       borisjohnson    81.483602   719.750318   Topic9  -0.6941   1.2032
# 1            johnson    81.498341  1180.103217   Topic9  -0.6939   0.7089
# 4        teammoderna     0.044752   153.872755   Topic9  -8.2011  -4.7611
# 3  johnsonandjohnson     0.046859   392.655159   Topic9  -8.1551  -5.6519
# 0            moderna     0.046859  2352.618687   Topic9  -8.1551  -7.4422
# 4        teammoderna   153.734246   153.872755  Topic10  -0.0024   3.4376
# 3  johnsonandjohnson     0.074174   392.655159  Topic10  -7.6390  -5.1358
# 2       borisjohnson     0.074174   719.750318  Topic10  -7.6390  -5.7418
# 1            johnson     0.088139  1180.103217  Topic10  -7.4665  -6.0637
# 0            moderna     0.140143  2352.618687  Topic10  -7.0028  -6.2899, token_table=      Topic      Freq               Term
# term
# 2         4  0.886419       borisjohnson
# 2         9  0.112539       borisjohnson
# 1         5  0.416065            johnson
# 1         6  0.390644            johnson
# 1         8  0.123718            johnson
# 1         9  0.068638            johnson
# 3         7  0.998331  johnsonandjohnson
# 0         1  0.341747            moderna
# 0         2  0.317093            moderna
# 0         3  0.309442            moderna
# 0         8  0.031454            moderna
# 4        10  1.000827        teammoderna, R=5, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[9, 5, 3, 8, 4, 2, 10, 6, 1, 7])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # All Topics Probabilities in each Document

# %%
# convert all probability distribution into dataframe (we are doing this to also keep topics having 0 probability)
# In other case topics having 0 probability will be misleading
def topics_document_to_dataframe(topics_document, num_topics):
    res = pd.DataFrame(columns=range(num_topics))
    for topic_weight in topics_document:
        res.loc[0, topic_weight[0]] = topic_weight[1]
    return res

# %%
# find topic probabilities that model assign to all documents
topics = [best_model[corpus[i]] for i in range(len(text_data))]

# %%
# make dataframe of all document probability distribution
document_topic = \
pd.concat([topics_document_to_dataframe(topics_document, num_topics=best_topic_number) for topics_document in topics]) \
  .reset_index(drop=True).fillna(0)

# %%
document_topic.head(10)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000
# 1  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000
# 2  0.033333  0.033333  0.700000  0.033333  0.033333  0.033333  0.033333
# 3  0.033333  0.033333  0.033333  0.033333  0.033333  0.033333  0.033333
# 4  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000
# 5  0.020000  0.020000  0.820000  0.020000  0.020000  0.020000  0.020000
# 6  0.033333  0.033333  0.033333  0.033333  0.700000  0.033333  0.033333
# 7  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000
# 8  0.033333  0.033333  0.033333  0.033333  0.033333  0.033333  0.033333
# 9  0.033333  0.033333  0.700000  0.033333  0.033333  0.033333  0.033333
#
#           7         8         9
# 0  0.100000  0.100000  0.100000
# 1  0.100000  0.100000  0.100000
# 2  0.033333  0.033333  0.033333
# 3  0.033333  0.700000  0.033333
# 4  0.100000  0.100000  0.100000
# 5  0.020000  0.020000  0.020000
# 6  0.033333  0.033333  0.033333
# 7  0.100000  0.100000  0.100000
# 8  0.033333  0.700000  0.033333
# 9  0.033333  0.033333  0.033333

# %% [markdown]
# # Calculate and Find Keywords in each Document

# %%
def format_topics_sentences(ldamodel=best_model, corpus=corpus, texts=text_data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Per_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=best_model, corpus=corpus, texts=text_data)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             0.0                0.10
# 1            1             0.0                0.10
# 2            2             2.0                0.70
# 3            3             4.0                0.70
# 4            4             0.0                0.10
# 5            5             4.0                0.82
# 6            6             2.0                0.70
# 7            7             0.0                0.10
# 8            8             2.0                0.70
# 9            9             4.0                0.70
#
#                                             Keywords                Text
# 0  johnson, borisjohnson, moderna, johnsonandjohn...            [pfizer]
# 1  johnson, borisjohnson, moderna, johnsonandjohn...            [pfizer]
# 2  moderna, johnson, johnsonandjohnson, teammoder...           [moderna]
# 3  moderna, johnsonandjohnson, johnson, teammoder...           [moderna]
# 4  johnson, borisjohnson, moderna, johnsonandjohn...            [pfizer]
# 5  moderna, johnsonandjohnson, johnson, teammoder...  [moderna, moderna]
# 6  moderna, johnson, johnsonandjohnson, teammoder...           [moderna]
# 7  johnson, borisjohnson, moderna, johnsonandjohn...            [pfizer]
# 8  moderna, johnson, johnsonandjohnson, teammoder...           [moderna]
# 9  moderna, johnsonandjohnson, johnson, teammoder...           [moderna]
