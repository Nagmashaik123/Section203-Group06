# %% [markdown]
# <a href="https://colab.research.google.com/github/Nagmashaik123/Section203-Group06/blob/main/Topic_Modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv(r"ProcessedCovidVaccineReact.csv")
df
# Out:
#                   TweetDate  ...               Country
# 0       2021-04-02 23:59:56  ...  United Arab Emirates
# 1       2021-04-02 23:59:53  ...               Unknown
# 2       2021-04-02 23:59:46  ...               Unknown
# 3       2021-04-02 23:59:43  ...             Indonesia
# 4       2021-04-02 23:59:43  ...         United States
# ...                     ...  ...                   ...
# 206245  2021-03-10 22:35:54  ...         United States
# 206246  2021-03-10 22:35:48  ...         United States
# 206247  2021-03-10 22:35:09  ...         United States
# 206248  2021-03-10 22:35:00  ...         United States
# 206249  2021-03-10 22:34:59  ...        United Kingdom
#
# [206250 rows x 7 columns]

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Package abc is already up-to-date!
#        | Downloading package alpino to /root/nltk_data...
#        |   Package alpino is already up-to-date!
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Package biocreative_ppi is already up-to-date!
#        | Downloading package brown to /root/nltk_data...
#        |   Package brown is already up-to-date!
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Package brown_tei is already up-to-date!
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Package cess_cat is already up-to-date!
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Package cess_esp is already up-to-date!
#        | Downloading package chat80 to /root/nltk_data...
#        |   Package chat80 is already up-to-date!
#        | Downloading package city_database to /root/nltk_data...
#        |   Package city_database is already up-to-date!
#        | Downloading package cmudict to /root/nltk_data...
#        |   Package cmudict is already up-to-date!
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Package comparative_sentences is already up-to-date!
#        | Downloading package comtrans to /root/nltk_data...
#        |   Package comtrans is already up-to-date!
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Package conll2000 is already up-to-date!
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Package conll2002 is already up-to-date!
#        | Downloading package conll2007 to /root/nltk_data...
#        |   Package conll2007 is already up-to-date!
#        | Downloading package crubadan to /root/nltk_data...
#        |   Package crubadan is already up-to-date!
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Package dependency_treebank is already up-to-date!
#        | Downloading package dolch to /root/nltk_data...
#        |   Package dolch is already up-to-date!
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Package europarl_raw is already up-to-date!
#        | Downloading package floresta to /root/nltk_data...
#        |   Package floresta is already up-to-date!
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Package framenet_v15 is already up-to-date!
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Package framenet_v17 is already up-to-date!
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Package gazetteers is already up-to-date!
#        | Downloading package genesis to /root/nltk_data...
#        |   Package genesis is already up-to-date!
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Package gutenberg is already up-to-date!
#        | Downloading package ieer to /root/nltk_data...
#        |   Package ieer is already up-to-date!
#        | Downloading package inaugural to /root/nltk_data...
#        |   Package inaugural is already up-to-date!
#        | Downloading package indian to /root/nltk_data...
#        |   Package indian is already up-to-date!
#        | Downloading package jeita to /root/nltk_data...
#        |   Package jeita is already up-to-date!
#        | Downloading package kimmo to /root/nltk_data...
#        |   Package kimmo is already up-to-date!
#        | Downloading package knbc to /root/nltk_data...
#        |   Package knbc is already up-to-date!
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Package lin_thesaurus is already up-to-date!
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Package mac_morpho is already up-to-date!
#        | Downloading package machado to /root/nltk_data...
#        |   Package machado is already up-to-date!
#        | Downloading package masc_tagged to /root/nltk_data...
#        |   Package masc_tagged is already up-to-date!
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Package moses_sample is already up-to-date!
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Package movie_reviews is already up-to-date!
#        | Downloading package names to /root/nltk_data...
#        |   Package names is already up-to-date!
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        |   Package nombank.1.0 is already up-to-date!
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Package nps_chat is already up-to-date!
#        | Downloading package omw to /root/nltk_data...
#        |   Package omw is already up-to-date!
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Package opinion_lexicon is already up-to-date!
#        | Downloading package paradigms to /root/nltk_data...
#        |   Package paradigms is already up-to-date!
#        | Downloading package pil to /root/nltk_data...
#        |   Package pil is already up-to-date!
#        | Downloading package pl196x to /root/nltk_data...
#        |   Package pl196x is already up-to-date!
#        | Downloading package ppattach to /root/nltk_data...
#        |   Package ppattach is already up-to-date!
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Package problem_reports is already up-to-date!
#        | Downloading package propbank to /root/nltk_data...
#        |   Package propbank is already up-to-date!
#        | Downloading package ptb to /root/nltk_data...
#        |   Package ptb is already up-to-date!
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Package product_reviews_1 is already up-to-date!
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Package product_reviews_2 is already up-to-date!
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Package pros_cons is already up-to-date!
#        | Downloading package qc to /root/nltk_data...
#        |   Package qc is already up-to-date!
#        | Downloading package reuters to /root/nltk_data...
#        |   Package reuters is already up-to-date!
#        | Downloading package rte to /root/nltk_data...
#        |   Package rte is already up-to-date!
#        | Downloading package semcor to /root/nltk_data...
#        |   Package semcor is already up-to-date!
#        | Downloading package senseval to /root/nltk_data...
#        |   Package senseval is already up-to-date!
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Package sentiwordnet is already up-to-date!
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Package sentence_polarity is already up-to-date!
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Package shakespeare is already up-to-date!
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Package sinica_treebank is already up-to-date!
#        | Downloading package smultron to /root/nltk_data...
#        |   Package smultron is already up-to-date!
#        | Downloading package state_union to /root/nltk_data...
#        |   Package state_union is already up-to-date!
#        | Downloading package stopwords to /root/nltk_data...
#        |   Package stopwords is already up-to-date!
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Package subjectivity is already up-to-date!
#        | Downloading package swadesh to /root/nltk_data...
#        |   Package swadesh is already up-to-date!
#        | Downloading package switchboard to /root/nltk_data...
#        |   Package switchboard is already up-to-date!
#        | Downloading package timit to /root/nltk_data...
#        |   Package timit is already up-to-date!
#        | Downloading package toolbox to /root/nltk_data...
#        |   Package toolbox is already up-to-date!
#        | Downloading package treebank to /root/nltk_data...
#        |   Package treebank is already up-to-date!
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Package twitter_samples is already up-to-date!
#        | Downloading package udhr to /root/nltk_data...
#        |   Package udhr is already up-to-date!
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Package udhr2 is already up-to-date!
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Package unicode_samples is already up-to-date!
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        |   Package universal_treebanks_v20 is already up-to-date!
#        | Downloading package verbnet to /root/nltk_data...
#        |   Package verbnet is already up-to-date!
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Package verbnet3 is already up-to-date!
#        | Downloading package webtext to /root/nltk_data...
#        |   Package webtext is already up-to-date!
#        | Downloading package wordnet to /root/nltk_data...
#        |   Package wordnet is already up-to-date!
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Package wordnet_ic is already up-to-date!
#        | Downloading package words to /root/nltk_data...
#        |   Package words is already up-to-date!
#        | Downloading package ycoe to /root/nltk_data...
#        |   Package ycoe is already up-to-date!
#        | Downloading package rslp to /root/nltk_data...
#        |   Package rslp is already up-to-date!
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Package maxent_treebank_pos_tagger is already up-to-date!
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Package universal_tagset is already up-to-date!
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Package maxent_ne_chunker is already up-to-date!
#        | Downloading package punkt to /root/nltk_data...
#        |   Package punkt is already up-to-date!
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Package book_grammars is already up-to-date!
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Package sample_grammars is already up-to-date!
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Package spanish_grammars is already up-to-date!
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Package basque_grammars is already up-to-date!
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Package large_grammars is already up-to-date!
#        | Downloading package tagsets to /root/nltk_data...
#        |   Package tagsets is already up-to-date!
#        | Downloading package snowball_data to /root/nltk_data...
#        |   Package snowball_data is already up-to-date!
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Package bllip_wsj_no_aux is already up-to-date!
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Package word2vec_sample is already up-to-date!
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        |   Package panlex_swadesh is already up-to-date!
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Package mte_teip5 is already up-to-date!
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Package averaged_perceptron_tagger is already up-to-date!
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Package averaged_perceptron_tagger_ru is already up-to-
#        |       date!
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Package perluniprops is already up-to-date!
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Package nonbreaking_prefixes is already up-to-date!
#        | Downloading package vader_lexicon to /root/nltk_data...
#        |   Package vader_lexicon is already up-to-date!
#        | Downloading package porter_test to /root/nltk_data...
#        |   Package porter_test is already up-to-date!
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Package wmt15_eval is already up-to-date!
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Package mwa_ppdb is already up-to-date!
#        |
#      Done downloading collection all
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %%
import itertools
import collections
from nltk import ngrams
from nltk.tokenize import word_tokenize

words_sentence = []
for sentence in df['CleanedTweet']:
  try:
    if pd.isnull(sentence) or float(sentence):
      tokens.append("")
  except ValueError:
      words_sentence.append(word_tokenize(sentence))

aftercleaning = [item for item in words_sentence if item != []]
iterations = list(itertools.chain.from_iterable(aftercleaning))
one_gram_data = ngrams(iterations, 1)
collections.Counter(one_gram_data).most_common(20000)
# Out:
# [(('rt',), 112087),
#  (('covidvaccine',), 95367),
#  (('vaccine',), 53844),
#  (('vaccinated',), 43935),
#  (('get',), 26983),
#  (('amp',), 18143),
#  (('covid',), 16716),
#  (('today',), 16533),
#  (('first',), 15727),
#  (('people',), 15464),
#  (('vaccines',), 14617),
#  (('got',), 14228),
#  (('vaccination',), 14073),
#  (('dose',), 13719),
#  (('im',), 12582),
#  (('doses',), 12572),
#  (('moderna',), 12160),
#  (('pfizer',), 9945),
#  (('one',), 9857),
#  (('astrazeneca',), 9721),
#  (('year',), 9710),
#  (('would',), 9360),
#  (('shot',), 9151),
#  (('getting',), 8652),
#  (('safe',), 8065),
#  (('need',), 7924),
#  (('us',), 7639),
#  (('see',), 7614),
#  (('health',), 6973),
#  (('thank',), 6482),
#  (('eligible',), 6347),
#  (('take',), 6251),
#  (('ago',), 6162),
#  (('still',), 6042),
#  (('coronavirus',), 6020),
#  (('new',), 5950),
#  (('two',), 5929),
#  (('please',), 5856),
#  (('like',), 5806),
#  (('second',), 5585),
#  (('dont',), 5528),
#  (('day',), 5403),
#  (('life',), 5082),
#  (('support',), 5036),
#  (('jab',), 5029),
#  (('vaccinessavelives',), 4978),
#  (('received',), 4932),
#  (('know',), 4874),
#  (('mrna',), 4765),
#  (('done',), 4751),
#  (('india',), 4743),
#  (('appointment',), 4660),
#  (('go',), 4648),
#  (('tried',), 4618),
#  (('time',), 4598),
#  (('anniversary',), 4594),
#  (('good',), 4564),
#  (('never',), 4560),
#  (('ichaydon',), 4535),
#  (('spoiler',), 4463),
#  (('hap',), 4457),
#  (('trump',), 4342),
#  (('davidmweissman',), 4315),
#  (('everyone',), 4246),
#  (('april',), 4100),
#  (('long',), 4000),
#  (('cant',), 3958),
#  (('great',), 3905),
#  (('many',), 3902),
#  (('hotvickkrishna',), 3882),
#  (('decision',), 3840),
#  (('help',), 3818),
#  (('fully',), 3813),
#  (('pandemic',), 3771),
#  (('httpstco',), 3748),
#  (('imagine',), 3746),
#  (('effects',), 3708),
#  (('age',), 3707),
#  (('uk',), 3679),
#  (('well',), 3625),
#  (('ending',), 3625),
#  (('saving',), 3518),
#  (('make',), 3489),
#  (('work',), 3465),
#  (('blood',), 3462),
#  (('leaving',), 3452),
#  (('available',), 3432),
#  (('information',), 3427),
#  (('youre',), 3409),
#  (('maga',), 3400),
#  (('safety',), 3375),
#  (('dr',), 3372),
#  (('week',), 3366),
#  (('show',), 3365),
#  (('want',), 3349),
#  (('free',), 3346),
#  (('march',), 3285),
#  (('made',), 3273),
#  (('side',), 3244),
#  (('million',), 3215),
#  (('cases',), 3215),
#  (('community',), 3193),
#  (('family',), 3189),
#  (('even',), 3152),
#  (('news',), 3123),
#  (('country',), 3123),
#  (('vaccinate',), 3079),
#  (('thanks',), 3054),
#  (('drericding',), 3026),
#  (('days',), 2985),
#  (('years',), 2981),
#  (('book',), 2946),
#  (('last',), 2934),
#  (('appointments',), 2914),
#  (('nhs',), 2876),
#  (('virus',), 2872),
#  (('back',), 2867),
#  (('ontario',), 2858),
#  (('medical',), 2833),
#  (('eu',), 2831),
#  (('state',), 2827),
#  (('wait',), 2814),
#  (('took',), 2794),
#  (('part',), 2774),
#  (('feel',), 2586),
#  (('morning',), 2576),
#  (('next',), 2574),
#  (('clinic',), 2567),
#  (('may',), 2565),
#  (('slots',), 2510),
#  (('receive',), 2505),
#  (('way',), 2502),
#  (('going',), 2494),
#  (('says',), 2480),
#  (('via',), 2463),
#  (('government',), 2408),
#  (('krispykreme',), 2402),
#  (('best',), 2399),
#  (('happy',), 2389),
#  (('anyone',), 2382),
#  (('care',), 2375),
#  (('grateful',), 2359),
#  (('also',), 2351),
#  (('rollout',), 2326),
#  (('president',), 2324),
#  (('share',), 2315),
#  (('yet',), 2280),
#  (('arm',), 2279),
#  (('world',), 2279),
#  (('committee',), 2277),
#  (('starting',), 2260),
#  (('protect',), 2246),
#  (('important',), 2242),
#  (('keep',), 2240),
#  (('staff',), 2234),
#  (('administered',), 2230),
#  (('yesterday',), 2226),
#  (('workers',), 2223),
#  (('feeling',), 2194),
#  (('come',), 2188),
#  (('fucking',), 2179),
#  (('emas',), 2179),
#  (('prac',), 2157),
#  (('much',), 2141),
#  (('ca',), 2136),
#  (('really',), 2132),
#  (('right',), 2124),
#  (('getvaccinated',), 2112),
#  (('donut',), 2107),
#  (('despite',), 2090),
#  (('ive',), 2077),
#  (('weeks',), 2067),
#  (('every',), 2065),
#  (('could',), 2065),
#  (('lets',), 2039),
#  (('patients',), 2028),
#  (('said',), 2028),
#  (('citizens',), 2011),
#  (('vaccinations',), 2010),
#  (('clots',), 2001),
#  (('far',), 1995),
#  (('check',), 1982),
#  (('effective',), 1982),
#  (('open',), 1980),
#  (('maryltrump',), 1979),
#  (('largestvaccinedrive',), 1968),
#  (('call',), 1966),
#  (('johnson',), 1965),
#  (('say',), 1946),
#  (('science',), 1934),
#  (('biden',), 1928),
#  (('soon',), 1926),
#  (('register',), 1926),
#  (('another',), 1916),
#  (('questions',), 1874),
#  (('corona',), 1874),
#  (('update',), 1872),
#  (('hope',), 1867),
#  (('find',), 1849),
#  (('aged',), 1849),
#  (('vaccineswork',), 1821),
#  (('horrible',), 1817),
#  (('watch',), 1817),
#  (('shots',), 1788),
#  (('follow',), 1784),
#  (('visit',), 1775),
#  (('must',), 1769),
#  (('public',), 1763),
#  (('finally',), 1730),
#  (('hours',), 1729),
#  (('around',), 1714),
#  (('benefits',), 1713),
#  (('read',), 1703),
#  (('excited',), 1700),
#  (('deaths',), 1699),
#  (('give',), 1694),
#  (('park',), 1694),
#  (('risks',), 1690),
#  (('centre',), 1689),
#  (('old',), 1676),
#  (('countries',), 1665),
#  (('taking',), 1660),
#  (('locations',), 1657),
#  (('think',), 1651),
#  (('tomorrow',), 1651),
#  (('since',), 1642),
#  (('believe',), 1640),
#  (('risk',), 1613),
#  (('use',), 1597),
#  (('cvs',), 1596),
#  (('given',), 1595),
#  (('center',), 1595),
#  (('better',), 1593),
#  (('fresno',), 1593),
#  (('video',), 1590),
#  (('live',), 1587),
#  (('naheedd',), 1585),
#  (('mask',), 1584),
#  (('thats',), 1575),
#  (('big',), 1574),
#  (('data',), 1569),
#  (('across',), 1561),
#  (('sure',), 1556),
#  (('outweigh',), 1554),
#  (('waiting',), 1547),
#  (('able',), 1525),
#  (('looking',), 1524),
#  (('site',), 1523),
#  (('monday',), 1519),
#  (('love',), 1516),
#  (('china',), 1511),
#  (('hospital',), 1507),
#  (('working',), 1506),
#  (('friends',), 1504),
#  (('residents',), 1504),
#  (('team',), 1499),
#  (('home',), 1489),
#  (('line',), 1488),
#  (('garbage',), 1487),
#  (('canada',), 1485),
#  (('healthcare',), 1484),
#  (('proud',), 1479),
#  (('breaking',), 1476),
#  (('stop',), 1468),
#  (('doctors',), 1463),
#  (('online',), 1462),
#  (('pm',), 1458),
#  (('reminder',), 1456),
#  (('concludes',), 1454),
#  (('end',), 1453),
#  (('county',), 1444),
#  (('trial',), 1438),
#  (('progress',), 1422),
#  (('w',), 1415),
#  (('others',), 1402),
#  (('https',), 1399),
#  (('adults',), 1378),
#  (('red',), 1374),
#  (('continue',), 1372),
#  (('needs',), 1371),
#  (('info',), 1370),
#  (('va',), 1365),
#  (('making',), 1352),
#  (('amazing',), 1352),
#  (('cdc',), 1351),
#  (('lockdown',), 1343),
#  (('little',), 1335),
#  (('lives',), 1333),
#  (('wearamask',), 1330),
#  (('business',), 1317),
#  (('number',), 1317),
#  (('mass',), 1313),
#  (('announced',), 1298),
#  (('spread',), 1291),
#  (('scientists',), 1291),
#  (('didnt',), 1290),
#  (('potus',), 1289),
#  (('pakistan',), 1289),
#  (('start',), 1286),
#  (('folks',), 1284),
#  (('local',), 1278),
#  (('whether',), 1273),
#  (('eligibility',), 1271),
#  (('full',), 1268),
#  (('major',), 1267),
#  (('month',), 1258),
#  (('job',), 1256),
#  (('turn',), 1251),
#  (('already',), 1249),
#  (('group',), 1238),
#  (('normal',), 1236),
#  (('night',), 1229),
#  (('older',), 1229),
#  (('early',), 1229),
#  (('social',), 1224),
#  (('due',), 1221),
#  (('months',), 1219),
#  (('look',), 1202),
#  (('told',), 1193),
#  (('travel',), 1191),
#  (('though',), 1174),
#  (('population',), 1173),
#  (('house',), 1168),
#  (('theatlantic',), 1167),
#  (('total',), 1163),
#  (('states',), 1163),
#  (('post',), 1159),
#  (('someone',), 1158),
#  (('covidvaccination',), 1154),
#  (('plan',), 1154),
#  (('heres',), 1144),
#  (('minister',), 1140),
#  (('join',), 1139),
#  (('thing',), 1136),
#  (('coming',), 1135),
#  (('using',), 1133),
#  (('th',), 1131),
#  (('volunteers',), 1125),
#  (('nilikm',), 1118),
#  (('members',), 1116),
#  (('access',), 1116),
#  (('children',), 1115),
#  (('city',), 1114),
#  (('hug',), 1109),
#  (('weve',), 1108),
#  (('whats',), 1104),
#  (('note',), 1096),
#  (('ask',), 1095),
#  (('pharmacies',), 1095),
#  (('kenyatta',), 1093),
#  (('exported',), 1089),
#  (('stay',), 1084),
#  (('schedule',), 1080),
#  (('bakersfield',), 1078),
#  (('doesnt',), 1077),
#  (('possible',), 1076),
#  (('system',), 1074),
#  (('including',), 1071),
#  (('true',), 1068),
#  (('positive',), 1068),
#  (('sore',), 1067),
#  (('ill',), 1062),
#  (('published',), 1058),
#  (('v',), 1057),
#  (('friday',), 1055),
#  (('together',), 1055),
#  (('let',), 1052),
#  (('least',), 1052),
#  (('high',), 1050),
#  (('richardgcorbett',), 1049),
#  (('supply',), 1048),
#  (('forward',), 1047),
#  (('rite',), 1047),
#  (('ready',), 1047),
#  (('wear',), 1045),
#  (('vacc',), 1044),
#  (('choose',), 1043),
#  (('calling',), 1039),
#  (('process',), 1039),
#  (('sick',), 1038),
#  (('works',), 1036),
#  (('california',), 1034),
#  (('experience',), 1031),
#  (('aids',), 1028),
#  (('website',), 1027),
#  (('list',), 1016),
#  (('pfizervaccine',), 1012),
#  (('theres',), 1005),
#  (('bit',), 997),
#  (('offered',), 991),
#  (('kids',), 988),
#  (('national',), 987),
#  (('latest',), 986),
#  (('narendramodi',), 985),
#  (('without',), 984),
#  (('nobody',), 982),
#  (('springs',), 980),
#  (('everything',), 973),
#  (('remember',), 967),
#  (('sharing',), 966),
#  (('yes',), 963),
#  (('parents',), 959),
#  (('enough',), 958),
#  (('north',), 958),
#  (('marr',), 956),
#  (('younger',), 954),
#  (('media',), 951),
#  (('false',), 951),
#  (('providing',), 949),
#  (('put',), 947),
#  (('tell',), 945),
#  (('exports',), 945),
#  (('coronavaccine',), 943),
#  (('learn',), 942),
#  (('az',), 941),
#  (('isnt',), 939),
#  (('booked',), 934),
#  (('fight',), 934),
#  (('tested',), 931),
#  (('less',), 930),
#  (('details',), 928),
#  (('immunity',), 927),
#  (('communities',), 926),
#  (('hi',), 924),
#  (('campaign',), 924),
#  (('mar',), 924),
#  (('press',), 924),
#  (('receiving',), 923),
#  (('arent',), 921),
#  (('sign',), 920),
#  (('almost',), 919),
#  (('distribution',), 919),
#  (('happened',), 918),
#  (('gp',), 918),
#  (('jampj',), 917),
#  (('trying',), 916),
#  (('away',), 914),
#  (('clovis',), 913),
#  (('drharshvardhan',), 913),
#  (('ones',), 911),
#  (('govt',), 909),
#  (('efficacy',), 907),
#  (('masks',), 904),
#  (('save',), 903),
#  (('el',), 899),
#  (('anything',), 898),
#  (('mind',), 898),
#  (('things',), 897),
#  (('step',), 897),
#  (('win',), 896),
#  (('thankful',), 895),
#  (('havent',), 895),
#  (('worked',), 894),
#  (('bring',), 893),
#  (('wont',), 882),
#  (('review',), 878),
#  (('encourage',), 876),
#  (('body',), 876),
#  (('vaccinating',), 876),
#  (('fact',), 876),
#  (('weekend',), 875),
#  (('running',), 873),
#  (('clot',), 867),
#  (('per',), 867),
#  (('registration',), 865),
#  (('co',), 863),
#  (('study',), 859),
#  (('planned',), 858),
#  (('palm',), 856),
#  (('school',), 855),
#  (('borisjohnson',), 851),
#  (('hills',), 850),
#  (('serum',), 842),
#  (('person',), 839),
#  (('real',), 838),
#  (('shows',), 837),
#  (('saturday',), 836),
#  (('elses',), 833),
#  (('report',), 833),
#  (('hard',), 833),
#  (('provide',), 831),
#  (('hear',), 830),
#  (('research',), 830),
#  (('lot',), 826),
#  (('youve',), 826),
#  (('rate',), 823),
#  (('three',), 822),
#  (('loved',), 821),
#  (('nothing',), 820),
#  (('drive',), 820),
#  (('treat',), 818),
#  (('areas',), 816),
#  (('newtonclarkeuk',), 816),
#  (('service',), 815),
#  (('covax',), 814),
#  (('covishield',), 814),
#  (('taken',), 812),
#  (('started',), 812),
#  (('lockdownno',), 810),
#  (('americans',), 810),
#  (('daily',), 804),
#  (('miss',), 802),
#  (('easy',), 801),
#  (('vax',), 800),
#  (('retweet',), 800),
#  (('message',), 796),
#  (('link',), 794),
#  (('pharmacy',), 792),
#  (('card',), 791),
#  (('went',), 789),
#  (('anaheim',), 785),
#  (('delivered',), 784),
#  (('global',), 784),
#  (('spot',), 783),
#  (('giving',), 780),
#  (('comes',), 780),
#  (('moment',), 780),
#  (('disease',), 780),
#  (('valley',), 780),
#  (('nurse',), 777),
#  (('truth',), 774),
#  (('sites',), 774),
#  (('surging',), 772),
#  (('deadly',), 772),
#  (('response',), 769),
#  (('mom',), 768),
#  (('spreading',), 766),
#  (('theyve',), 766),
#  (('gets',), 763),
#  (('helping',), 763),
#  (('doctor',), 762),
#  (('account',), 760),
#  (('lady',), 760),
#  (('est',), 758),
#  (('toronto',), 757),
#  (('death',), 755),
#  (('scheduled',), 755),
#  (('frozen',), 754),
#  (('ministers',), 754),
#  (('beach',), 753),
#  (('briefing',), 751),
#  (('jabs',), 750),
#  (('clinics',), 748),
#  (('immune',), 748),
#  (('experts',), 748),
#  (('hardest',), 746),
#  (('nhsengland',), 743),
#  (('joe',), 742),
#  (('infected',), 741),
#  (('listen',), 740),
#  (('leaders',), 739),
#  (('elderly',), 734),
#  (('huge',), 733),
#  (('breakingdue',), 728),
#  (('nice',), 724),
#  (('hey',), 722),
#  (('id',), 720),
#  (('story',), 720),
#  (('black',), 720),
#  (('place',), 718),
#  (('else',), 717),
#  (('thursday',), 717),
#  (('case',), 716),
#  (('reports',), 716),
#  (('means',), 713),
#  (('past',), 712),
#  (('employees',), 712),
#  (('iamwandasykes',), 710),
#  (('different',), 710),
#  (('asap',), 707),
#  (('northwest',), 706),
#  (('chile',), 706),
#  (('rejuvenated',), 704),
#  (('telling',), 704),
#  (('uhuru',), 700),
#  (('places',), 699),
#  (('maybe',), 698),
#  (('cdcgov',), 698),
#  (('todays',), 697),
#  (('teachers',), 694),
#  (('bad',), 692),
#  (('friend',), 692),
#  (('chief',), 690),
#  (('talk',), 688),
#  (('minutes',), 686),
#  (('phase',), 686),
#  (('wave',), 685),
#  (('women',), 684),
#  (('oxfordastrazeneca',), 682),
#  (('south',), 682),
#  (('consider',), 681),
#  (('la',), 680),
#  (('question',), 680),
#  (('smooth',), 680),
#  (('makes',), 679),
#  (('millions',), 679),
#  (('cov',), 678),
#  (('los',), 677),
#  (('understand',), 675),
#  (('might',), 675),
#  (('peru',), 675),
#  (('corner',), 674),
#  (('additional',), 673),
#  (('super',), 671),
#  (('riskin',), 670),
#  (('angeles',), 669),
#  (('fauci',), 669),
#  (('protection',), 668),
#  (('seen',), 668),
#  (('observ',), 667),
#  (('scottmorrisonmp',), 666),
#  (('hello',), 665),
#  (('heard',), 664),
#  (('ever',), 664),
#  (('st',), 664),
#  (('europe',), 664),
#  (('within',), 664),
#  (('felt',), 664),
#  (('severe',), 664),
#  (('either',), 663),
#  (('granted',), 662),
#  (('half',), 662),
#  (('vaccinepassports',), 660),
#  (('refusing',), 660),
#  (('passports',), 658),
#  (('left',), 658),
#  (('hollywood',), 658),
#  (('essential',), 658),
#  (('frontline',), 657),
#  (('area',), 657),
#  (('entry',), 657),
#  (('currently',), 657),
#  (('san',), 655),
#  (('single',), 655),
#  (('maskup',), 654),
#  (('covaxin',), 652),
#  (('symptoms',), 651),
#  (('power',), 651),
#  (('along',), 650),
#  (('set',), 649),
#  (('west',), 648),
#  (('wow',), 647),
#  (('problem',), 644),
#  (('closer',), 644),
#  (('ages',), 643),
#  (('booking',), 642),
#  (('c',), 642),
#  (('auspol',), 640),
#  (('vulnerable',), 640),
#  (('persons',), 639),
#  (('unicef',), 637),
#  (('walk',), 634),
#  (('among',), 632),
#  (('latinos',), 632),
#  (('hot',), 631),
#  (('astrazenecavaccine',), 631),
#  (('later',), 630),
#  (('inequality',), 630),
#  (('yall',), 629),
#  (('always',), 629),
#  (('god',), 628),
#  (('groups',), 626),
#  (('mine',), 625),
#  (('whole',), 625),
#  (('misinformation',), 625),
#  (('canon',), 623),
#  (('convention',), 623),
#  (('florida',), 622),
#  (('winner',), 622),
#  (('healthy',), 622),
#  (('powershot',), 621),
#  (('source',), 621),
#  (('nairobi',), 620),
#  (('students',), 619),
#  (('test',), 617),
#  (('variants',), 617),
#  (('international',), 615),
#  (('dad',), 614),
#  (('hospitalized',), 610),
#  (('fauciouchie',), 609),
#  (('behind',), 607),
#  (('light',), 607),
#  (('worth',), 606),
#  (('fine',), 606),
#  (('companies',), 606),
#  (('dangerous',), 605),
#  (('something',), 604),
#  (('usa',), 603),
#  (('freezers',), 603),
#  (('article',), 601),
#  (('gotten',), 600),
#  (('er',), 598),
#  (('director',), 596),
#  (('times',), 594),
#  (('datadrivenmd',), 594),
#  (('lead',), 593),
#  (('asked',), 592),
#  (('small',), 591),
#  (('restrictions',), 588),
#  (('used',), 588),
#  (('buena',), 587),
#  (('desert',), 587),
#  (('issue',), 586),
#  (('joebiden',), 586),
#  (('hes',), 585),
#  (('event',), 584),
#  (('saying',), 584),
#  (('stark',), 583),
#  (('torontos',), 583),
#  (('extre',), 583),
#  (('centres',), 581),
#  (('called',), 581),
#  (('events',), 580),
#  (('johnsonandjohnson',), 579),
#  (('opportunity',), 578),
#  (('reported',), 578),
#  (('hanford',), 578),
#  (('texas',), 577),
#  (('young',), 577),
#  (('play',), 577),
#  (('indias',), 577),
#  (('america',), 576),
#  (('answer',), 575),
#  (('nolaready',), 575),
#  (('preventing',), 574),
#  (('pay',), 574),
#  (('injection',), 574),
#  (('seniors',), 573),
#  (('b',), 573),
#  (('approved',), 573),
#  (('experimental',), 572),
#  (('chico',), 572),
#  (('become',), 572),
#  (('efficient',), 571),
#  (('easter',), 571),
#  (('trials',), 571),
#  (('dots',), 571),
#  (('summer',), 570),
#  (('guidelines',), 569),
#  (('conditions',), 569),
#  (('relief',), 568),
#  (('smart',), 567),
#  (('blank',), 567),
#  (('twitter',), 565),
#  (('hall',), 565),
#  (('baldwin',), 565),
#  (('contrast',), 565),
#  (('tuesday',), 564),
#  (('administering',), 564),
#  (('cause',), 562),
#  (('reason',), 562),
#  (('trust',), 562),
#  (('cr',), 562),
#  (('drkhaldun',), 562),
#  (('covidiots',), 561),
#  (('based',), 561),
#  (('european',), 560),
#  (('seeing',), 559),
#  (('youtube',), 559),
#  (('thought',), 559),
#  (('send',), 558),
#  (('theyre',), 558),
#  (('record',), 558),
#  (('sprea',), 557),
#  (('plans',), 556),
#  (('pfizercovidvaccine',), 555),
#  (('downey',), 555),
#  (('centro',), 555),
#  (('instead',), 554),
#  (('u',), 554),
#  (('fever',), 553),
#  (('worlds',), 553),
#  (('indian',), 553),
#  (('disproportionat',), 553),
#  (('r',), 551),
#  (('glad',), 550),
#  (('thinking',), 549),
#  (('roll',), 548),
#  (('offer',), 548),
#  (('afternoon',), 548),
#  (('rich',), 547),
#  (('third',), 546),
#  (('headache',), 545),
#  (('leave',), 545),
#  (('senior',), 545),
#  (('feels',), 544),
#  (('camarillo',), 544),
#  (('absolutely',), 541),
#  (('thisisourshot',), 541),
#  (('pain',), 541),
#  (('died',), 541),
#  (('found',), 540),
#  (('sunday',), 540),
#  (('numbers',), 540),
#  (('head',), 539),
#  (('fema',), 538),
#  (('concerns',), 537),
#  (('httpst',), 536),
#  (('na',), 536),
#  (('officially',), 536),
#  (('wearing',), 536),
#  (('pregnant',), 536),
#  (('following',), 535),
#  (('according',), 534),
#  (('margaret',), 532),
#  (('role',), 530),
#  (('lots',), 529),
#  (('hit',), 529),
#  (('gov',), 529),
#  (('indiafightscorona',), 529),
#  (('priority',), 528),
#  (('tired',), 528),
#  (('needed',), 528),
#  (('ensure',), 527),
#  (('families',), 526),
#  (('condition',), 525),
#  (('especially',), 525),
#  (('http',), 524),
#  (('programme',), 523),
#  (('santa',), 522),
#  (('pretty',), 521),
#  (('korea',), 521),
#  (('doug',), 519),
#  (('nurses',), 518),
#  (('myanmar',), 517),
#  (('onpoli',), 515),
#  (('fordnation',), 514),
#  (('oxford',), 514),
#  (('rise',), 512),
#  (('gardens',), 511),
#  (('adverse',), 510),
#  (('issues',), 509),
#  (('complete',), 509),
#  (('efforts',), 509),
#  (('flu',), 509),
#  (('measures',), 508),
#  (('posting',), 508),
#  (('actually',), 507),
#  (('round',), 507),
#  (('cnn',), 507),
#  (('wife',), 506),
#  (('mean',), 506),
#  (('covina',), 506),
#  (('tests',), 506),
#  (('quick',), 504),
#  (('special',), 503),
#  (('minaunghlaing',), 503),
#  (('member',), 502),
#  (('hands',), 501),
#  (('happen',), 501),
#  (('ishatreza',), 501),
#  (('verified',), 501),
#  (('earlier',), 500),
#  (('n',), 499),
#  (('change',), 498),
#  (('rest',), 498),
#  (('point',), 498),
#  (('spring',), 497),
#  (('wrong',), 497),
#  (('artesia',), 497),
#  (('shipment',), 496),
#  (('doc',), 496),
#  (('colleagues',), 496),
#  (('hamidmirpak',), 496),
#  (('infection',), 495),
#  (('underlying',), 495),
#  (('yednetworkke',), 495),
#  (('statehousekenya',), 494),
#  (('needles',), 493),
#  (('date',), 493),
#  (('former',), 492),
#  (('lakh',), 492),
#  (('tonight',), 491),
#  (('couldnt',), 491),
#  (('takes',), 491),
#  (('coronavirusupdates',), 490),
#  (('pfizerbiontech',), 488),
#  (('hesitancy',), 487),
#  (('antibodies',), 486),
#  (('failure',), 485),
#  (('wonderful',), 485),
#  (('private',), 485),
#  (('arms',), 484),
#  (('everyday',), 484),
#  (('tweet',), 483),
#  (('living',), 483),
#  (('federal',), 483),
#  (('khan',), 482),
#  (('ahead',), 480),
#  (('cancer',), 479),
#  (('born',), 479),
#  (('temecula',), 477),
#  (('astrazenaca',), 477),
#  (('move',), 477),
#  (('shame',), 477),
#  (('modernavaccine',), 476),
#  (('return',), 476),
#  (('january',), 475),
#  (('contact',), 474),
#  (('ok',), 474),
#  (('mumbai',), 473),
#  (('effect',), 473),
#  (('control',), 473),
#  (('oh',), 472),
#  (('covi',), 471),
#  (('region',), 471),
#  (('goes',), 471),
#  (('mum',), 471),
#  (('arising',), 470),
#  (('hse',), 469),
#  (('sending',), 468),
#  (('face',), 467),
#  (('expected',), 467),
#  (('testing',), 466),
#  (('effort',), 464),
#  (('likely',), 464),
#  (('disability',), 464),
#  (('meghupdates',), 464),
#  (('staysafe',), 462),
#  (('course',), 462),
#  (('pharmaceutical',), 462),
#  (('seems',), 461),
#  (('walgreens',), 461),
#  (('j',), 461),
#  (('registered',), 461),
#  (('individuals',), 460),
#  (('program',), 460),
#  (('short',), 460),
#  (('equip',), 460),
#  (('bupa',), 460),
#  (('key',), 459),
#  (('ess',), 459),
#  (('man',), 458),
#  (('request',), 457),
#  (('worker',), 457),
#  (('low',), 456),
#  (('several',), 456),
#  (('modernapfizer',), 455),
#  (('bill',), 454),
#  (('madera',), 453),
#  (('meet',), 453),
#  (('gop',), 452),
#  (('late',), 452),
#  (('insure',), 452),
#  (('updated',), 450),
#  (('offering',), 449),
#  (('clinical',), 449),
#  (('mygovindia',), 449),
#  (('azusa',), 449),
#  (('facts',), 449),
#  (('okay',), 448),
#  (('mild',), 448),
#  (('helped',), 448),
#  (('hour',), 448),
#  (('general',), 448),
#  (('secured',), 448),
#  (('protected',), 447),
#  (('gives',), 445),
#  (('janssen',), 444),
#  (('updates',), 444),
#  (('webinar',), 444),
#  (('administration',), 444),
#  (('click',), 443),
#  (('entire',), 443),
#  (('maharashtra',), 443),
#  (('leading',), 443),
#  (('quickly',), 442),
#  (('looks',), 442),
#  (('union',), 441),
#  (('pmoindia',), 440),
#  (('serious',), 439),
#  (('choice',), 439),
#  (('australians',), 439),
#  (('order',), 438),
#  (('heart',), 438),
#  (('publichealth',), 437),
#  (('islamrizza',), 437),
#  (('wednesday',), 437),
#  (('africa',), 434),
#  (('chance',), 432),
#  (('reaction',), 431),
#  (('carer',), 431),
#  (('nearly',), 431),
#  (('gates',), 428),
#  (('happening',), 427),
#  (('irelandvaccine',), 426),
#  (('ppl',), 426),
#  (('hselive',), 426),
#  (('freedom',), 425),
#  (('york',), 425),
#  (('future',), 425),
#  (('beginning',), 424),
#  (('banning',), 423),
#  (('pharma',), 423),
#  (('phone',), 423),
#  (('nations',), 423),
#  (('evaunicef',), 422),
#  (('top',), 422),
#  (('availability',), 422),
#  (('p',), 421),
#  ...]

# %%
import pandas as pd
from gensim.models import Phrases
from gensim import corpora, models
from nltk.tokenize import word_tokenize 
tokens=[]
bigram = Phrases()
for a in df["CleanedTweet"]:
  try:
    if pd.isnull(a) or float(a):
      tokens.append("")
  except ValueError:
      tokens.append(word_tokenize(a))

bigram_data = models.Phrases(tokens, min_count=30)
bigrams_mod_val = models.phrases.Phraser(bigram_data)

# %%
#Top n-grams
import operator
dictionary={}
count=0
bigrams=[]
for id in range(len(tokens)):
    for token in bigrams_mod_val[tokens[id]]:
        if '_' in token:
          bigrams.append(token)
          tokens[id].append(token)
for keyVal in bigrams:
  if co in dictionary:
    dictionary[keyVal]+=1
  else:
    dictionary[keyVal]=1
data= sorted(dictionary.items(),key=operator.itemgetter(1),reverse=True)

# %%
data[:20000]
# Out:
# [('anniversary_im', 8912),
#  ('see_safe', 8908),
#  ('ichaydon_year', 8898),
#  ('ago_tried', 8898),
#  ('two_doses', 7064),
#  ('mrna_vaccine', 7006),
#  ('vaccines_pfizer', 6820),
#  ('moderna_vaccinessavelives', 6812),
#  ('vaccinated_httpstco', 6796),
#  ('hotvickkrishna_need', 6782),
#  ('life_saving', 6752),
#  ('trump_would', 6578),
#  ('davidmweissman_never', 6570),
#  ('would_imagine', 6570),
#  ('leaving_maga', 6570),
#  ('ending_support', 6570),
#  ('got_first', 5848),
#  ('first_dose', 5330),
#  ('side_effects', 5260),
#  ('fully_vaccinated', 4902),
#  ('donut_krispykreme', 3892),
#  ('fucking_year', 3860),
#  ('maryltrump_long', 3856),
#  ('emas_safety', 3742),
#  ('committee_prac', 3730),
#  ('slots_ca', 3592),
#  ('second_dose', 3466),
#  ('outweigh_risks', 2950),
#  ('astrazeneca_still', 2834),
#  ('concludes_benefits', 2816),
#  ('received_first', 2502),
#  ('cant_wait', 2470),
#  ('blood_clots', 2372),
#  ('cvs_locations', 2366),
#  ('doses_uk', 2274),
#  ('country_doses', 1882),
#  ('reminder_eu', 1876),
#  ('richardgcorbett_marr', 1874),
#  ('rite_aids', 1870),
#  ('million_doses', 1848),
#  ('take_cant', 1728),
#  ('horrible_garbage', 1726),
#  ('believe_theatlantic', 1726),
#  ('medical_information', 1632),
#  ('choose_vaccination', 1630),
#  ('nobody_elses', 1622),
#  ('lockdownno_whether', 1620),
#  ('took_first', 1588),
#  ('thank_president', 1522),
#  ('made_serum', 1486),
#  ('make_sure', 1464),
#  ('drericding_breakingdue', 1454),
#  ('surging_cases', 1454),
#  ('india_frozen', 1454),
#  ('major_exports', 1454),
#  ('doses_administered', 1422),
#  ('hug_please', 1408),
#  ('vaccine_treat', 1408),
#  ('iamwandasykes_fully', 1406),
#  ('vaccinated_rejuvenated', 1406),
#  ('trial_us', 1378),
#  ('dont_know', 1358),
#  ('effects_blood', 1338),
#  ('peru_chile', 1336),
#  ('drericding_blood', 1334),
#  ('clot_riskin', 1334),
#  ('clots_observ', 1334),
#  ('one_go', 1332),
#  ('younger_people', 1310),
#  ('public_health', 1296),
#  ('safe_effective', 1282),
#  ('johnson_amp', 1274),
#  ('excited_get', 1250),
#  ('follow_retweet', 1248),
#  ('get_sick', 1244),
#  ('years_age', 1234),
#  ('today_come', 1234),
#  ('appointments_available', 1226),
#  ('providing_vaccines', 1220),
#  ('announced_april', 1212),
#  ('like_free', 1200),
#  ('entry_win', 1196),
#  ('two_canon', 1196),
#  ('month_ago', 1192),
#  ('powershot_winner', 1190),
#  ('joe_biden', 1174),
#  ('drericding_horrible', 1166),
#  ('published_garbage', 1166),
#  ('true_extre', 1166),
#  ('mass_vaccination', 1134),
#  ('naheedd_red', 1128),
#  ('dots_pharmacies', 1128),
#  ('red_blank', 1128),
#  ('spot_torontos', 1128),
#  ('northwest_corner', 1128),
#  ('one_areas', 1128),
#  ('hardest_hi', 1128),
#  ('stark_contrast', 1116),
#  ('drkhaldun_worked', 1112),
#  ('er_last', 1112),
#  ('night_covid', 1112),
#  ('hospitalized_sprea', 1112),
#  ('datadrivenmd_age', 1106),
#  ('though_deaths', 1106),
#  ('california_latinos', 1106),
#  ('theyve_disproportionat', 1106),
#  ('first_lady', 1104),
#  ('next_week', 1102),
#  ('morning_im', 1096),
#  ('book_appointment', 1092),
#  ('vaccine_passports', 1090),
#  ('loved_ones', 1084),
#  ('deadly_virus', 1076),
#  ('davidmweissman_good', 1030),
#  ('made_china', 1018),
#  ('vaccination_centre', 1016),
#  ('north_korea', 1010),
#  ('myanmar_infected', 1006),
#  ('minaunghlaing_whats', 1000),
#  ('progress_dose', 990),
#  ('received_second', 984),
#  ('good_news', 972),
#  ('house_nairobi', 962),
#  ('took_state', 960),
#  ('back_normal', 946),
#  ('bring_vaccines', 946),
#  ('ontario_needs', 946),
#  ('spreading_false', 940),
#  ('account_hamidmirpak', 932),
#  ('doses_freezers', 928),
#  ('doctors_vaccinate', 922),
#  ('equip_family', 920),
#  ('vaccineswork_coronavirus', 914),
#  ('margaret_kenyatta', 914),
#  ('review_astrazeneca', 914),
#  ('uhuru_kenyatta', 912),
#  ('works_pfizer', 906),
#  ('hotvickkrishna_mrna', 904),
#  ('vaccine_modernapfizer', 904),
#  ('arising_vaccine', 896),
#  ('refusing_insure', 894),
#  ('wear_mask', 892),
#  ('newtonclarkeuk_bupa', 892),
#  ('age_eligible', 890),
#  ('statehousekenya_president', 890),
#  ('april_citizens', 860),
#  ('los_angeles', 856),
#  ('irelandvaccine_dose', 840),
#  ('mar_note', 818),
#  ('sore_arm', 818),
#  ('social_media', 814),
#  ('starting_april', 810),
#  ('feel_like', 808),
#  ('slots_va', 806),
#  ('gon_na', 796),
#  ('places_jab', 794),
#  ('job_nice', 794),
#  ('work_told', 794),
#  ('one_borisjohnson', 792),
#  ('health_care', 784),
#  ('im_feeling', 782),
#  ('scientists_amp', 776),
#  ('great_news', 776),
#  ('convention_center', 764),
#  ('far_everyday', 754),
#  ('dont_want', 750),
#  ('eligible_receive', 746),
#  ('thebaumann_miss', 742),
#  ('fact_scottmorrisonmp', 742),
#  ('secured_cheapest', 742),
#  ('australians_https', 742),
#  ('oliviatroye_everything', 738),
#  ('happened_take', 738),
#  ('anything_moment', 738),
#  ('granted_grateful', 738),
#  ('year_old', 728),
#  ('last_week', 718),
#  ('press_briefing', 714),
#  ('palm_springs', 712),
#  ('power_get', 712),
#  ('looking_forward', 710),
#  ('new_cases', 708),
#  ('mirmakofficial_shame', 708),
#  ('ministers_relatives', 708),
#  ('ministers_using', 708),
#  ('alhambra_anaheim', 702),
#  ('even_us', 700),
#  ('well_planned', 700),
#  ('narendramodi_smooth', 696),
#  ('campaign_wow', 696),
#  ('via_youtube', 694),
#  ('vivekagnihotri_india', 694),
#  ('must_obliged', 694),
#  ('last_night', 692),
#  ('stay_safe', 674),
#  ('well_done', 670),
#  ('linahidalgotx_part', 668),
#  ('monday_w', 664),
#  ('protect_family', 662),
#  ('running_get', 660),
#  ('essential_workers', 658),
#  ('virus_many', 656),
#  ('kimkbaltimore_people', 654),
#  ('tested_posting', 654),
#  ('agrees_give', 650),
#  ('every_day', 646),
#  ('years_old', 640),
#  ('vaccination_centres', 640),
#  ('coronavaccine_pakistan', 640),
#  ('el_centro', 634),
#  ('meghupdates_china', 634),
#  ('refuses_donate', 634),
#  ('payment_collateral', 634),
#  ('people_arent', 626),
#  ('buena_park', 624),
#  ('join_us', 622),
#  ('year_ago', 622),
#  ('prime_minister', 620),
#  ('lcmchealth_accepting', 620),
#  ('bill_gates', 616),
#  ('healthcare_workers', 612),
#  ('sputnik_v', 604),
#  ('may_suggest', 598),
#  ('come_forward', 598),
#  ('one_step', 596),
#  ('newtonclarkeuk_youre', 596),
#  ('youre_annoyed', 596),
#  ('please_share', 594),
#  ('looks_like', 588),
#  ('need_send', 588),
#  ('pharmaceutical_companies', 582),
#  ('side_effect', 580),
#  ('anyone_else', 578),
#  ('twittersupport_verified', 578),
#  ('apple_valley', 576),
#  ('hello_twittersafety', 576),
#  ('inequality_great', 574),
#  ('inequality_lead', 574),
#  ('tragedy_pandemic', 574),
#  ('health_workers', 572),
#  ('baldwin_park', 570),
#  ('clovis_corona', 566),
#  ('time_thinking', 564),
#  ('inordinate_amount', 562),
#  ('preventing_amp', 562),
#  ('drericding_theatlantic', 562),
#  ('save_lives', 560),
#  ('somebody_spends', 560),
#  ('profemilyoster_horrible', 560),
#  ('published_nonsense', 560),
#  ('mpaimd_long', 558),
#  ('new_york', 556),
#  ('astra_zeneca', 556),
#  ('bakersfield_baldwin', 556),
#  ('two_weeks', 548),
#  ('make_appointment', 546),
#  ('safety_committee', 542),
#  ('got_mine', 536),
#  ('herd_immunity', 532),
#  ('still_waiting', 526),
#  ('today_salmankhan', 526),
#  ('family_docs', 524),
#  ('india_crosses', 522),
#  ('high_risk', 518),
#  ('drharshvardhan_largestvaccinedrive', 516),
#  ('third_wave', 516),
#  ('astrazeneca_blood', 516),
#  ('cathedral_city', 502),
#  ('long_beach', 500),
#  ('nilikm_ontario', 500),
#  ('immune_system', 498),
#  ('stop_spread', 498),
#  ('downey_el', 498),
#  ('thank_potus', 496),
#  ('vaccination_site', 496),
#  ('telling_truth', 494),
#  ('banning_beaumont', 492),
#  ('worlds_largestvaccinedrive', 492),
#  ('starting_press', 490),
#  ('briefing_emas', 490),
#  ('prac_review', 490),
#  ('eligible_citizens', 488),
#  ('next_leg', 488),
#  ('dont_understand', 486),
#  ('miamalan_breaking', 486),
#  ('granted_janssen', 486),
#  ('manufacture_jampj', 486),
#  ('jab_registration', 486),
#  ('lets_gear', 486),
#  ('best_source', 482),
#  ('azusa_bakersfield', 482),
#  ('share_nhs', 480),
#  ('underlying_health', 478),
#  ('available_every', 478),
#  ('deptofdefense_dod', 476),
#  ('plans_keep', 476),
#  ('commitment_make', 476),
#  ('military_beneficiary', 476),
#  ('early_summer', 476),
#  ('vaccination_programme', 474),
#  ('let_us', 472),
#  ('covidnewsbymib_indiafightscorona', 472),
#  ('canyon_country', 470),
#  ('dont_forget', 470),
#  ('cr_doses', 470),
#  ('dr_warner', 466),
#  ('calling_teachers', 466),
#  ('paid_leave', 466),
#  ('beverly_hills', 464),
#  ('pfizer_moderna', 464),
#  ('cheridinovo_breaking', 464),
#  ('spread_word', 462),
#  ('aged_years', 458),
#  ('persons_years', 456),
#  ('citizens_eligible', 450),
#  ('walk_ins', 448),
#  ('measures_could', 442),
#  ('lockdowns_representation', 440),
#  ('failure_implement', 440),
#  ('prevented_drastic', 440),
#  ('amp_harmful', 440),
#  ('hall_j', 440),
#  ('eligible_register', 440),
#  ('schedule_appointment', 438),
#  ('today_request', 438),
#  ('coronavirus_corona', 438),
#  ('vaccinate_anyone', 438),
#  ('vaccination_drive', 436),
#  ('nolaready_want', 430),
#  ('drericding_shoot', 430),
#  ('foot_rich', 430),
#  ('countries_much', 430),
#  ('feels_like', 428),
#  ('time_province', 426),
#  ('friends_getting', 424),
#  ('corona_coronavirus', 424),
#  ('naheedd_okay', 424),
#  ('sosaskatchewan_introduced', 424),
#  ('doug_fords', 422),
#  ('children_august', 418),
#  ('dutertepalpak_suggestion', 418),
#  ('letlenilead_solution', 418),
#  ('duterteresign_asap', 418),
#  ('youre_aged', 416),
#  ('given_satisfactory', 416),
#  ('explanation_vaccinating', 416),
#  ('mrfrankbaraan_problem', 416),
#  ('check_share', 414),
#  ('berniespofforth_one', 414),
#  ('weve_vaccinate', 414),
#  ('im_calling', 412),
#  ('ishatreza_note', 412),
#  ('amp_gfarooqi', 412),
#  ('age_born', 410),
#  ('important_role', 408),
#  ('plan_comes', 406),
#  ('deadder_todays', 406),
#  ('sending_cnic', 406),
#  ('cherylfull_best', 404),
#  ('descriptor_yet', 404),
#  ('torontostar_fordva', 404),
#  ('sharing_false', 402),
#  ('tested_positive', 400),
#  ('frontline_workers', 398),
#  ('today_seen', 398),
#  ('along_dr', 398),
#  ('jalil_parker', 398),
#  ('drharshvardhan_india', 396),
#  ('received_almost', 396),
#  ('bhai_got', 396),
#  ('deptvetaffairs_vaccines', 394),
#  ('around_help', 394),
#  ('stay_home', 394),
#  ('amp_whet', 394),
#  ('entering_lilavati', 394),
#  ('please_keep', 392),
#  ('meghasprasad_sallu', 392),
#  ('shot_cov', 392),
#  ('details_sustainabledevelopment', 392),
#  ('smart_smart', 392),
#  ('sustainability_monitoring', 392),
#  ('moderna_az', 390),
#  ('vaccines_urgently', 390),
#  ('play_ending', 388),
#  ('end_pandemic', 386),
#  ('stanfordmed_watch', 386),
#  ('register_elderly', 386),
#  ('twentynine_palms', 384),
#  ('adverse_events', 382),
#  ('dangerous_check', 382),
#  ('age_group', 380),
#  ('busydrt_many', 380),
#  ('finally_alhamdulillah', 380),
#  ('rosakoire_get', 380),
#  ('across_country', 378),
#  ('mashwaniazhar_abbu', 378),
#  ('encourage_everyone', 376),
#  ('thank_science', 376),
#  ('light_end', 376),
#  ('received_least', 376),
#  ('ogun_state', 376),
#  ('folks_go', 376),
#  ('cause_maybe', 372),
#  ('popup_clinic', 372),
#  ('even_though', 372),
#  ('park_camarillo', 372),
#  ('toungeincheek_series', 370),
#  ('vaccine_queens', 370),
#  ('simp_health', 370),
#  ('people_simp', 370),
#  ('federal_government', 370),
#  ('directive_know', 370),
#  ('tests_positive', 368),
#  ('drmercykorir_new', 368),
#  ('shot_afternoon', 366),
#  ('ryanshead_make', 366),
#  ('mind_doug', 366),
#  ('fema_offered', 366),
#  ('us_additional', 366),
#  ('turned_arizona', 366),
#  ('book_appointments', 364),
#  ('social_distancing', 362),
#  ('santa_monica', 360),
#  ('vaccination_sites', 360),
#  ('made_possible', 356),
#  ('today_phc', 354),
#  ('okeilewo_abeokuta', 354),
#  ('care_employees', 350),
#  ('hot_springs', 348),
#  ('wait_line', 348),
#  ('starneelima_salman', 348),
#  ('khan_took', 348),
#  ('im_pro', 346),
#  ('contra_costa', 346),
#  ('dukhyariuzi_hello', 346),
#  ('twittersafetytwittersupport_verified', 346),
#  ('start_tomorrow', 344),
#  ('vkiragandur_hombale', 344),
#  ('committed_wellbeing', 344),
#  ('associates_amp', 344),
#  ('families_management', 344),
#  ('friends_family', 342),
#  ('warm_forehead', 342),
#  ('never_ask', 340),
#  ('fresno_gardena', 340),
#  ('family_friends', 340),
#  ('due_second', 340),
#  ('southgate_temecula', 340),
#  ('nolaready_starting', 338),
#  ('hardest_hit', 338),
#  ('walk_center', 338),
#  ('gov_website', 336),
#  ('palm_desert', 334),
#  ('beacon_hospital', 334),
#  ('excellence_kagutamuseveni', 334),
#  ('vaccineswork_vaccinessavelives', 332),
#  ('im_excited', 332),
#  ('vaccines_acquired', 330),
#  ('free_charge', 328),
#  ('higher_risk', 328),
#  ('krispy_kreme', 328),
#  ('culver_city', 326),
#  ('angeles_lynwood', 326),
#  ('nhsengland_youre', 326),
#  ('peel_region', 324),
#  ('bell_gardens', 324),
#  ('health_department', 324),
#  ('support_vaccinations', 324),
#  ('constitutional_rights', 324),
#  ('tweet_martinkulldorff', 322),
#  ('either_support', 322),
#  ('vaccinations_delivered', 322),
#  ('fuck_auspol', 322),
#  ('cowin_portal', 320),
#  ('nhs_best', 320),
#  ('says_additional', 320),
#  ('steverussell_fedex', 318),
#  ('ground_crews', 318),
#  ('pearson_international', 318),
#  ('airport_unload', 318),
#  ('shipment_three', 318),
#  ('refrigerated_containers', 318),
#  ('social_care', 318),
#  ('coachella_desert', 318),
#  ('new_yorkers', 318),
#  ('single_dose', 318),
#  ('find_information', 318),
#  ('great_job', 316),
#  ('country_return', 316),
#  ('immune_response', 316),
#  ('injection_site', 314),
#  ('many_lives', 314),
#  ('clinical_trials', 314),
#  ('second_wave', 314),
#  ('circulate_quickly', 314),
#  ('clinic_toronto', 314),
#  ('blood_clot', 312),
#  ('wanting_open', 312),
#  ('inaccurate_claims', 312),
#  ('starting_march', 312),
#  ('working_survival', 312),
#  ('rate_goes', 312),
#  ('senior_citizens', 312),
#  ('clinic_visitors', 312),
#  ('bitch_loudest', 310),
#  ('normal_folks', 310),
#  ('arcadia_artesia', 310),
#  ('frankgunnphoto_vaccine', 310),
#  ('fresno_hanford', 308),
#  ('oxford_astrazeneca', 308),
#  ('scottfishman_know', 308),
#  ('desert_hot', 306),
#  ('park_buena', 306),
#  ('watch_video', 304),
#  ('ontario_total', 304),
#  ('long_term', 300),
#  ('help_protect', 300),
#  ('mar_freezerfridge', 300),
#  ('oxxrowanxxo_good', 300),
#  ('didnt_feel', 298),
#  ('staff_volunteers', 298),
#  ('strides_pharma', 298),
#  ('wear_masks', 296),
#  ('proud_mum', 296),
#  ('even_booked', 296),
#  ('despite_really', 294),
#  ('scared_migrants', 294),
#  ('justified_distrust', 294),
#  ('health_syste', 292),
#  ('ontario_years', 292),
#  ('united_states', 290),
#  ('dont_bother', 290),
#  ('appointment_saturday', 290),
#  ('hawaiian_gardens', 290),
#  ('imagine_wo', 290),
#  ('san_diego', 288),
#  ('government_offer', 288),
#  ('artesia_azusa', 288),
#  ('state_house', 288),
#  ('inviting_community', 286),
#  ('members_ages', 286),
#  ('anaheim_bell', 286),
#  ('help_keep', 286),
#  ('front_line', 286),
#  ('bakersfield_chico', 286),
#  ('absurd_based', 286),
#  ('social_distance', 286),
#  ('islamrizza_waiting', 286),
#  ('free_vitamins', 286),
#  ('minerals_herbs', 286),
#  ('nongmo_fruits', 286),
#  ('amp_vegetables', 286),
#  ('student_loan', 286),
#  ('meghupdates_indias', 286),
#  ('sciences_produce', 286),
#  ('chula_vista', 284),
#  ('nightshiftmd_imo', 284),
#  ('limiting_availability', 284),
#  ('chino_clovis', 284),
#  ('shots_arms', 282),
#  ('starting_monday', 282),
#  ('days_early', 282),
#  ('turn_comes', 282),
#  ('went_back', 282),
#  ('one_thinks', 280),
#  ('vaccineca_cvs', 280),
#  ('locations_show', 280),
#  ('false_information', 280),
#  ('anyone_years', 280),
#  ('clovis_fresno', 278),
#  ('best_way', 278),
#  ('working_hard', 278),
#  ('experimental_jabs', 278),
#  ('thats_crazy', 276),
#  ('pregnant_women', 276),
#  ('go_dinner', 276),
#  ('davidmweissman_potus', 276),
#  ('literally_got', 276),
#  ('phone_va', 276),
#  ('around_world', 274),
#  ('feeling_great', 272),
#  ('per_day', 272),
#  ('scenario_pave', 272),
#  ('old_destroyed', 272),
#  ('redondo_beach', 270),
#  ('part_much', 270),
#  ('felt_like', 270),
#  ('people_privilege', 270),
#  ('go_gym', 270),
#  ('get_nails', 270),
#  ('hope_centerofhopela', 270),
#  ('islamrizza_isnt', 268),
#  ('protect_others', 268),
#  ('vaccination_program', 268),
#  ('temecula_twentynine', 268),
#  ('get_tes', 268),
#  ('shomaristone_done', 268),
#  ('months_ago', 266),
#  ('slots_md', 266),
#  ('largestvaccinedrive_shri', 266),
#  ('thescenestar_la', 266),
#  ('want_single', 266),
#  ('dose_johnsonampjohnson', 266),
#  ('chico_clovis', 264),
#  ('source_info', 264),
#  ('book_online', 264),
#  ('burbank_camarillo', 264),
#  ('rancho_cucamonga', 262),
#  ('january_regist', 262),
#  ('jab_asap', 262),
#  ('sharing_experience', 262),
#  ('doctor_help', 262),
#  ('doses_homeless', 260),
#  ('community_phoenix', 260),
#  ('places_like', 260),
#  ('administering_doses', 260),
#  ('remember_irish', 260),
#  ('pm_picked', 260),
#  ('stethoscope_amp', 260),
#  ('venice_west', 258),
#  ('body_aches', 258),
#  ('effective_preventing', 258),
#  ('last_hours', 258),
#  ('born_january', 258),
#  ('union_minister', 258),
#  ('gardena_hollywood', 256),
#  ('right_thing', 256),
#  ('health_condition', 256),
#  ('azfamily_armed', 256),
#  ('johnson_medical', 256),
#  ('students_administered', 256),
#  ('major_milestone', 256),
#  ('tell_truth', 254),
#  ('aged_care', 252),
#  ('vaccinessavelives_vaccinated', 252),
#  ('arm_sore', 252),
#  ('west_hollywood', 252),
#  ('im_glad', 252),
#  ('wash_hands', 252),
#  ('hands_deck', 252),
#  ('diamond_bar', 252),
#  ('eligible_citizen', 252),
#  ('well_organised', 252),
#  ('adverse_reactions', 250),
#  ('yucca_valley', 250),
#  ('costa_mesa', 250),
#  ('across_mumbai', 250),
#  ('family_members', 248),
#  ('wearing_mask', 248),
#  ('questions_answered', 248),
#  ('receives_first', 248),
#  ('danville_emporia', 248),
#  ('rollout_inequitable', 246),
#  ('peel_scarborough', 246),
#  ('northwest_toronto', 246),
#  ('share_pics', 246),
#  ('fight_scott', 246),
#  ('lakh_doses', 244),
#  ('least_one', 244),
#  ('private_sector', 244),
#  ('chico_chino', 244),
#  ('gutresolution_march', 244),
#  ('deaths_lifethreatening', 244),
#  ('cases_permanent', 244),
#  ('next_month', 244),
#  ('many_essenti', 244),
#  ('tests_oddly', 244),
#  ('evaunicef_covax', 242),
#  ('emergency_use', 242),
#  ('kids_school', 242),
#  ('everyone_else', 242),
#  ('appointments_newly', 242),
#  ('camarillo_canyon', 242),
#  ('president_biden', 242),
#  ('vax_also', 242),
#  ('get_pap', 242),
#  ('feels_good', 240),
#  ('monday_march', 240),
#  ('still_wear', 240),
#  ('foreign_affairs', 240),
#  ('european_medicines', 240),
#  ('trump_doesnt', 240),
#  ('melissalmrogers_people', 240),
#  ('showing_pics', 240),
#  ('smear_colo', 240),
#  ('spread_virus', 238),
#  ('year_olds', 238),
#  ('community_members', 238),
#  ('everyone_involved', 238),
#  ('etnowlive_mahindragroup', 238),
#  ('chief_anand', 238),
#  ('mahindra_reiterates', 238),
#  ('plea_central', 238),
#  ('government_permit', 238),
#  ('maharashtra_universalise', 238),
#  ('offered_help', 238),
#  ('ceo_hse', 238),
#  ('click_link', 236),
#  ('service_please', 236),
#  ('health_minister', 236),
#  ('dighavkarkiran_list', 236),
#  ('watch_full', 234),
#  ('vaccination_rates', 234),
#  ('needles_palm', 234),
#  ('cocohealth_people', 234),
#  ('ask_antilockdown', 234),
#  ('movement_consists', 234),
#  ('mostly_certainly', 234),
#  ('led_political', 234),
#  ('save_life', 232),
#  ('rolling_hills', 232),
#  ('actively_choosing', 232),
#  ('michaelcoren_need', 232),
#  ('extremists_antia', 232),
#  ('hard_work', 230),
#  ('doctors_medical', 230),
#  ('apr_days', 230),
#  ('early_jul', 230),
#  ('new_variants', 230),
#  ('migunamiguna_despot', 230),
#  ('uhuru_kenyattas', 230),
#  ('ps_macharia', 230),
#  ('kamau_offered', 230),
#  ('free_foreign', 230),
#  ('diplomats_rich', 230),
#  ('gp_clinics', 230),
#  ('deserve_damn', 230),
#  ('ounce_credit', 230),
#  ('older_eligible', 228),
#  ('today_tirupathi', 228),
#  ('san_bernardino', 228),
#  ('primary_care', 228),
#  ('segundo_fresno', 228),
#  ('weve_flattened', 228),
#  ('wrong_curve', 228),
#  ('delay_uk', 228),
#  ('isnt_working', 228),
#  ('dont_change', 228),
#  ('davidmweissman_listen', 228),
#  ('drfauci_got', 228),
#  ('inglewood_los', 226),
#  ('got_ta', 224),
#  ('didnt_even', 224),
#  ('much_better', 224),
#  ('community_leaders', 224),
#  ('good_morning', 224),
#  ('pfizer_biontech', 224),
#  ('due_shipment', 224),
#  ('problem_india', 224),
#  ('hard_matthancock', 224),
#  ('vaccinestatusuk_targets', 222),
#  ('course_save', 222),
#  ('lives_livelihoods', 222),
#  ('nakasero_take', 222),
#  ('ministry_health', 220),
#  ('appointment_online', 220),
#  ('know_someone', 220),
#  ('wearing_masks', 220),
#  ('gives_us', 220),
#  ('good_thing', 220),
#  ('medical_history', 220),
#  ('jillpromoli_ontario', 220),
#  ('eu_exported', 218),
#  ('pulaski_richlands', 218),
#  ('wasayjalil_best', 218),
#  ('arvin_bakersfield', 216),
#  ('vice_president', 216),
#  ('staff_selfless', 216),
#  ('unicef_past', 216),
#  ('ethiopia_nigeria', 216),
#  ('sudan_philippines', 216),
#  ('team_effort', 214),
#  ('questions_passing', 214),
#  ('care_home', 212),
#  ('everyone_helped', 212),
#  ('usairforce_airmen', 212),
#  ('pop_site', 212),
#  ('hours_since', 210),
#  ('step_towards', 210),
#  ('cdc_said', 210),
#  ('springs_fresno', 210),
#  ('telling_patients', 210),
#  ('reluctant_telling', 210),
#  ('holding_extraordinary', 210),
#  ('meeting_investigation', 210),
#  ('fauci_ouchie', 208),
#  ('clinical_trial', 208),
#  ('narendramodi_ji', 208),
#  ('corona_covina', 208),
#  ('andhra_pradesh', 208),
#  ('presenter_nana', 208),
#  ('north_west', 208),
#  ('invite_book', 208),
#  ('shining_light', 208),
#  ('astrazeneca_thr', 208),
#  ('emerson_church', 208),
#  ('hills_buena', 206),
#  ('lets_keep', 206),
#  ('feel_fine', 206),
#  ('infectious_disease', 206),
#  ('county_residents', 206),
#  ('reedley_sanger', 206),
#  ('let_know', 206),
#  ('total_number', 206),
#  ('expert_group', 206),
#  ('vaccination_modelling', 206),
#  ('mygovindia_attention', 206),
#  ('happybritscot_well', 206),
#  ('done_privateeyenews', 206),
#  ('snps_less', 206),
#  ('stellar_record', 206),
#  ('nilikm_hey', 206),
#  ('ontario_pulling', 206),
#  ('carolynmcc_hey', 206),
#  ('jacksonville_peeps', 206),
#  ('jampj_va', 206),
#  ('read_full', 204),
#  ('paradiserajwar_mera', 204),
#  ('bharat_mahanwe', 204),
#  ('believe_peace', 204),
#  ('prosperity_growth', 204),
#  ('allhum_hain', 204),
#  ('cr_cumulative', 204),
#  ('questions_patients', 204),
#  ('ongoing_evaluation', 204),
#  ('thankyouscience_imnotgonnacryincvs', 204),
#  ('okimight_dontjudge', 204),
#  ('experts_say', 202),
#  ('themohanbabu_got', 202),
#  ('infectious_diseases', 202),
#  ('safety_net', 202),
#  ('falseinformation_misinformation', 202),
#  ('ema_convening', 202),
#  ('ad_hoc', 202),
#  ('march_provide', 202),
#  ('additional_input', 202),
#  ('kanwal_shauzab', 202),
#  ('terrible_suffering', 202),
#  ('real_uk', 202),
#  ('variant_lethal', 202),
#  ('therealhoarse_happened', 202),
#  ('ithitsya_sohap', 202),
#  ('different_county', 202),
#  ('gerards_school', 202),
#  ('major_landmark', 202),
#  ('little_bit', 200),
#  ('protect_loved', 200),
#  ('coronavirus_coronavirusupdates', 200),
#  ('big_pharma', 200),
#  ('johnson_johnson', 200),
#  ('health_services', 200),
#  ('union_health', 200),
#  ('richardgcorbett_bbcqt', 200),
#  ('reminder_bbcquestiontime', 200),
#  ('sandyford_industrial', 200),
#  ('estate_st', 200),
#  ('frontline_health', 198),
#  ('cancer_patients', 198),
#  ('aged_older', 198),
#  ('boris_johnson', 198),
#  ('hanford_highland', 198),
#  ('along_wife', 198),
#  ('unpaid_carers', 198),
#  ('ki_suno', 198),
#  ('waiting_administered', 198),
#  ('thats_supply', 198),
#  ('fresno_indio', 196),
#  ('family_doctors', 196),
#  ('drrobdavidson_get', 196),
#  ('protects_path', 196),
#  ('nhs_staff', 196),
#  ('president_uhuru', 196),
#  ('nhs_sending', 196),
#  ('jlancastercbc_ontario', 196),
#  ('end_march', 194),
#  ('proud_part', 194),
#  ('dr_fauci', 194),
#  ('hours_later', 192),
#  ('doesnt_mean', 192),
#  ('aged_book', 192),
#  ('time_stand', 192),
#  ('banning_barstow', 192),
#  ('hipaa_onepage', 192),
#  ('primer_basics', 192),
#  ('celliottability_today', 192),
#  ('south_africa', 192),
#  ('virginia_beach', 192),
#  ('dont_miss', 190),
#  ('mental_illness', 190),
#  ('important_part', 190),
#  ('wan_na', 190),
#  ('years_older', 190),
#  ('center_hall', 190),
#  ('share_video', 190),
#  ('crore_doses', 190),
#  ('needs_better', 190),
#  ('arm_hurts', 188),
#  ('people_covidpassports', 188),
#  ('standards_safety', 188),
#  ('covina_cypress', 188),
#  ('corona_costa', 188),
#  ('mesa_covina', 188),
#  ('drharshvardhan_laregstvaccinedrive', 188),
#  ('walkins_convention', 188),
#  ('imran_khan', 188),
#  ('mcdonalds_sprite', 188),
#  ('ward_secretariat', 186),
#  ('anaheim_hills', 186),
#  ('vaccineswork_vaccineequity', 186),
#  ('cdc_says', 184),
#  ('bharathpet_guntur', 184),
#  ('biharhealthdept_bulletin', 184),
#  ('daily_state', 184),
#  ('report_provisional', 184),
#  ('largestvaccinedrive_https', 184),
#  ('couple_days', 184),
#  ('appointment_openings', 184),
#  ('rising_cases', 184),
#  ('health_organization', 184),
#  ('gp_practice', 184),
#  ('starting_tomorrow', 182),
#  ('become_eligible', 182),
#  ('answer_questions', 182),
#  ('yednetworkke_elderly', 182),
#  ('infection_thus', 182),
#  ('european_union', 182),
#  ('huntington_park', 182),
#  ('gratitude_scientists', 182),
#  ('soon_possible', 182),
#  ('lansing_yall', 182),
#  ('links_pharmacy', 182),
#  ('didnt_know', 180),
#  ('porterville_redlands', 180),
#  ('coronavirus_guidelines', 180),
#  ('louisiana_eligible', 180),
#  ('graphs_like', 180),
#  ('shown_europe', 180),
#  ('explains_pressure', 180),
#  ('head_government', 180),
#  ('trying_save', 180),
#  ('pages_https', 180),
#  ('best_protection', 178),
#  ('scorecards_march', 178),
#  ('hug_brother', 178),
#  ('denny_im', 178),
#  ('amp_patachanjokaachonjo', 178),
#  ('yednetworkke_collectively', 178),
#  ('angamizacorona_wearamask', 178),
#  ('eu_plannin', 178),
#  ('family_friend', 178),
#  ('colonial_heights', 178),
#  ('bakersfield_clovis', 178),
#  ('woman_dies', 178),
#  ('micrologsbyz_father', 178),
#  ('proud_citizen', 178),
#  ('indian_origin', 178),
#  ('part_job', 178),
#  ('beautiful_day', 176),
#  ('currently_eligible', 176),
#  ('expected_high', 176),
#  ('quality_efficacy', 176),
#  ('bjsurgery_important', 176),
#  ('openaccessbjs_paper', 176),
#  ('preop_vaccines', 176),
#  ('safe_surg', 176),
#  ('yednetworkke_rise', 176),
#  ('angamizacorona_ar', 176),
#  ('tells_truth', 176),
#  ('everyone_louisiana', 176),
#  ('doug_ford', 176),
#  ('yednetworkke_throughout', 176),
#  ('care_colleagues', 176),
#  ('response_youve', 176),
#  ('led_past', 176),
#  ('resources_could', 176),
#  ('starting_apri', 176),
#  ('assaulted_khalistani', 176),
#  ('ag_apparently', 176),
#  ('full_salary', 176),
#  ('meanwhile_many', 176),
#  ('youve_received', 174),
#  ('anita_anand', 174),
#  ('dhscgovuk_sharing', 174),
#  ('learning_disability', 174),
#  ('people_lining', 174),
#  ('hanford_kingsburg', 174),
#  ('cnoengland_couldnt', 174),
#  ('proud_nursing', 174),
#  ('midwifery_amp', 174),
#  ('three_weeks', 172),
#  ('health_ministry', 172),
#  ('things_starting', 172),
#  ('press_conference', 172),
#  ('visit_call', 172),
#  ('look_someone', 172),
#  ('salman_khan', 172),
#  ('alertmore_californians', 172),
#  ('data_shows', 170),
#  ('every_single', 170),
#  ('study_shows', 170),
#  ...]

# %%
labels = ['Words', 'Frequency']
df = pd.DataFrame.from_records(data[:20000], columns=labels)
df
# Out:
#                     Words  Frequency
# 0          anniversary_im       8912
# 1                see_safe       8908
# 2           ichaydon_year       8898
# 3               ago_tried       8898
# 4               two_doses       7064
# ...                   ...        ...
# 3515      introduced_paid          2
# 3516        leave_looking          2
# 3517  hilarious_explainer          2
# 3518    concerns_relating          2
# 3519         co_morbidity          2
#
# [3520 rows x 2 columns]
