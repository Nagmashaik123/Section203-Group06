# %% [markdown]
# <a href="https://colab.research.google.com/github/Nagmashaik123/Section203-Group06/blob/main/model_LDA_on_Vaccine_Brands.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import re
import os
import io
import spacy
import string
import numpy as np
import pandas as pd

# Gensim
import gensim
from gensim import models
import gensim.corpora as corpora
from gensim.models import Phrases
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read and Prepare Dataset

# %%
dataset = pd.read_csv("ProcessedCovidVaccineReact.csv", index_col=0)
dataset.shape
# Out:
# (352022, 6)

# %%
dataset = dataset.dropna() # drop null values
dataset.shape
# Out:
# (352010, 6)

# %%
dataset.head(5)
# Out:
#                                                              TweetText  ...         Country
# TweetDate                                                               ...
# 2021-03-17 23:59:34  The only way #COVID19 can mutate with variants...  ...         Unknown
# 2021-03-17 23:59:20  I've now officially had my 1st dose of the #Co...  ...         Unknown
# 2021-03-17 23:58:31  @hendopolis Imagine if the #Brexit referendum ...  ...  United Kingdom
# 2021-03-17 23:58:03  @EICostheta @RicBarraArch1 @insiders Yep. The ...  ...       Australia
# 2021-03-17 23:57:37  This sounds like an important topic for @NickS...  ...          Brazil
#
# [5 rows x 6 columns]

# %%
text_data = dataset["CleanedTweet"]  # select cleaned tweets column

# %%
text__data =  [text.split() for text in text_data]  # tokenize dataset

# %%
len(text__data)
# Out:
# 352010

# %%
# Manually declaring keywords for each vaccine through tweet observation
pfizer_Vaccine = [ 'pfizer', 'pfizervaccine','pfizercovidvaccine','modernapfizer','biotech','pfizerbiotech','pfizerbiontech'] 
Moderna_Vaccine =['modernavaccine','teammoderna','moderna','modernagang','modernas'] # Moderna Vaccine
Johnson_Vaccine = ['johnsonandjohnson','johnsonandjohnsonvaccine','johnsonjohnson','johnsons','borisjohnsons','johnsonampjohnson','johnsonjohnsonvax','johnsonand','janssenglobal','janssenvaccine','janssen','janssenus'] # johnsonandjohnson Vaccine
Covaxin_Vaccine =['covax','vax','covaxin','covaxsd','covaxinrockstheworld','covaxvaccinations','covaxinreiterated'] # Covaxin Vaccine
Covishield_Vaccine =['covishield','covishieldvaccine','covishielded'] # Covishield Vaccine
Astrazeneca_Vaccine = ['astrazeneca','breakingastrazeneca','oxfordastrazeneca','astrazenecas',
                       'astrazenecavaccine','astrazenecaoxford','astrazenecauk']
Sputnik_Vaccine = ['sputnikint','sputnik','sputnikvaccine','sputnikv','sputnikvaccineke',
                   'sputnikvaccineinkenya','sputnikvaccinekenya']         


text_data = []
for tweetSentence in text__data:
  
  sent = []
  for tweetWord in tweetSentence:
    if tweetWord in pfizer_Vaccine:
      sent.append('Pfizer')
    elif tweetWord in Moderna_Vaccine:
      sent.append('Moderna')
    elif tweetWord in Astrazeneca_Vaccine:
      sent.append('Astrazenca')
    elif tweetWord in Johnson_Vaccine:
      sent.append('Johnson&jonson')
    elif tweetWord in Covaxin_Vaccine:
      sent.append('Covaxin')
    elif tweetWord in Sputnik_Vaccine:
      sent.append('Sputnik')
    else :
      pass
         
       
  if sent:
    text_data.append(sent)

# %%
text_data
# Out:
# [['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Moderna', 'Moderna'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Pfizer', 'Pfizer'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Pfizer', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Moderna', 'Moderna', 'Pfizer', 'Pfizer', 'Pfizer'],
#  ['Astrazenca'],
#  ['Johnson&jonson'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Pfizer', 'Pfizer'],
#  ['Pfizer'],
#  ['Moderna', 'Moderna', 'Moderna'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Pfizer', 'Pfizer', 'Pfizer'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca', 'Pfizer'],
#  ['Covaxin'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer', 'Moderna'],
#  ['Pfizer'],
#  ['Covaxin'],
#  ['Moderna', 'Moderna'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer', 'Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer', 'Moderna'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Moderna', 'Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Covaxin', 'Covaxin'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer', 'Moderna'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Pfizer', 'Astrazenca'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer', 'Covaxin'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Johnson&jonson'],
#  ['Pfizer', 'Astrazenca', 'Pfizer'],
#  ['Moderna', 'Moderna'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Johnson&jonson'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Johnson&jonson'],
#  ['Pfizer', 'Pfizer', 'Pfizer'],
#  ['Johnson&jonson'],
#  ['Pfizer', 'Pfizer', 'Pfizer'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Moderna', 'Covaxin', 'Moderna'],
#  ['Astrazenca', 'Astrazenca', 'Astrazenca'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Moderna', 'Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Moderna', 'Moderna'],
#  ['Pfizer'],
#  ['Covaxin'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Covaxin'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer', 'Moderna', 'Sputnik'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Pfizer', 'Pfizer'],
#  ['Moderna', 'Pfizer'],
#  ['Pfizer'],
#  ['Johnson&jonson'],
#  ['Moderna'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Sputnik', 'Sputnik', 'Sputnik'],
#  ['Pfizer'],
#  ['Moderna', 'Pfizer'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Moderna', 'Pfizer', 'Moderna', 'Pfizer'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Pfizer', 'Moderna'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Pfizer', 'Moderna'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Sputnik'],
#  ['Moderna'],
#  ['Pfizer', 'Pfizer'],
#  ['Pfizer'],
#  ['Pfizer', 'Pfizer'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Johnson&jonson', 'Moderna'],
#  ['Moderna'],
#  ['Pfizer', 'Pfizer'],
#  ['Pfizer', 'Pfizer'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Pfizer', 'Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Covaxin', 'Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Pfizer'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Johnson&jonson'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna', 'Pfizer', 'Johnson&jonson'],
#  ['Pfizer', 'Pfizer'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca', 'Astrazenca'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Moderna', 'Moderna', 'Moderna'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Covaxin'],
#  ['Moderna', 'Moderna'],
#  ['Pfizer'],
#  ['Astrazenca', 'Pfizer'],
#  ['Astrazenca'],
#  ['Moderna', 'Moderna'],
#  ['Covaxin'],
#  ['Moderna'],
#  ['Johnson&jonson'],
#  ['Moderna'],
#  ['Johnson&jonson', 'Johnson&jonson', 'Johnson&jonson'],
#  ['Astrazenca'],
#  ['Pfizer', 'Astrazenca'],
#  ['Covaxin', 'Covaxin', 'Covaxin'],
#  ['Covaxin'],
#  ['Covaxin', 'Pfizer', 'Moderna'],
#  ['Pfizer'],
#  ['Astrazenca', 'Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Pfizer', 'Moderna'],
#  ['Pfizer'],
#  ['Covaxin'],
#  ['Sputnik'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca', 'Astrazenca'],
#  ['Pfizer'],
#  ['Covaxin', 'Covaxin'],
#  ['Covaxin'],
#  ['Astrazenca', 'Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Pfizer', 'Pfizer'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Pfizer', 'Moderna', 'Johnson&jonson'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Johnson&jonson'],
#  ['Pfizer', 'Astrazenca', 'Moderna', 'Johnson&jonson'],
#  ['Covaxin', 'Covaxin'],
#  ['Moderna', 'Moderna'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer', 'Moderna', 'Astrazenca', 'Johnson&jonson'],
#  ['Pfizer', 'Moderna'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca', 'Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Sputnik'],
#  ['Pfizer', 'Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca', 'Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Pfizer'],
#  ['Moderna'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Johnson&jonson'],
#  ['Astrazenca', 'Astrazenca', 'Astrazenca'],
#  ['Moderna'],
#  ['Covaxin'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Johnson&jonson'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Covaxin'],
#  ['Pfizer'],
#  ['Pfizer', 'Moderna', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer', 'Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Pfizer', 'Moderna'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Moderna', 'Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Covaxin', 'Covaxin'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Covaxin'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Covaxin'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Moderna', 'Pfizer', 'Johnson&jonson'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer', 'Moderna'],
#  ['Pfizer', 'Pfizer'],
#  ['Moderna'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Covaxin'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Moderna'],
#  ['Pfizer', 'Covaxin'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Pfizer', 'Covaxin'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Covaxin'],
#  ['Pfizer', 'Moderna', 'Moderna', 'Pfizer'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Pfizer', 'Pfizer'],
#  ['Johnson&jonson', 'Johnson&jonson'],
#  ['Johnson&jonson'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer', 'Pfizer'],
#  ['Johnson&jonson'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca', 'Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer', 'Covaxin'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Moderna', 'Pfizer'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca', 'Moderna'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Pfizer', 'Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca', 'Covaxin'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Sputnik'],
#  ['Moderna'],
#  ['Covaxin'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Covaxin'],
#  ['Pfizer'],
#  ['Pfizer', 'Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Pfizer'],
#  ['Moderna'],
#  ['Astrazenca', 'Pfizer', 'Astrazenca', 'Astrazenca', 'Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer', 'Covaxin'],
#  ['Pfizer', 'Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna', 'Moderna'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Sputnik'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Pfizer', 'Pfizer', 'Pfizer', 'Pfizer'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer', 'Pfizer'],
#  ['Pfizer', 'Pfizer'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca', 'Astrazenca', 'Astrazenca'],
#  ['Astrazenca', 'Pfizer'],
#  ['Sputnik', 'Sputnik'],
#  ['Astrazenca', 'Moderna', 'Pfizer', 'Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer', 'Astrazenca'],
#  ['Pfizer', 'Astrazenca'],
#  ['Astrazenca', 'Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Sputnik', 'Sputnik'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Sputnik'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna', 'Moderna', 'Pfizer'],
#  ['Moderna', 'Moderna', 'Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Covaxin', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer', 'Astrazenca'],
#  ['Pfizer'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Johnson&jonson'],
#  ['Covaxin'],
#  ['Sputnik', 'Sputnik'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Sputnik', 'Sputnik'],
#  ['Sputnik', 'Sputnik'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Covaxin', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Moderna', 'Moderna'],
#  ['Pfizer', 'Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Astrazenca', 'Astrazenca', 'Astrazenca', 'Astrazenca'],
#  ['Sputnik'],
#  ['Moderna'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca', 'Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Covaxin'],
#  ['Moderna', 'Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Pfizer', 'Pfizer'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Covaxin', 'Pfizer'],
#  ['Moderna', 'Moderna'],
#  ['Astrazenca'],
#  ['Moderna', 'Moderna'],
#  ['Moderna'],
#  ['Astrazenca', 'Astrazenca', 'Astrazenca'],
#  ['Pfizer', 'Moderna'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Covaxin'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Covaxin'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer', 'Pfizer', 'Pfizer', 'Pfizer'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca', 'Pfizer', 'Moderna'],
#  ['Moderna'],
#  ['Covaxin'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Sputnik', 'Sputnik'],
#  ['Pfizer'],
#  ['Johnson&jonson'],
#  ['Astrazenca'],
#  ['Covaxin', 'Covaxin'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Johnson&jonson'],
#  ['Pfizer', 'Moderna'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca', 'Pfizer', 'Moderna', 'Sputnik'],
#  ['Pfizer'],
#  ['Johnson&jonson'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Moderna', 'Pfizer', 'Pfizer'],
#  ['Johnson&jonson'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Pfizer'],
#  ['Covaxin'],
#  ['Johnson&jonson'],
#  ['Pfizer'],
#  ['Pfizer', 'Moderna'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Astrazenca', 'Astrazenca', 'Astrazenca'],
#  ['Covaxin'],
#  ['Pfizer', 'Astrazenca', 'Pfizer', 'Astrazenca'],
#  ['Sputnik'],
#  ['Pfizer', 'Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna', 'Moderna'],
#  ['Pfizer'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Moderna', 'Moderna'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Moderna', 'Pfizer'],
#  ['Astrazenca', 'Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer', 'Moderna'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Sputnik'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Pfizer', 'Pfizer'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer', 'Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer', 'Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Pfizer', 'Pfizer'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Johnson&jonson'],
#  ['Covaxin'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Johnson&jonson'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Covaxin'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Moderna', 'Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Moderna', 'Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Pfizer'],
#  ['Johnson&jonson'],
#  ['Pfizer'],
#  ['Johnson&jonson'],
#  ['Moderna', 'Pfizer'],
#  ['Moderna', 'Pfizer'],
#  ['Pfizer'],
#  ['Moderna'],
#  ['Johnson&jonson'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Johnson&jonson'],
#  ['Astrazenca'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Pfizer', 'Pfizer'],
#  ['Moderna', 'Moderna'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Johnson&jonson', 'Moderna', 'Pfizer'],
#  ['Johnson&jonson'],
#  ['Astrazenca'],
#  ['Covaxin'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer', 'Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Astrazenca', 'Astrazenca'],
#  ['Moderna', 'Moderna', 'Moderna'],
#  ['Sputnik'],
#  ['Moderna'],
#  ['Moderna'],
#  ['Astrazenca'],
#  ...]

# %% [markdown]
# ### Make Bigrams for LDA Model

# %%
# Build the bigram models
bigram = gensim.models.Phrases(text_data, min_count=1) # higher threshold fewer phrases.

# Faster way to get a sentence clubbed as a bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)

text_data = [bigram_mod[doc] for doc in text_data]

# %%
text_data[:10]
# Out:
# [['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Astrazenca'],
#  ['Pfizer'],
#  ['Astrazenca'],
#  ['Moderna'],
#  ['Moderna']]

# %% [markdown]
# # Build Dictionary

# %%
# make dictionary of complete corpus
dictionary_LDA = corpora.Dictionary(text_data)
# filter tokens below frequency of 3 words
dictionary_LDA.filter_extremes(no_below=3)
# index to words 
corpus = [dictionary_LDA.doc2bow(tok) for tok in text_data]

# %% [markdown]
# # Build LDA Model
# # Compute Coherence and Preplexity
# # Choose optimal number of topics

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    
    topics_list = [2, 4, 6, 8, 10, 12]
    coherence_values = []
    perplexity_val = []
    model_list = []
    for num_topics in topics_list:
        model = models.LdaModel(corpus, num_topics=num_topics, id2word=dictionary_LDA, passes=40,iterations =100, alpha=0.05, eta=0.01)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=text_data, dictionary=dictionary_LDA, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        perplexity_val.append(model.log_perplexity(corpus))

    return model_list, coherence_values, perplexity_val

# %% [markdown]
# # Train LDA Model

# %%
# Can take a long time to run.
model_list, coherence_values, perplexity_val = compute_coherence_values(dictionary=dictionary_LDA, corpus=corpus, texts=text_data, start=2, limit=40, step=6)

# %% [markdown]
# # Plot Coherence Scores

# %%
# Show graph
import matplotlib.pyplot as plt

topics_list = [2, 4,6, 8, 10, 12]
plt.plot(topics_list, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %% [markdown]
# # Plot Perplexity Scores

# %%
# Show graph
import matplotlib.pyplot as plt

topics_list = [2, 4,6, 8, 10, 12]
plt.plot(topics_list, perplexity_val)
plt.xlabel("Num Topics")
plt.ylabel("Perplexity score")
plt.legend(("perplexity_values"), loc='best')
plt.show()

# %% [markdown]
# ### Display Results

# %%
# Print the coherence scores
topics_list = [6, 8, 10, 12]
for m, cv, pr in zip(topics_list, coherence_values, perplexity_val):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4), " has Perplexity of", round(pr, 4))
# Out:
# Num Topics = 6  has Coherence Value of 0.1933  has Perplexity of -1.5671
# Num Topics = 8  has Coherence Value of 0.1933  has Perplexity of -1.7603
# Num Topics = 10  has Coherence Value of 0.1933  has Perplexity of -1.9494
# Num Topics = 12  has Coherence Value of 0.1933  has Perplexity of -2.0667

# %% [markdown]
# ## Train Model with Best number of topics

# %%
best_topic_number = 10
best_model = models.LdaModel(corpus, num_topics=best_topic_number, id2word=dictionary_LDA, passes=40, iterations = 100, alpha=0.05, eta=0.01)

# %%
coherencemodel = CoherenceModel(model=best_model, texts=text_data, dictionary=dictionary_LDA, coherence='c_v')
coherence_score = coherencemodel.get_coherence()
perplexity_score = best_model.log_perplexity(corpus)
print("Num Topics =", best_topic_number, " has Coherence Value of", round(coherence_score, 4), " has Perplexity of", round(perplexity_score, 4))
# Out:
# Num Topics = 10  has Coherence Value of 0.1933  has Perplexity of -2.2188

# %%
# display all topics with weight of all keywords
for i,topic in best_model.show_topics(formatted=True, num_topics=best_topic_number, num_words=10):
    print(str(i)+": "+ topic)
    print()
# Out:
# 0: 1.000*"Sputnik" + 0.000*"Pfizer" + 0.000*"Astrazenca" + 0.000*"Moderna" + 0.000*"Johnson&jonson" + 0.000*"Covaxin"
#
# 1: 1.000*"Johnson&jonson" + 0.000*"Pfizer" + 0.000*"Astrazenca" + 0.000*"Moderna" + 0.000*"Covaxin" + 0.000*"Sputnik"
#
# 2: 1.000*"Covaxin" + 0.000*"Pfizer" + 0.000*"Astrazenca" + 0.000*"Moderna" + 0.000*"Johnson&jonson" + 0.000*"Sputnik"
#
# 3: 1.000*"Moderna" + 0.000*"Pfizer" + 0.000*"Astrazenca" + 0.000*"Johnson&jonson" + 0.000*"Covaxin" + 0.000*"Sputnik"
#
# 4: 1.000*"Astrazenca" + 0.000*"Pfizer" + 0.000*"Moderna" + 0.000*"Johnson&jonson" + 0.000*"Covaxin" + 0.000*"Sputnik"
#
# 5: 1.000*"Astrazenca" + 0.000*"Pfizer" + 0.000*"Moderna" + 0.000*"Johnson&jonson" + 0.000*"Covaxin" + 0.000*"Sputnik"
#
# 6: 1.000*"Pfizer" + 0.000*"Astrazenca" + 0.000*"Moderna" + 0.000*"Johnson&jonson" + 0.000*"Covaxin" + 0.000*"Sputnik"
#
# 7: 0.501*"Pfizer" + 0.499*"Astrazenca" + 0.000*"Moderna" + 0.000*"Johnson&jonson" + 0.000*"Covaxin" + 0.000*"Sputnik"
#
# 8: 0.514*"Pfizer" + 0.486*"Moderna" + 0.000*"Astrazenca" + 0.000*"Johnson&jonson" + 0.000*"Covaxin" + 0.000*"Sputnik"
#
# 9: 1.000*"Pfizer" + 0.000*"Astrazenca" + 0.000*"Moderna" + 0.000*"Johnson&jonson" + 0.000*"Covaxin" + 0.000*"Sputnik"

# %%
# !pip install pyLDAvis==3.2.2
# Out:
# Collecting pyLDAvis==3.2.2
#   Downloading https://files.pythonhosted.org/packages/24/38/6d81eff34c84c9158d3b7c846bff978ac88b0c2665548941946d3d591158/pyLDAvis-3.2.2.tar.gz (1.7MB)
#      |████████████████████████████████| 1.7MB 17.3MB/s
# Requirement already satisfied: wheel>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==3.2.2) (0.36.2)
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==3.2.2) (1.19.5)
# Requirement already satisfied: scipy>=0.18.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==3.2.2) (1.4.1)
# Requirement already satisfied: joblib>=0.8.4 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==3.2.2) (1.0.1)
# Requirement already satisfied: jinja2>=2.7.2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==3.2.2) (2.11.3)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==3.2.2) (2.7.3)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==3.2.2) (0.16.0)
# Collecting funcy
#   Downloading https://files.pythonhosted.org/packages/66/89/479de0afbbfb98d1c4b887936808764627300208bb771fcd823403645a36/funcy-1.15-py2.py3-none-any.whl
# Requirement already satisfied: pandas>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==3.2.2) (1.1.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.7.2->pyLDAvis==3.2.2) (1.1.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17.0->pyLDAvis==3.2.2) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17.0->pyLDAvis==3.2.2) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.17.0->pyLDAvis==3.2.2) (1.15.0)
# Building wheels for collected packages: pyLDAvis
#   Building wheel for pyLDAvis (setup.py) ... done
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.2.2-py2.py3-none-any.whl size=135593 sha256=0a8cb359b5119edcc25e23cc6165b9df4b47b61a2f9fd4639387b924115241ca
#   Stored in directory: /root/.cache/pip/wheels/74/df/b6/97234c8446a43be05c9a8687ee0db1f1b5ade5f27729187eae
# Successfully built pyLDAvis
# Installing collected packages: funcy, pyLDAvis
# Successfully installed funcy-1.15 pyLDAvis-3.2.2

# %% [markdown]
# # Visulaize Topics

# %%
import pyLDAvis.gensim
warnings.filterwarnings('ignore')

pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(best_model, corpus, dictionary=dictionary_LDA, mds='mmds')
vis
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 3     -0.491891 -0.004153       1        1  16.291466
# 8     -0.276995  0.116503       2        1  13.483278
# 9     -0.113913  0.189091       3        1  12.069245
# 6     -0.113169  0.186053       4        1  11.951806
# 5      0.403934 -0.062293       5        1  10.971180
# 4      0.404069 -0.061812       6        1  10.836297
# 2      0.188266  0.523721       7        1   8.634434
# 1      0.125012 -0.499212       8        1   7.493317
# 0     -0.267465 -0.436285       9        1   4.958994
# 7      0.142152  0.048388      10        1   3.309983, topic_info=              Term          Freq         Total Category  logprob  loglift
# 1       Astrazenca  15811.000000  15811.000000  Default   6.0000   6.0000
# 0           Pfizer  21978.000000  21978.000000  Default   5.0000   5.0000
# 2          Moderna  15400.000000  15400.000000  Default   4.0000   4.0000
# 4          Covaxin   5819.000000   5819.000000  Default   3.0000   3.0000
# 3   Johnson&jonson   5050.000000   5050.000000  Default   2.0000   2.0000
# ..             ...           ...           ...      ...      ...      ...
# 0           Pfizer   1118.476643  21978.409715  Topic10  -0.6905   0.4301
# 5          Sputnik      0.050461   3342.557999  Topic10 -10.6968  -7.6928
# 3   Johnson&jonson      0.050461   5050.797366  Topic10 -10.6968  -8.1056
# 4          Covaxin      0.050461   5819.942649  Topic10 -10.6968  -8.2474
# 2          Moderna      0.050461  15400.099728  Topic10 -10.6968  -9.2204
#
# [66 rows x 6 columns], token_table=      Topic      Freq            Term
# term
# 1         5  0.467706      Astrazenca
# 1         6  0.461951      Astrazenca
# 1        10  0.070330      Astrazenca
# 4         7  1.000010         Covaxin
# 3         8  1.000040  Johnson&jonson
# 2         1  0.713047         Moderna
# 2         2  0.286946         Moderna
# 0         2  0.212436          Pfizer
# 0         3  0.370136          Pfizer
# 0         4  0.366542          Pfizer
# 0        10  0.050868          Pfizer
# 5         9  0.999833         Sputnik, R=6, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 9, 10, 7, 6, 5, 3, 2, 1, 8])

# %% [markdown]
# ![Screen Shot 2021-04-25 at 7.18.27 PM.png](data:image/png;base64,...)

# %% [markdown]
# # All Topics Probabilities in each Document

# %%
# convert all probability distribution into dataframe (we are doing this to also keep topics having 0 probability)
# In other case topics having 0 probability will be misleading
def topics_document_to_dataframe(topics_document, num_topics):
    res = pd.DataFrame(columns=range(num_topics))
    for topic_weight in topics_document:
        res.loc[0, topic_weight[0]] = topic_weight[1]
    return res

# %%
# find topic probabilities that model assign to all documents
topics = [best_model[corpus[i]] for i in range(len(text_data))]

# %%
# make dataframe of all document probability distribution
document_topic = \
pd.concat([topics_document_to_dataframe(topics_document, num_topics=best_topic_number) for topics_document in topics]) \
  .reset_index(drop=True).fillna(0)

# %%
document_topic.head(10)
# Out:
#           0         1         2  ...         7         8         9
# 0  0.033333  0.033333  0.033333  ...  0.033333  0.033333  0.700000
# 1  0.033333  0.033333  0.033333  ...  0.033333  0.033333  0.033333
# 2  0.033333  0.033333  0.033333  ...  0.033333  0.033333  0.033333
# 3  0.033333  0.033333  0.033333  ...  0.033333  0.033333  0.033333
# 4  0.033333  0.033333  0.033333  ...  0.033333  0.033333  0.033333
# 5  0.033333  0.033333  0.033333  ...  0.033333  0.033333  0.033333
# 6  0.033333  0.033333  0.033333  ...  0.033333  0.033333  0.700000
# 7  0.033333  0.033333  0.033333  ...  0.033333  0.033333  0.033333
# 8  0.033333  0.033333  0.033333  ...  0.033333  0.033333  0.033333
# 9  0.033333  0.033333  0.033333  ...  0.033333  0.033333  0.033333
#
# [10 rows x 10 columns]

# %% [markdown]
# # Calculate and Find Keywords in each Document

# %%
def format_topics_sentences(ldamodel=best_model, corpus=corpus, texts=text_data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Per_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=best_model, corpus=corpus, texts=text_data)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head(10)
# Out:
#    Document_No  ...          Text
# 0            0  ...      [Pfizer]
# 1            1  ...  [Astrazenca]
# 2            2  ...  [Astrazenca]
# 3            3  ...      [Pfizer]
# 4            4  ...  [Astrazenca]
# 5            5  ...  [Astrazenca]
# 6            6  ...      [Pfizer]
# 7            7  ...  [Astrazenca]
# 8            8  ...     [Moderna]
# 9            9  ...     [Moderna]
#
# [10 rows x 5 columns]
